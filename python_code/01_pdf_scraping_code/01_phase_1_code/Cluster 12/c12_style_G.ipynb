# %% [markdown]
# # Code for a subset of cluster 11 projects to test

# %%
import os
import pdfplumber
import pandas as pd
import re
import PyPDF2
from tabulate import tabulate

def clean_column_headers(headers):
    """Cleans column headers by normalizing and removing unwanted characters."""
    cleaned_headers = []
    for header in headers:
        if header is None:
            header = ""
        elif isinstance(header, str):
            header = header.lower()
            header = re.sub(r'\s+', ' ', header)
            header = re.sub(r'\(.*?\)', '', header)
            header = re.sub(r'[^a-zA-Z0-10\s]', '', header)
            header = header.strip()
        cleaned_headers.append(header)
    return cleaned_headers

def clean_string_cell(value):
    """Cleans string cells by removing newlines and trimming spaces."""
    if isinstance(value, str):
        return value.replace('\n', ' ').strip()
    return value

def contains_phrase(row, phrase):
    """Checks if any cell in a row contains a specific phrase."""
    regex_pattern = re.sub(r"\s+", r"\\s*", phrase)
    pattern = re.compile(regex_pattern, flags=re.IGNORECASE)
    return row.astype(str).apply(lambda cell: bool(pattern.search(cell))).any()


def extract_specific_phrase(title):
    """
    Extracts a specific phrase from the table title based on predefined keywords.

    Args:
        title (str): The table title string.

    Returns:
        str: The extracted specific phrase if found, else the original title.
    """
    phrases = [
        "PTO",
        "Reliability Network Upgrade",
        "Area Delivery Network Upgrade",
        "Local Delivery Network",
        "ADNU",
        "LDNU",
        "RNU"
    ]

    for phrase in phrases:
        if re.search(rf"\b{re.escape(phrase)}\b", title, re.IGNORECASE):
            return phrase
    return title  # Fallback to the entire title if no specific phrase is found



def reorder_columns(df):
    """
    Reorders the columns of the DataFrame based on the specified order.

    Args:
        df (pd.DataFrame): The DataFrame to reorder.

    Returns:
        pd.DataFrame: The reordered DataFrame.
    """
    desired_order = [
        "q_id",
        "cluster",
        "req_deliverability",
        "latitude",
        "longitude",
        "capacity",
        "point_of_interconnection",
        "type of upgrade",
        "upgrade",
        "description",
        "cost allocation factor"
    ]

    # Start with desired columns that exist in the DataFrame
    existing_desired = [col for col in desired_order if col in df.columns]

    # Then add the remaining columns
    remaining = [col for col in df.columns if col not in existing_desired]

    # Combine the two lists
    new_order = existing_desired + remaining

    # Reorder the DataFrame
    df = df[new_order]

    return df


def search_gps_coordinates(text):
    """Search for GPS coordinates using multiple patterns."""
    print("Searching for GPS coordinates...")
    gps_coords = re.search(r"gps coordinates:\s*([\d\.\-]+),\s*([\d\.\-]+)", text, re.IGNORECASE)
    if gps_coords:
        print(f"Found GPS coordinates: {gps_coords.groups()}")
        return gps_coords.groups()

    project_coords = re.search(r"latitude[:\s]*([\d\.\-]+)[^\d]+longitude[:\s]*([\d\.\-]+)", text, re.IGNORECASE)
    if project_coords:
        print(f"Found project coordinates: {project_coords.groups()}")
        return project_coords.groups()

    gps_coords_directional = re.search(
        r"gps coordinates:\s*([\d\.\-]+)\s*[nNsS],\s*([\d\.\-]+)\s*[eEwW]", text, re.IGNORECASE)
    if gps_coords_directional:
        lat, lon = gps_coords_directional.groups()
        latitude = lat if "N" in text.upper() else f"-{lat}"  # Adjust latitude sign
        longitude = lon if "E" in text.upper() else f"-{lon}"  # Adjust longitude sign
        print(f"Found directional GPS coordinates: {(latitude, longitude)}")
        return (latitude, longitude)

    print("GPS coordinates not found.")
    return (None, None)


 

def extract_table1(pdf_path):
    """
    Extracts the Point of Interconnection from Table 1 in the provided PDF.
    Implements a retry mechanism with different table extraction settings if initial attempts fail.

    Args:
        pdf_path (str): Path to the PDF file.

    Returns:
        str: Extracted Point of Interconnection value,
             "Value Missing" if label found but no value,
             or None if not found.
    """
    print(f"\nProcessing {pdf_path} for Table 1 extraction...")
    point_of_interconnection = None

    # Define the regex pattern for 'Point of Interconnection' (case-insensitive)
    poi_pattern = re.compile(r"Point\s+of\s+Interconnection", re.IGNORECASE)

    # Define different table extraction settings to try
    table_settings_list = [
        {
            "horizontal_strategy": "text",
            "vertical_strategy": "lines",
            "snap_tolerance": 1,
        },
        {
            "horizontal_strategy": "lines",
            "vertical_strategy": "lines",
            "snap_tolerance": 2,  # Increased tolerance for retry
        }
    ]

    with pdfplumber.open(pdf_path) as pdf:
        # Identify all pages that contain "Table 1"
        table1_pages = []
        for i, page in enumerate(pdf.pages):
            text = page.extract_text() or ""
            if re.search(r"Table\s*1\b", text, re.IGNORECASE):
                table1_pages.append(i)

        if not table1_pages:
            print("No Table 1 found in the PDF.")
            return None  # Return None if no Table 1 found

        first_page = table1_pages[0]
        last_page = table1_pages[-1]
        scrape_start = first_page
        scrape_end = last_page + 1  # Plus one to include the next page if needed

        print(f"Table 1 starts on page {scrape_start + 1} and ends on page {scrape_end + 1}")

        # Flag to indicate if extraction was successful
        extraction_successful = False

        # Iterate through the specified page range
        for page_number in range(scrape_start, min(scrape_end + 1, len(pdf.pages))):
            page = pdf.pages[page_number]
            print(f"\nScraping tables on page {page_number + 1} for Table 1...")

            for attempt, table_settings in enumerate(table_settings_list, start=1):
                print(f"\nAttempt {attempt} with table settings: {table_settings}")
                tables = page.find_tables(table_settings=table_settings)
                print(f"Found {len(tables)} table(s) on page {page_number + 1} with current settings.")

                for table_index, table in enumerate(tables, start=1):
                    tab = table.extract()
                    if not tab:
                        print(f"Table {table_index} on page {page_number + 1} is empty. Skipping.")
                        continue  # Skip empty tables

                    print(f"\n--- Table {table_index} on Page {page_number + 1} ---")
                    for row_num, row in enumerate(tab, start=1):
                        print(f"Row {row_num}: {row}")

                    # Iterate through each row in the table
                    for row_index, row in enumerate(tab, start=1):
                        # Iterate through each cell in the row
                        for cell_index, cell in enumerate(row, start=1):
                            if cell and poi_pattern.search(cell):
                                # Assuming the next column contains the value
                                poi_col_index = cell_index  # 1-based index
                                adjacent_col_index = poi_col_index + 1  # Next column

                                if adjacent_col_index <= len(row):
                                    poi_value = clean_string_cell(row[adjacent_col_index - 1])
                                    if poi_value:  # Check if the value is not empty
                                        point_of_interconnection = poi_value
                                        print(f"\nFound Point of Interconnection: '{point_of_interconnection}' "
                                              f"(Page {page_number + 1}, Table {table_index}, Row {row_index})")
                                        extraction_successful = True
                                        break  # Exit the cell loop
                                    else:
                                        print(f"\nPoint of Interconnection label found but adjacent value is empty "
                                              f"(Page {page_number + 1}, Table {table_index}, Row {row_index}).")
                                        # Proceed to scan surrounding rows for the value
                                        poi_value_parts = []

                                        # Define the range to scan: two rows above and two rows below
                                        # Convert to 0-based index
                                        current_row_idx = row_index - 1
                                        start_scan = max(0, current_row_idx - 2)
                                        end_scan = min(len(tab), current_row_idx + 3)  # Exclusive

                                        print(f"Scanning rows {start_scan + 1} to {end_scan} for POI value parts.")

                                        for scan_row_index in range(start_scan, end_scan):
                                            # Skip the current row where the label was found
                                            if scan_row_index == current_row_idx:
                                                continue

                                            scan_row = tab[scan_row_index]
                                            # Ensure the adjacent column exists in the scan row
                                            if adjacent_col_index - 1 < len(scan_row):
                                                scan_cell = clean_string_cell(scan_row[adjacent_col_index - 1])
                                                if scan_cell and not poi_pattern.search(scan_cell):
                                                    poi_value_parts.append(scan_cell)
                                                    print(f"Found POI part in row {scan_row_index + 1}: '{scan_cell}'")
                                                elif poi_pattern.search(scan_cell):
                                                    # If another POI label is found, skip it
                                                    print(f"Encountered another POI label in row {scan_row_index + 1}. Skipping this row.")
                                                    continue

                                        if poi_value_parts:
                                            # Concatenate the parts to form the complete POI value
                                            point_of_interconnection = " ".join(poi_value_parts)
                                            print(f"\nConcatenated Point of Interconnection: '{point_of_interconnection}' "
                                                  f"(Page {page_number + 1}, Table {table_index})")
                                            extraction_successful = True
                                            break  # Exit the cell loop
                                        else:
                                            print(f"\nNo POI value found in the surrounding rows "
                                                  f"(Page {page_number + 1}, Table {table_index}, Row {row_index}).")
                                            # Do not return immediately; proceed to retry
                                else:
                                    print(f"\nPoint of Interconnection label found but no adjacent column "
                                          f"(Page {page_number + 1}, Table {table_index}, Row {row_index}).")
                                    # Do not return immediately; proceed to retry
                        if extraction_successful:
                            break  # Exit the row loop
                    if extraction_successful:
                        break  # Exit the table loop
                if extraction_successful:
                    break  # Exit the attempt loop
            if extraction_successful:
                break  # Exit the page loop

    if not extraction_successful:
        # After all attempts, determine the appropriate return value
        if point_of_interconnection is not None and point_of_interconnection != "":
            # Label was found but no value
            print("Point of Interconnection label found but no adjacent value.")
            return "Value Missing"
        else:
            # Label not found
            print("Point of Interconnection not found in Table 1.")
            return None

    return point_of_interconnection





def extract_base_data(pdf_path, project_id):
    """Extract base data from the PDF and return as a DataFrame."""
    print("Extracting base data from PDF...")
    with open(pdf_path, 'rb') as pdf:
        reader = PyPDF2.PdfReader(pdf)
        text = ""
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                text += page_text

    text = clean_string_cell(text)

    queue_id = re.search(r"q[\s_-]*(\d+)", text, re.IGNORECASE)
    queue_id = queue_id.group(1) if queue_id else str(project_id)  # Use project_id if queue_id is not found
    print(f"Extracted Queue ID: {queue_id}")

    cluster_number = re.search(r"queue[\s_-]*cluster[\s_-]*(\d+)", text, re.IGNORECASE)
    cluster_number = cluster_number.group(1) if cluster_number else None
    print(f"Extracted Cluster Number: {cluster_number}")

    deliverability_status = re.search(r"(\w+)\s*capacity deliverability status", text, re.IGNORECASE)
    deliverability_status = deliverability_status.group(1) if deliverability_status else None
    print(f"Extracted Deliverability Status: {deliverability_status}")

    # Extract Capacity
    capacity = re.search(r"total rated output of (\d+)\s*mw", text, re.IGNORECASE)
    if capacity:
        capacity = int(capacity.group(1))
    else:
        capacity2 = re.search(r"(\d+)\s*mw", text)
        capacity = int(capacity2.group(1)) if capacity2 else None
    print(f"Extracted Capacity: {capacity}")

    # Removed Point of Interconnection extraction as per instruction
    point_of_interconnection = extract_table1(pdf_path)
    #point_of_interconnection = None
    latitude, longitude = search_gps_coordinates(text)

    # Initialize base data dictionary
    base_data = {
        "q_id": [queue_id],
        "cluster": [cluster_number],
        "req_deliverability": [deliverability_status],
        "latitude": [latitude],
        "longitude": [longitude],
        "capacity": [capacity],
        "point_of_interconnection": [point_of_interconnection]
    }

    print("Base data extracted:", base_data)
    return pd.DataFrame(base_data)





def extract_table7(pdf_path):
    """
    Extracts Table 7 data from the provided PDF.

    Args:
        pdf_path (str): Path to the PDF file.

    Returns:
        pd.DataFrame: Extracted Table 7 data.
    """
    print(f"\nProcessing {pdf_path} for Table 7 extraction...")
    extracted_tables = []
    specific_phrase = None  # To store the specific phrase from the table title

    with pdfplumber.open(pdf_path) as pdf:
        # Identify all pages that contain "Table 7" or "Table 7-"
        table7_pages = []
        for i, page in enumerate(pdf.pages):
            text = page.extract_text() or ""
            if re.search(r"Table\s*7[-\s]", text, re.IGNORECASE): #[-\s]
                table7_pages.append(i)

        if not table7_pages:
            print("No Table 7 found in the PDF.")
            return pd.DataFrame()  # Return empty DataFrame if no Table 7 found

        first_page = table7_pages[0]
        last_page = table7_pages[-1]
        scrape_start = first_page
        scrape_end = last_page + 1  # Plus one to include the next page

        print(f"Table 7 starts on page {scrape_start + 1} and ends on page {scrape_end + 1}")

        # Iterate through the specified page range
        for page_number in range(scrape_start, min(scrape_end + 1, len(pdf.pages))):
            page = pdf.pages[page_number]
            print(f"\nScraping tables on page {page_number + 1}...")
            tables = page.find_tables(table_settings={
                "horizontal_strategy": "lines",
                "vertical_strategy": "lines",
            })

            for table_index, table in enumerate(tables):
                tab = table.extract()
                if not tab:
                    print(f"Table {table_index + 1} on page {page_number + 1} is empty. Skipping.")
                    continue  # Skip empty tables

                # Get the bounding box of the current table
                table_bbox = table.bbox  # (x0, y0, x1, y1)

                # Define a bounding box from the top of the page to the top of the table
                # Coordinates: (x0, y0, x1, y1)
                title_bbox = (0, 0, page.width, table_bbox[1])

                # Extract text within the title bounding box
                title_text = page.within_bbox(title_bbox).extract_text() or ""

                # Initialize table_title as None
                table_title = None

                if title_text:
                    # Split the title text into lines and reverse to start checking from the closest line to the table
                    title_lines = title_text.split('\n')[::-1]

                    for line in title_lines:
                        line = line.strip()
                        # Check if the line matches the table title pattern (e.g., "Table 7-1: PTO Upgrade")
                        match = re.match(r"Table\s*7[-.]\d+[:\-\s]*(.*)", line, re.IGNORECASE)
                        if match:
                            table_title = match.group(1).strip()
                            break  # Stop after finding the closest table title

                if table_title:
                    # New Table 7 detected
                    specific_phrase = extract_specific_phrase(table_title)  # Extracted phrase from the title
                    print(f"New Table 7 detected: '{specific_phrase}' on page {page_number + 1}, table {table_index + 1}")

                    # Extract headers and data rows
                    headers = clean_column_headers(tab[0])
                    data_rows = tab[1:]

                    # Create DataFrame for the new table
                    try:
                        df_new = pd.DataFrame(data_rows, columns=headers)
                    except ValueError as ve:
                        print(f"Error creating DataFrame for new table on page {page_number + 1}, table {table_index + 1}: {ve}")
                        continue  # Skip this table due to error

                    # Special Handling for "Area Delivery Network Upgrade" Tables
                    if re.search(r"Area\s*Delivery\s*Network\s*Upgrade", specific_phrase, re.IGNORECASE):
                        print("Detected 'Area Delivery Network Upgrade' table.")
                        if "adnu" in df_new.columns:
                            # Rename 'adnu' to 'upgrade'
                            if "upgrade" in df_new.columns:
                                # Avoid duplicate 'upgrade' columns
                                df_new.drop(columns=['adnu'], inplace=True)
                                print("Dropped 'ADNU' column to avoid duplicate 'upgrade' columns.")
                            else:
                                df_new.rename(columns={'adnu': 'upgrade'}, inplace=True)
                                print("Renamed 'ADNU' to 'upgrade'.")
                        if "type of upgrade" not in df_new.columns:
                            df_new["type of upgrade"] = specific_phrase
                            print("Added 'type of upgrade' column with specific phrase.")
                    else:
                        # General Handling for other tables
                        if "type of upgrade" in df_new.columns:
                            first_row = df_new.iloc[0]
                            if pd.isna(first_row["type of upgrade"]) or first_row["type of upgrade"] == "":
                                print(f"Replacing 'None' in 'Type of Upgrade' for the first data row on page {page_number + 1}, table {table_index + 1}")
                                df_new.at[0, "type of upgrade"] = specific_phrase
                        else:
                            # If "Type of Upgrade" column does not exist, add it
                            df_new["type of upgrade"] = specific_phrase
                            print(f"'Type of Upgrade' column added with value '{specific_phrase}' on page {page_number + 1}, table {table_index + 1}")

                    # Ensure no duplicate columns
                    if df_new.columns.duplicated().any():
                        print(f"Duplicate columns detected in new table on page {page_number + 1}, table {table_index + 1}. Dropping duplicates.")
                        df_new = df_new.loc[:, ~df_new.columns.duplicated()]

                    # Append the new table to the list
                    extracted_tables.append(df_new)
                else:
                    # Continuation Table detected
                    if specific_phrase is None:
                        print(f"No previous Table 7 title found for continuation on page {page_number + 1}, table {table_index + 1}. Skipping.")
                        continue  # Skip if no previous title to refer to

                    print(f"Continuation Table detected on page {page_number + 1}, table {table_index + 1}")

                    # Treat all rows as data without headers
                    data_rows = tab

                    # Check if the number of columns matches
                    expected_columns = len(extracted_tables[-1].columns) if extracted_tables else None
                    if expected_columns is None:
                        print(f"No existing table to continue with on page {page_number + 1}, table {table_index + 1}. Skipping.")
                        continue  # No table to continue with

                    # Define expected columns based on the last extracted table
                    expected_headers = extracted_tables[-1].columns.tolist()

                    # Define the list of column headers to check in continuation tables
                    header_keywords = ["type of upgrade", "adnu"]

                    # Check if the first row contains any header keywords
                    first_continuation_row = data_rows[0] if len(data_rows) > 0 else []
                    is_header_row = any(
                        re.search(rf"\b{kw}\b", str(cell), re.IGNORECASE) for kw in header_keywords for cell in first_continuation_row
                    )

                    if is_header_row:
                        print(f"Detected header row in continuation table on page {page_number + 1}, table {table_index + 1}. Dropping the header row.")
                        data_rows = data_rows[1:]  # Drop the header row

                    # Special Handling for "Area Delivery Network Upgrade" Tables in Continuation
                    if re.search(r"Area\s*Delivery\s*Network\s*Upgrade", specific_phrase, re.IGNORECASE):
                        print("Handling continuation for 'Area Delivery Network Upgrade' table.")
                        if "adnu" in data_rows[0]:
                            # Rename 'ADNU' to 'upgrade' in continuation table.
                            print("Renaming 'ADNU' to 'upgrade' in continuation table.")
                            data_rows = [ ["upgrade"] + row[1:] for row in data_rows ]
                        if "type of upgrade" not in expected_headers:
                            # Insert 'upgrade' column at the beginning
                            print("Inserting 'type of upgrade' column with specific phrase in continuation table.")
                            data_rows = [ [specific_phrase] + row for row in data_rows ]

                    # Handle missing or extra columns
                    if len(data_rows[0]) < expected_columns:
                        if re.search(r"Area\s*Delivery\s*Network\s*Upgrade", specific_phrase, re.IGNORECASE):
                            # For ADNU tables, assume missing "upgrade" column
                            print(f"Detected missing 'upgrade' column in continuation table on page {page_number + 1}, table {table_index + 1}. Inserting 'upgrade' column.")
                            data_rows = [[specific_phrase] + row for row in data_rows]
                        else:
                            # For other tables, assume missing "Type of Upgrade" column
                            print(f"Detected missing 'Type of Upgrade' column in continuation table on page {page_number + 1}, table {table_index + 1}. Inserting 'Type of Upgrade' column.")
                            data_rows = [[specific_phrase] + row for row in data_rows]
                    elif len(data_rows[0]) > expected_columns:
                        # Extra columns detected; adjust accordingly
                        print(f"Detected extra columns in continuation table on page {page_number + 1}, table {table_index + 1}. Dropping extra columns.")
                        data_rows = [row[:expected_columns] for row in data_rows]

                    # Create DataFrame for the continuation table
                    try:
                        df_continuation = pd.DataFrame(data_rows, columns=expected_headers)
                    except ValueError as ve:
                        print(f"Error creating DataFrame for continuation table on page {page_number + 1}, table {table_index + 1}: {ve}")
                        continue  # Skip this table due to error

                    # Special Handling for "Area Delivery Network Upgrade" Tables in Continuation
                    if re.search(r"Area\s*Delivery\s*Network\s*Upgrade", specific_phrase, re.IGNORECASE):
                        if "type of upgrade" in df_continuation.columns:
                            first_row = df_continuation.iloc[0]
                            if pd.isna(first_row["type of upgrade"]) or first_row["type of upgrade"] == "":
                                print(f"Replacing 'None' in 'type of upgrade' for the first data row of continuation on page {page_number + 1}, table {table_index + 1}")
                                df_continuation.at[0, "type of upgrade"] = specific_phrase
                        else:
                            # If "type of upgrade" column does not exist, add it
                            df_continuation["type of upgrade"] = specific_phrase
                            print(f"'type of upgrade' column added with value '{specific_phrase}' for continuation on page {page_number + 1}, table {table_index + 1}")
                    else:
                        # General Handling for other tables
                        if "type of upgrade" in df_continuation.columns:
                            first_row = df_continuation.iloc[0]
                            if pd.isna(first_row["type of upgrade"]) or first_row["type of upgrade"] == "":
                                print(f"Replacing 'None' in 'Type of Upgrade' for the first data row of continuation on page {page_number + 1}, table {table_index + 1}")
                                df_continuation.at[0, "type of upgrade"] = specific_phrase
                        else:
                            # If "Type of Upgrade" column does not exist, add it
                            df_continuation["type of upgrade"] = specific_phrase
                            print(f"'Type of Upgrade' column added with value '{specific_phrase}' for continuation on page {page_number + 1}, table {table_index + 1}")

                    # Ensure no duplicate columns
                    if df_continuation.columns.duplicated().any():
                        print(f"Duplicate columns detected in continuation table on page {page_number + 1}, table {table_index + 1}. Dropping duplicates.")
                        df_continuation = df_continuation.loc[:, ~df_continuation.columns.duplicated()]

                    # Merge with the last extracted table
                    extracted_tables[-1] = pd.concat([extracted_tables[-1], df_continuation], ignore_index=True, sort=False)

    # After scraping all tables, concatenate them
    if extracted_tables:
        # To prevent reindexing errors, ensure all DataFrames have unique and consistent columns
        # Collect all unique column names
        all_columns = set()
        for df in extracted_tables:
            all_columns.update(df.columns.tolist())
        #all_columns = sorted(all_columns)  # Optional: sort columns for consistency

        standardized_tables = []
        for df in extracted_tables:
            # Reindex to have all columns, filling missing ones with NaN
            standardized_df = df.reindex(columns=all_columns)
            standardized_tables.append(standardized_df)

        print("\nConcatenating all extracted Table 7 data...")
        try:
            table7_data = pd.concat(standardized_tables, ignore_index=True, sort=False)
        except Exception as e:
            print(f"Error concatenating tables: {e}")
            table7_data = pd.DataFrame()
    else:
        print("No Table 7 data extracted.")
        table7_data = pd.DataFrame()

    return table7_data

# Example Usage
def main():
    pdfs = [    
       #"/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data/947/02_phase_1_study/Q947 GV Solar 3_C6Ph I_Appendix A-Individual Study Report_Final.pdf",
      # "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data/1010/02_phase_1_study/C7PhI Appendix A - Q1010 Dyer Summit Wind Repower.pdf",
      # "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data/1021/02_phase_1_study/Q1021_StocktonBiomass_PHI_Report-Addendum1.pdf",
       # "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data/1030/02_phase_1_study/C7PhI - Appendix A - Q1030   South Lake Solar.pdf",
       # "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data/1035/02_phase_1_study/C7PhI Appendix A - Q1035 Magellan Solar Final.pdf",
        #"/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data/1098/02_phase_1_study/C8 Ph I Appendix A - Q1098 Birds Landing Wind.pdf",
        #"/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data/1102/02_phase_1_study/C8 Ph I Appendix A - Q1102 Cornwall Energy Storage.pdf",
       # "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data/1130/02_phase_1_study/Q1130 Moon Prism 2_Appendix A Report_C8PhI.pdf",

        #"/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data/1133/02_phase_1_study/Q1133 Oveja Solar Farm_Appendix A Report_C8PhI.pdf",
        #"/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data/1158/02_phase_1_study/Q1158 Slate_Appendix A Report_C8PhI.pdf",
        #"/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data/1170/02_phase_1_study/QC8PhI_Q1170_Gateway Energy Storage_Appendix A_1-15-2016.pdf",
        #"/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data/1459/02_phase_1_study/Q1459_Mulqueeney_Ranch_Wind_OCR.pdf"
        "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data/1657/02_phase_1_study/QC12PhI_Q1657_Sandpiper_Storage_Appendix_A_01-15-2020.pdf"
    ]

    # Initialize an empty DataFrame to store all results
    core = pd.DataFrame()

    for pdf_path in pdfs:
        print(f"\nProcessing PDF: {pdf_path}")
        # Extract base data
        project_id = os.path.basename(pdf_path).split('.')[0]  # Modify as appropriate
        base_data = extract_base_data(pdf_path, project_id)

        # Extract Table 7 data
        table7_data = extract_table7(pdf_path)

        if table7_data.empty:
            print(f"No Table 7 data found in {pdf_path}. Using base data only.")
            merged_df = base_data
        else:
            # Merge base data with Table 7 data
            overlapping_columns = base_data.columns.intersection(table7_data.columns)
            table7_data = table7_data.drop(columns=overlapping_columns, errors='ignore')
            base_data_repeated = pd.concat([base_data] * len(table7_data), ignore_index=True)
            try:
                merged_df = pd.concat([base_data_repeated, table7_data], axis=1, sort=False)
                print(f"Merged base data with Table 7 data for {pdf_path}")
            except Exception as e:
                print(f"Error merging base data with Table 7 data for {pdf_path}: {e}")
                merged_df = base_data  # Fallback to base data only

        # Append to core
        try:
            core = pd.concat([core, merged_df], ignore_index=True, sort=False)
        except Exception as e:
            print(f"Error appending data from {pdf_path} to core DataFrame: {e}")

    # Clean up the entire DataFrame
    core = core.applymap(clean_string_cell)

    # Reorder columns as specified
    core = reorder_columns(core)
    print("\nColumns reordered as per specification.")

    # Display the final combined DataFrame
    print("\nFinal combined DataFrame:")
    print(tabulate(core, headers='keys', tablefmt='fancy_grid', showindex=False))

    # Save to CSV if needed
    # core.to_csv('final_data.csv', index=False)

if __name__ == "__main__":
    main()
# Out:
# Processing PDF: /Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/data/1657/02_phase_1_study/QC12PhI_Q1657_Sandpiper_Storage_Appendix_A_01-15-2020.pdf
# Extracting base data from PDF...
# Extracted Queue ID: 1657
# Extracted Cluster Number: 12
# Extracted Deliverability Status: None
# Extracted Capacity: None
#
# Processing /Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/data/1657/02_phase_1_study/QC12PhI_Q1657_Sandpiper_Storage_Appendix_A_01-15-2020.pdf for Table 1 extraction...
# Table 1 starts on page 3 and ends on page 5
#
# Scraping tables on page 3 for Table 1...
#
# Attempt 1 with table settings: {'horizontal_strategy': 'text', 'vertical_strategy': 'lines', 'snap_tolerance': 1}
# Found 0 table(s) on page 3 with current settings.
#
# Attempt 2 with table settings: {'horizontal_strategy': 'lines', 'vertical_strategy': 'lines', 'snap_tolerance': 2}
# Found 0 table(s) on page 3 with current settings.
#
# Scraping tables on page 4 for Table 1...
#
# Attempt 1 with table settings: {'horizontal_strategy': 'text', 'vertical_strategy': 'lines', 'snap_tolerance': 1}
# Found 1 table(s) on page 4 with current settings.
#
# --- Table 1 on Page 4 ---
# Row 1: ['']
# Row 2: ['']
# Row 3: ['Project Location']
# Row 4: ['']
# Row 5: ['']
# Row 6: ['']
# Row 7: ['']
# Row 8: ['']
# Row 9: ['Number and Type of Generators']
# Row 10: ['']
# Row 11: ['']
# Row 12: ['']
# Row 13: ['']
# Row 14: ['']
# Row 15: ['Generation Capacity by Source Type']
# Row 16: ['']
# Row 17: ['']
# Row 18: ['']
# Row 19: ['Generating Facility Gross Capacity']
# Row 20: ['']
# Row 21: ['Generating Facility Gross Output']
# Row 22: ['']
# Row 23: ['Generator Auxiliary Load']
# Row 24: ['']
# Row 25: ['Maximum Net Output at Generation']
# Row 26: ['']
# Row 27: ['']
# Row 28: ['']
# Row 29: ['Facility']
# Row 30: ['']
# Row 31: ['Estimated Generation Tie-Line Losses']
# Row 32: ['']
# Row 33: ['Estimated Maximum Net Output at POI']
# Row 34: ['']
# Row 35: ['']
# Row 36: ['']
# Row 37: ['(Note 1)']
# Row 38: ['']
# Row 39: ['Requested Net Output at the POI (Note 3)']
# Row 40: ['']
# Row 41: ['']
# Row 42: ['']
# Row 43: ['']
# Row 44: ['']
# Row 45: ['Interconnection Customer description of']
# Row 46: ['']
# Row 47: ['']
# Row 48: ['']
# Row 49: ['automatic control scheme which will be']
# Row 50: ['']
# Row 51: ['']
# Row 52: ['']
# Row 53: ['installed to ensure that the Maximum MW']
# Row 54: ['']
# Row 55: ['']
# Row 56: ['']
# Row 57: ['at POI does not exceed requested value']
# Row 58: ['']
# Row 59: ['']
# Row 60: ['']
# Row 61: ['']
# Row 62: ['']
# Row 63: ['Deliverability Requested']
# Row 64: ['']
# Row 65: ['']
# Row 66: ['']
# Row 67: ['']
# Row 68: ['']
# Row 69: ['Step-Up Transformers']
# Row 70: ['']
# Row 71: ['']
# Row 72: ['']
# Row 73: ['']
# Row 74: ['']
# Row 75: ['Point of Interconnection']
# Row 76: ['']
# Row 77: ['Interconnection Customer Requested In -']
# Row 78: ['']
# Row 79: ['']
# Row 80: ['']
# Row 81: ['Service Date']
# Row 82: ['']
# Row 83: ['Interconnection Customer Requested']
# Row 84: ['']
# Row 85: ['']
# Row 86: ['']
# Row 87: ['Commercial Operation Date']
# Row 88: ['']
#
# Point of Interconnection label found but no adjacent column (Page 4, Table 1, Row 75).
#
# Attempt 2 with table settings: {'horizontal_strategy': 'lines', 'vertical_strategy': 'lines', 'snap_tolerance': 2}
# Found 1 table(s) on page 4 with current settings.
#
# --- Table 1 on Page 4 ---
# Row 1: ['Project Location', 'Avenue La Pata, 1 mile south of Stallion Ridge, San Juan Capistrano,\nOrange, CA 92675\nLatitude: 33.485922 Longitude: -117.611970']
# Row 2: ['Number and Type of Generators', 'The project consists of 80x3 MVA FREEMAQ PCSK, FP3000K (2022)\nEnergy Battery Storage inverters']
# Row 3: ['Generation Capacity by Source Type', 'BESS = 240 MVA Charging Source: ISO Grid\nDuration: 4 Hrs. Total Storage Capability = 1120 MWh\nRequested Storage Charging Power (to be studied) = 200 MW']
# Row 4: ['Generating Facility Gross Capacity', '240 MVA']
# Row 5: ['Generating Facility Gross Output', '203.36 MW']
# Row 6: ['Generator Auxiliary Load', '0.12 MW']
# Row 7: ['Maximum Net Output at Generation\nFacility', '203.24 MW']
# Row 8: ['Estimated Generation Tie-Line Losses', '3.24 MW']
# Row 9: ['Estimated Maximum Net Output at POI\n(Note 1)', '200.1 MW (Note 2)']
# Row 10: ['Requested Net Output at the POI (Note 3)', '200 MW']
# Row 11: ['Interconnection Customer description of\nautomatic control scheme which will be\ninstalled to ensure that the Maximum MW\nat POI does not exceed requested value', 'The Plant Power Control (PPC) control system or equivalent plant\nProgrammable Logic Control (PLC) control system will monitor direct\ndata input from the POI, which will interface with the inverters and\ncustomer SCADA system, as well as the utility RTU. It will operate per\nexecuted set-point control of the MW output at the POI, as well as\npower factor and voltage control as needed to ensure the maximum\nMW at POI does not exceed 200 MW.']
# Row 12: ['Deliverability Requested', 'Full Capacity']
# Row 13: ['Step-Up Transformers', '\uf0b7 1x138/34.5/13.8-kV unit transformer, three phase, rated for 279\nMVA with 11% impedance on a 165 MVA base\n\uf0b7 80x34.5/0.6-Kv unit transformer, three phase, rated for 3.3 MVA\nwith 5.75% impedance on a 3.3 MVA base']
# Row 14: ['Point of Interconnection', 'New Switchyard with the Capistrano – Pico 138 kV line looped-in']
# Row 15: ['Interconnection Customer Requested In -\nService Date', '03/31/2023']
# Row 16: ['Interconnection Customer Requested\nCommercial Operation Date', '06/30/2023']
#
# Found Point of Interconnection: 'New Switchyard with the Capistrano – Pico 138 kV line looped-in' (Page 4, Table 1, Row 14)
# Searching for GPS coordinates...
# Found project coordinates: ('33.485922', '-117.611970')
# Base data extracted: {'q_id': ['1657'], 'cluster': ['12'], 'req_deliverability': [None], 'latitude': ['33.485922'], 'longitude': ['-117.611970'], 'capacity': [None], 'point_of_interconnection': ['New Switchyard with the Capistrano – Pico 138 kV line looped-in']}
#
# Processing /Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/data/1657/02_phase_1_study/QC12PhI_Q1657_Sandpiper_Storage_Appendix_A_01-15-2020.pdf for Table 7 extraction...
# No Table 7 found in the PDF.
# No Table 7 data found in /Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/data/1657/02_phase_1_study/QC12PhI_Q1657_Sandpiper_Storage_Appendix_A_01-15-2020.pdf. Using base data only.
#
# Columns reordered as per specification.
#
# Final combined DataFrame:
# ╒════════╤═══════════╤══════════════════════╤════════════╤═════════════╤════════════╤═════════════════════════════════════════════════════════════════╕
# │   q_id │   cluster │ req_deliverability   │   latitude │   longitude │ capacity   │ point_of_interconnection                                        │
# ╞════════╪═══════════╪══════════════════════╪════════════╪═════════════╪════════════╪═════════════════════════════════════════════════════════════════╡
# │   1657 │        12 │                      │    33.4859 │    -117.612 │            │ New Switchyard with the Capistrano – Pico 138 kV line looped-in │
# ╘════════╧═══════════╧══════════════════════╧════════════╧═════════════╧════════════╧═════════════════════════════════════════════════════════════════╛
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_59501/2058555679.py:652: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   core = core.applymap(clean_string_cell)

# %% [markdown]
# # Code for all Cluster 12 projects in style G

# %%
import os
import pdfplumber
import pandas as pd
import re
import PyPDF2
import traceback

# Define paths and project range
BASE_DIRECTORY = "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/03_data"
OUTPUT_CSV_PATH_ORIGINAL = "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/03_raw/rawdata_cluster12_style_G_originals.csv"
OUTPUT_CSV_PATH_ADDENDUM = "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/03_raw/rawdata_cluster12_style_G_addendums.csv"
LOG_FILE_PATH = "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/03_raw/scraping_cluster12_style_G_log.txt"
PROJECT_RANGE = range(1541, 1676)  # Inclusive range for q_ids in Clusters 11

# Initialize DataFrames
core_originals = pd.DataFrame()
core_addendums = pd.DataFrame()

# Initialize tracking variables
scraped_projects = set()
skipped_projects = set()
missing_projects = set()
scraped_pdfs = []
skipped_pdfs = []
addendum_pdfs = []
original_pdfs = []
style_n_pdfs = []  # List to track style N PDFs
total_pdfs_accessed = 0
total_pdfs_scraped = 0
total_pdfs_skipped = 0
original_has_table7 = {}  # Dictionary to track if original PDFs have table7

def clean_column_headers(headers):
    """Cleans column headers by normalizing and removing unwanted characters."""
    cleaned_headers = []
    for header in headers:
        if header is None:
            header = ""
        elif isinstance(header, str):
            header = header.lower()
            header = re.sub(r'\s+', ' ', header)
            header = re.sub(r'\(.*?\)', '', header)
            header = re.sub(r'[^a-zA-Z0-9\s]', '', header)
            header = header.strip()
        cleaned_headers.append(header)
    return cleaned_headers

def clean_string_cell(value):
    """Cleans string cells by removing newlines and trimming spaces."""
    if isinstance(value, str):
        return value.replace('\n', ' ').strip()
    return value

def contains_phrase(row, phrase):
    """Checks if any cell in a row contains a specific phrase."""
    regex_pattern = re.sub(r"\s+", r"\\s*", phrase)
    pattern = re.compile(regex_pattern, flags=re.IGNORECASE)
    return row.astype(str).apply(lambda cell: bool(pattern.search(cell))).any()

def extract_specific_phrase(title):
    """
    Extracts a specific phrase from the table title based on predefined keywords.

    Args:
        title (str): The table title string.

    Returns:
        str: The extracted specific phrase if found, else the original title.
    """
    phrases = [
        "PTO",
        "Reliability Network Upgrade",
        "Area Delivery Network Upgrade",
        "Local Delivery Network",
        "Other Potential Network Upgrade",
        "Area Delivery Network Upgrades",
        "Conditionally Assigned Network Upgrades",
        "ADNU",
        "LDNU",
        "RNU"
    ]

    for phrase in phrases:
        if re.search(rf"\b{re.escape(phrase)}\b", title, re.IGNORECASE):
            return phrase
    return title  # Fallback to the entire title if no specific phrase is found

def reorder_columns(df):
    """
    Reorders the columns of the DataFrame based on the specified order.

    Args:
        df (pd.DataFrame): The DataFrame to reorder.

    Returns:
        pd.DataFrame: The reordered DataFrame.
    """
    desired_order = [
        "q_id",
        "cluster",
        "req_deliverability",
        "latitude",
        "longitude",
        "capacity",
        "point_of_interconnection",
        "type of upgrade",
        "upgrade",
        "description",
        "cost allocation factor"
    ]

    # Start with desired columns that exist in the DataFrame
    existing_desired = [col for col in desired_order if col in df.columns]

    # Then add the remaining columns
    remaining = [col for col in df.columns if col not in existing_desired]

    # Combine the two lists
    new_order = existing_desired + remaining

    # Reorder the DataFrame
    df = df[new_order]

    return df

def search_gps_coordinates(text, log_file):
    """Search for GPS coordinates using multiple patterns."""
    gps_coords = re.search(r"gps coordinates:\s*([\d\.\-]+),\s*([\d\.\-]+)", text, re.IGNORECASE)
    if gps_coords:
        print(f"Found GPS coordinates: {gps_coords.groups()}", file=log_file)
        return gps_coords.groups()

    project_coords = re.search(r"latitude[:\s]*([\d\.\-]+)[^\d]+longitude[:\s]*([\d\.\-]+)", text, re.IGNORECASE)
    if project_coords:
        print(f"Found project coordinates: {project_coords.groups()}", file=log_file)
        return project_coords.groups()

    gps_coords_directional = re.search(
        r"gps coordinates:\s*([\d\.\-]+)\s*[nNsS],\s*([\d\.\-]+)\s*[eEwW]", text, re.IGNORECASE)
    if gps_coords_directional:
        lat, lon = gps_coords_directional.groups()
        latitude = lat if "N" in text.upper() else f"-{lat}"  # Adjust latitude sign
        longitude = lon if "E" in text.upper() else f"-{lon}"  # Adjust longitude sign
        print(f"Found directional GPS coordinates: {(latitude, longitude)}", file=log_file)
        return (latitude, longitude)

    print("GPS coordinates not found.", file=log_file)
    return (None, None)

def extract_table1(pdf_path, log_file):
    """
    Extracts the Point of Interconnection from Table 1 in the provided PDF.
    Implements a retry mechanism with different table extraction settings if initial attempts fail.

    Args:
        pdf_path (str): Path to the PDF file.
        log_file (file object): Log file to write print statements.

    Returns:
        str: Extracted Point of Interconnection value,
             "Value Missing" if label found but no value,
             or None if not found.
    """
    print(f"\nProcessing {pdf_path} for Table 1 extraction...", file=log_file)
    point_of_interconnection = None

    # Define the regex pattern for 'Point of Interconnection' (case-insensitive)
    poi_pattern = re.compile(r"Point\s+of\s+Interconnection", re.IGNORECASE)

    # Define different table extraction settings to try
    table_settings_list = [
        {
            "horizontal_strategy": "text",
            "vertical_strategy": "lines",
            "snap_tolerance": 1,
        },
        {
            "horizontal_strategy": "lines",
            "vertical_strategy": "lines",
            "snap_tolerance": 2,  # Increased tolerance for retry
        }
    ]

    try:
        with pdfplumber.open(pdf_path) as pdf:
            # Identify all pages that contain "Table 1"
            table1_pages = []
            for i, page in enumerate(pdf.pages):
                text = page.extract_text() or ""
                if re.search(r"Table\s*1\b", text, re.IGNORECASE):
                    table1_pages.append(i)

            if not table1_pages:
                print("No Table 1 found in the PDF.", file=log_file)
                return None  # Return None if no Table 1 found

            first_page = table1_pages[0]
            last_page = table1_pages[-1]
            scrape_start = first_page
            scrape_end = last_page + 2  # Plus one to include the next page if needed

            print(f"Table 1 starts on page {scrape_start + 1} and ends on page {scrape_end + 1}", file=log_file)

            # Flag to indicate if extraction was successful
            extraction_successful = False

            # Iterate through the specified page range
            for page_number in range(scrape_start, min(scrape_end + 1, len(pdf.pages))):
                page = pdf.pages[page_number]
                print(f"\nScraping tables on page {page_number + 1} for Table 1...", file=log_file)

                for attempt, table_settings in enumerate(table_settings_list, start=1):
                    print(f"\nAttempt {attempt} with table settings: {table_settings}", file=log_file)
                    tables = page.find_tables(table_settings=table_settings)
                    print(f"Found {len(tables)} table(s) on page {page_number + 1} with current settings.", file=log_file)

                    for table_index, table in enumerate(tables, start=1):
                        tab = table.extract()
                        if not tab:
                            print(f"Table {table_index} on page {page_number + 1} is empty. Skipping.", file=log_file)
                            continue  # Skip empty tables

                        print(f"\n--- Table {table_index} on Page {page_number + 1} ---", file=log_file)
                        for row_num, row in enumerate(tab, start=1):
                            print(f"Row {row_num}: {row}", file=log_file)

                        # Iterate through each row in the table
                        for row_index, row in enumerate(tab, start=1):
                            # Iterate through each cell in the row
                            for cell_index, cell in enumerate(row, start=1):
                                if cell and poi_pattern.search(cell):
                                    # Assuming the next column contains the value
                                    poi_col_index = cell_index  # 1-based index
                                    adjacent_col_index = poi_col_index + 1  # Next column

                                    if adjacent_col_index <= len(row):
                                        poi_value = clean_string_cell(row[adjacent_col_index - 1])
                                        if poi_value:  # Check if the value is not empty
                                            point_of_interconnection = poi_value
                                            print(f"\nFound Point of Interconnection: '{point_of_interconnection}' "
                                                  f"(Page {page_number + 1}, Table {table_index}, Row {row_index})", file=log_file)
                                            extraction_successful = True
                                            break  # Exit the cell loop
                                        else:
                                            print(f"\nPoint of Interconnection label found but adjacent value is empty "
                                                  f"(Page {page_number + 1}, Table {table_index}, Row {row_index}).", file=log_file)
                                            # Proceed to scan surrounding rows for the value
                                            poi_value_parts = []

                                            # Define the range to scan: two rows above and two rows below
                                            # Convert to 0-based index
                                            current_row_idx = row_index - 1
                                            start_scan = max(0, current_row_idx - 2)
                                            end_scan = min(len(tab), current_row_idx + 3)  # Exclusive

                                            print(f"Scanning rows {start_scan + 1} to {end_scan} for POI value parts.", file=log_file)

                                            for scan_row_index in range(start_scan, end_scan):
                                                # Skip the current row where the label was found
                                                if scan_row_index == current_row_idx:
                                                    continue

                                                scan_row = tab[scan_row_index]
                                                # Ensure the adjacent column exists in the scan row
                                                if adjacent_col_index - 1 < len(scan_row):
                                                    scan_cell = clean_string_cell(scan_row[adjacent_col_index - 1])
                                                    if scan_cell and not poi_pattern.search(scan_cell):
                                                        poi_value_parts.append(scan_cell)
                                                        print(f"Found POI part in row {scan_row_index + 1}: '{scan_cell}'", file=log_file)
                                                    elif poi_pattern.search(scan_cell):
                                                        # If another POI label is found, skip it
                                                        print(f"Encountered another POI label in row {scan_row_index + 1}. Skipping this row.", file=log_file)
                                                        continue

                                            if poi_value_parts:
                                                # Concatenate the parts to form the complete POI value
                                                point_of_interconnection = " ".join(poi_value_parts)
                                                print(f"\nConcatenated Point of Interconnection: '{point_of_interconnection}' "
                                                      f"(Page {page_number + 1}, Table {table_index})", file=log_file)
                                                extraction_successful = True
                                                break  # Exit the cell loop
                                            else:
                                                print(f"\nNo POI value found in the surrounding rows "
                                                      f"(Page {page_number + 1}, Table {table_index}, Row {row_index}).", file=log_file)
                                                # Do not return immediately; proceed to retry
                                    else:
                                        print(f"\nPoint of Interconnection label found but no adjacent column "
                                              f"(Page {page_number + 1}, Table {table_index}, Row {row_index}).", file=log_file)
                                        # Do not return immediately; proceed to retry
                            if extraction_successful:
                                break  # Exit the row loop
                        if extraction_successful:
                            break  # Exit the table loop
                    if extraction_successful:
                        break  # Exit the attempt loop
                if extraction_successful:
                    break  # Exit the page loop

    except Exception as e:
        print(f"Error processing Table 1 in {pdf_path}: {e}", file=log_file)
        print(traceback.format_exc(), file=log_file)
        return None

    if not extraction_successful:
        # After all attempts, determine the appropriate return value
        if point_of_interconnection is not None and point_of_interconnection != "":
            # Label was found but no value
            print("Point of Interconnection label found but no adjacent value.", file=log_file)
            return "Value Missing"
        else:
            # Label not found
            print("Point of Interconnection not found in Table 1.", file=log_file)
            return None

    return point_of_interconnection

def extract_base_data(pdf_path, project_id, log_file):
    """Extract base data from the PDF and return as a DataFrame."""
    print("Extracting base data from PDF...", file=log_file)
    try:
        with open(pdf_path, 'rb') as pdf_file:
            reader = PyPDF2.PdfReader(pdf_file)
            text = ""
            for page in reader.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text

        text = clean_string_cell(text)

        queue_id = re.search(r"q[\s_-]*(\d+)", text, re.IGNORECASE)
        queue_id = queue_id.group(1) if queue_id else str(project_id)  # Use project_id if queue_id is not found
        print(f"Extracted Queue ID: {queue_id}", file=log_file)

        # Updated Cluster Extraction
        clusters = re.findall(r"queue[\s_-]*cluster[\s_-]*(\d+)", text, re.IGNORECASE)
        if '12' in clusters:
            cluster_number = '12'
        elif clusters:
            cluster_number = max(clusters, key=lambda x: int(x))  # Choose the highest cluster number found
        else:
            cluster_number = '12'  # Default to 12 if not found
        print(f"Extracted Cluster Number: {cluster_number}", file=log_file)

        deliverability_status = re.search(r"(\w+)\s*capacity deliverability status", text, re.IGNORECASE)
        deliverability_status = deliverability_status.group(1) if deliverability_status else None
        print(f"Extracted Deliverability Status: {deliverability_status}", file=log_file)

        # Extract Capacity
        capacity = re.search(r"total rated output of (\d+)\s*mw", text, re.IGNORECASE)
        if capacity:
            capacity = int(capacity.group(1))
        else:
            capacity2 = re.search(r"(\d+)\s*mw", text)
            capacity = int(capacity2.group(1)) if capacity2 else None
        print(f"Extracted Capacity: {capacity}", file=log_file)

        # Extract Point of Interconnection
        point_of_interconnection = extract_table1(pdf_path, log_file)

        latitude, longitude = search_gps_coordinates(text, log_file)

        # Initialize base data dictionary
        base_data = {
            "q_id": [queue_id],
            "cluster": [cluster_number],
            "req_deliverability": [deliverability_status],
            "latitude": [latitude],
            "longitude": [longitude],
            "capacity": [capacity],
            "point_of_interconnection": [point_of_interconnection]
        }

        print("Base data extracted:", file=log_file)
        print(base_data, file=log_file)
        return pd.DataFrame(base_data)

    except Exception as e:
        print(f"Error extracting base data from {pdf_path}: {e}", file=log_file)
        print(traceback.format_exc(), file=log_file)
        return pd.DataFrame()  # Return empty DataFrame on error

def adjust_rows_length(data_rows, headers):
    """Ensure each row in data_rows matches the length of headers by truncating or padding."""
    col_count = len(headers)
    for i in range(len(data_rows)):
        row = data_rows[i]
        if len(row) > col_count:
            data_rows[i] = row[:col_count]
        elif len(row) < col_count:
            data_rows[i].extend([""]*(col_count - len(row)))

def extract_table7(pdf_path, log_file, is_addendum=False):
    """
    Extracts Table 7 data from the provided PDF.

    Args:
        pdf_path (str): Path to the PDF file.
        log_file (file object): Log file to write print statements.
        is_addendum (bool): Whether the PDF is an addendum.

    Returns:
        pd.DataFrame: Extracted Table 7 data.
    """
    print(f"\nProcessing {pdf_path} for Table 7 extraction...", file=log_file)
    extracted_tables = []
    specific_phrase = None

    try:
        with pdfplumber.open(pdf_path) as pdf:
            # Identify pages that contain "Table 7-1" to "Table 7-5" with hyphen or dot
            table7_pages = []
            for i, page in enumerate(pdf.pages):
                text = page.extract_text() or ""
                if  re.search(r"Table\s*7[-.]([1-5])\b", text, re.IGNORECASE): #re.search(r"(Modification\s+of\s+)?Table\s*7[-.]([1-5])\b", text, re.IGNORECASE):
                    table7_pages.append(i)


                     


            if not table7_pages:
                print("No Table 7-1 to 7-5 found in the PDF.", file=log_file)
                return pd.DataFrame()

            first_page = table7_pages[0]
            last_page = table7_pages[-1]
            scrape_start = first_page
            scrape_end = last_page + 2

            print(f"Table 7 starts on page {scrape_start + 1} and ends on page {scrape_end}", file=log_file)

            for page_number in range(scrape_start, min(scrape_end, len(pdf.pages))):
                page = pdf.pages[page_number]
                print(f"\nScraping tables on page {page_number + 1}...", file=log_file)
                tables = page.find_tables(table_settings={
                    "horizontal_strategy": "lines",
                    "vertical_strategy": "lines",
                })

                for table_index, table in enumerate(tables):
                    tab = table.extract()
                    if not tab:
                        print(f"Table {table_index + 1} on page {page_number + 1} is empty. Skipping.", file=log_file)
                        continue

                    table_bbox = table.bbox
                    title_bbox = (0, 0, page.width, table_bbox[1])
                    title_text = page.within_bbox(title_bbox).extract_text() or ""
                    table_title = None

                    if title_text:
                        title_lines = title_text.split('\n')[::-1]
                        for line in title_lines:
                            line = line.strip()
                            match = re.search(r"(Modification\s+of\s+)?Table\s*7[-.]([1-5])[:\-\s]*(.*)", line, re.IGNORECASE)
                            if match:
                                table_title = match.group(3).strip()
                                break

                    if table_title:
                        # New Table 7 detected
                        specific_phrase = extract_specific_phrase(table_title)
                        print(f"New Table 7 detected: '{specific_phrase}' on page {page_number + 1}, table {table_index + 1}", file=log_file)

                        headers = clean_column_headers(tab[0])
                        data_rows = tab[1:]

                        # Create DataFrame for new table
                        try:
                            df_new = pd.DataFrame(data_rows, columns=headers)
                        except ValueError as ve:
                            print(f"Error creating DataFrame for new table on page {page_number + 1}, table {table_index + 1}: {ve}", file=log_file)
                            continue

                        # Handle new ADNU tables (grouping logic)
                        if re.search(r"Area\s*Delivery\s*Network\s*Upgrade", specific_phrase, re.IGNORECASE):
                            print("Detected 'Area Delivery Network Upgrade' table (new).", file=log_file)
                            if "adnu" in df_new.columns:
                                if "type of upgrade" not in df_new.columns:
                                    # Group all adnu rows into one 'upgrade' row
                                    adnu_values = df_new["adnu"].dropna().astype(str).tolist()
                                    grouped_adnu = " ".join(adnu_values)
                                    other_columns = df_new.drop(columns=["adnu"]).iloc[0].to_dict()

                                    df_grouped = pd.DataFrame({
                                        "upgrade": [grouped_adnu],
                                        "type of upgrade": [specific_phrase]
                                    })

                                    for col, value in other_columns.items():
                                        df_grouped[col] = value

                                    print("Grouped all 'adnu' rows into a single 'upgrade' row for new ADNU table.", file=log_file)
                                    df_new = df_grouped
                                else:
                                    # If 'type of upgrade' exists, just rename adnu if needed
                                    if "upgrade" in df_new.columns:
                                        df_new.drop(columns=['adnu'], inplace=True)
                                        print("Dropped 'adnu' column to avoid duplicate 'upgrade'.", file=log_file)
                                    else:
                                        df_new.rename(columns={'adnu': 'upgrade'}, inplace=True)
                                        print("Renamed 'adnu' to 'upgrade' in new ADNU table.", file=log_file)
                            if "type of upgrade" not in df_new.columns:
                                df_new["type of upgrade"] = specific_phrase
                                print("Added 'type of upgrade' to all rows in new ADNU table.", file=log_file)
                            else:
                                # If 'type of upgrade' exists and first row none, original logic replaced only first row if needed
                                first_row = df_new.iloc[0]
                                if pd.isna(first_row["type of upgrade"]) or first_row["type of upgrade"] == "":
                                    df_new.at[0, "type of upgrade"] = specific_phrase
                                    print("Replaced None in 'type of upgrade' first row for new ADNU table.", file=log_file)
                        else:
                            # Non-ADNU new tables
                            if "type of upgrade" not in df_new.columns:
                                df_new["type of upgrade"] = specific_phrase
                                print("Added 'type of upgrade' to all rows in new non-ADNU table.", file=log_file)
                            else:
                                # If exist and none in first row original logic replaced only first row
                                first_row = df_new.iloc[0]
                                if pd.isna(first_row["type of upgrade"]) or first_row["type of upgrade"] == "":
                                    print("Replacing None in 'type of upgrade' for the first row in new non-ADNU table.", file=log_file)
                                    df_new.at[0, "type of upgrade"] = specific_phrase

                        if df_new.columns.duplicated().any():
                            print("Duplicate columns detected in new table. Dropping duplicates.", file=log_file)
                            df_new = df_new.loc[:, ~df_new.columns.duplicated()]

                        extracted_tables.append(df_new)
                    else:
                        # Continuation Table
                        if specific_phrase is None:
                            print(f"No previous Table 7 title found for continuation on page {page_number + 1}, table {table_index + 1}. Skipping.", file=log_file)
                            continue

                        print(f"Continuation Table detected on page {page_number + 1}, table {table_index + 1}", file=log_file)
                        data_rows = tab

                        # Check if the number of columns matches
                        expected_columns = len(extracted_tables[-1].columns) if extracted_tables else None
                        if expected_columns is None:
                            print(f"No existing table to continue with on page {page_number + 1}, table {table_index + 1}. Skipping.", file=log_file)
                            continue  # No table to continue with

                        # Define expected columns based on the last extracted table
                        expected_headers = extracted_tables[-1].columns.tolist()

                        # Detect header row in continuation
                        header_keywords = ["type of upgrade", "adnu", "MW at POI"]
                        first_continuation_row = data_rows[0] if data_rows else []
                        is_header_row = any(
                            re.search(rf"\b{kw}\b", str(cell), re.IGNORECASE) for kw in header_keywords for cell in first_continuation_row
                        )

                        if is_header_row:
                            print(f"Detected header row in continuation table on page {page_number + 1}, table {table_index + 1}.", file=log_file)
                            actual_header_row = data_rows[0]
                            actual_headers = clean_column_headers(actual_header_row)

                            # Go back to previous page bounding box to update table title if needed
                            if page_number > 0:
                                previous_page = pdf.pages[page_number - 1]
                                bbox_lower_region = (0, table_bbox[1], previous_page.width, previous_page.height)
                                title_text_previous = previous_page.within_bbox(bbox_lower_region).extract_text() or ""
                                new_table_title = None
                                if title_text_previous:
                                    title_lines_prev = title_text_previous.split('\n')[::-1]
                                    for line in title_lines_prev:
                                        line = line.strip()
                                        match_prev = re.search(r"(Modification\s+of\s+)?Table\s*7[-.]([1-5])[:\-\s]*(.*)", line, re.IGNORECASE)
                                        if match_prev:
                                            new_table_title = match_prev.group(3).strip()
                                            break
                                if new_table_title:
                                    specific_phrase = extract_specific_phrase(new_table_title)
                                    print(f"Updated table title from previous page: '{specific_phrase}' for continuation table on page {page_number + 1}, table {table_index + 1}", file=log_file)
                                else:
                                    print("No table title found in previous page region. Using existing specific_phrase.", file=log_file)
                            else:
                                print("No previous page available for title extraction for continuation table. Using existing specific_phrase.", file=log_file)

                            # Handle continuation ADNU or non-ADNU
                            if re.search(r"Area\s*Delivery\s*Network\s*Upgrades", specific_phrase, re.IGNORECASE):
                                print("Continuation ADNU table detected. No grouping, just rename and type of upgrade handling.", file=log_file)
                                if "type of upgrade" not in data_rows[0]:
                                    # Insert 'type of upgrade' column at the beginning
                                    print("Inserting 'type of upgrade' column with specific phrase in continuation table.", file=log_file)
                                    data_rows = [ [specific_phrase] + row for row in data_rows ]

                                    if "ADNU" in data_rows[0]:
                                        print("Handling continuation for 'Area Delivery Network Upgrade' table", file=log_file)
                                        print("Renaming 'ADNU' to 'upgrade' in continuation table.", file=log_file)
                                        # Find the index where "ADNU" occurs in the first row
                                        adnu_idx = data_rows[0].index("ADNU")
                                        # Replace "ADNU" with "upgrade" in that column for every row
                                        data_rows[0][adnu_idx] = "upgrade"
                            else:
                                # General Handling for other tables
                                if "type of upgrade" not in data_rows[0]:
                                    # Insert 'type of upgrade' column at the beginning
                                    print("Inserting 'type of upgrade' column with specific phrase in continuation table.", file=log_file)
                                    data_rows = [ [specific_phrase] + row for row in data_rows ]

                                    if "Type of Upgrade" in data_rows[0]:
                                        print("Handling continuation for non-ADNU table.", file=log_file)
                                        print("Renaming 'Type of Upgrade' to 'upgrade' in continuation table.", file=log_file)
                                        # Find the index where "Type of Upgrade" occurs in the first row
                                        upgrade_idx = data_rows[0].index("Type of Upgrade")
                                        # Replace "Type of Upgrade" with "upgrade" in that column for every row
                                        data_rows[0][upgrade_idx] = "upgrade"

                        # Handle missing or extra columns
                        if len(data_rows[0]) < expected_columns:
                            if re.search(r"Area\s*Delivery\s*Network\s*Upgrade", specific_phrase, re.IGNORECASE):
                                # For ADNU tables, assume missing "upgrade" column
                                print(f"Detected missing 'upgrade' column in continuation table on page {page_number + 1}, table {table_index + 1}. Inserting 'upgrade' column.", file=log_file)
                                data_rows = [row[:7] + [specific_phrase] + row[7:] for row in data_rows]

                            else:
                                # For other tables, assume missing "Type of Upgrade" column
                                print(f"Detected missing 'Type of Upgrade' column in continuation table on page {page_number + 1}, table {table_index + 1}. Inserting 'Type of Upgrade' column.", file=log_file)
                                data_rows = [[specific_phrase] + row for row in data_rows]
                        elif len(data_rows[0]) > expected_columns:
                            # Extra columns detected; adjust accordingly
                            print(f"Detected extra columns in continuation table on page {page_number + 1}, table {table_index + 1}. Dropping extra columns.", file=log_file)
                            data_rows = [row[:expected_columns] for row in data_rows]

                        # Create DataFrame for the continuation table
                        if is_header_row:
                            data_rows = data_rows[1:]
                            print(f"Dropped header row from data_rows after modifications for continuation table on page {page_number + 1}, table {table_index + 1}.", file=log_file)

                        try:
                            df_continuation = pd.DataFrame(data_rows, columns=expected_headers)
                        except ValueError as ve:
                            print(f"Error creating DataFrame for continuation table on page {page_number + 1}, table {table_index + 1}: {ve}", file=log_file)
                            continue  # Skip this table due to error

                        # Special Handling for "Area Delivery Network Upgrade" Tables in Continuation
                        if re.search(r"Area\s*Delivery\s*Network\s*Upgrades", specific_phrase, re.IGNORECASE):
                            if "type of upgrade" in df_continuation.columns:
                                first_row = df_continuation.iloc[0]
                                if pd.isna(first_row["type of upgrade"]) or first_row["type of upgrade"] == "":
                                    print(f"Replacing 'None' in 'type of upgrade' for the first data row of continuation on page {page_number + 1}, table {table_index + 1}", file=log_file)
                                    df_continuation.at[0, "type of upgrade"] = specific_phrase
                            else:
                                # If "type of upgrade" column does not exist, add it
                                df_continuation["type of upgrade"] = specific_phrase
                                print(f"'type of upgrade' column added with value '{specific_phrase}' for continuation on page {page_number + 1}, table {table_index + 1}", file=log_file)
                        else:
                            # General Handling for other tables
                            if "type of upgrade" in df_continuation.columns:
                                first_row = df_continuation.iloc[0]
                                if pd.isna(first_row["type of upgrade"]) or first_row["type of upgrade"] == "":
                                    print(f"Replacing 'None' in 'Type of Upgrade' for the first data row of continuation on page {page_number + 1}, table {table_index + 1}", file=log_file)
                                    df_continuation.at[0, "type of upgrade"] = specific_phrase
                            else:
                                # If "Type of Upgrade" column does not exist, add it
                                df_continuation["type of upgrade"] = specific_phrase
                                print(f"'Type of Upgrade' column added with value '{specific_phrase}' for continuation on page {page_number + 1}, table {table_index + 1}", file=log_file)

                        # Ensure no duplicate columns
                        if df_continuation.columns.duplicated().any():
                            print(f"Duplicate columns detected in continuation table on page {page_number + 1}, table {table_index + 1}. Dropping duplicates.", file=log_file)
                            df_continuation = df_continuation.loc[:, ~df_continuation.columns.duplicated()]

                        # Merge with the last extracted table
                        extracted_tables[-1] = pd.concat([extracted_tables[-1], df_continuation], ignore_index=True, sort=False)            

    except Exception as e:
        print(f"Error processing Table 7 in {pdf_path}: {e}", file=log_file)
        print(traceback.format_exc(), file=log_file)
        return pd.DataFrame()

    # After processing all tables, concatenate them
    if extracted_tables:
        all_columns = set()
        for df in extracted_tables:
            all_columns.update(df.columns.tolist())

        standardized_tables = []
        for df in extracted_tables:
            standardized_df = df.reindex(columns=all_columns)
            standardized_tables.append(standardized_df)

        print("\nConcatenating all extracted Table 7 data...", file=log_file)
        try:
            table7_data = pd.concat(standardized_tables, ignore_index=True, sort=False)
            print(f"Successfully concatenated {len(standardized_tables)} tables.", file=log_file)
        except Exception as e:
            print(f"Error concatenating tables: {e}", file=log_file)
            print(traceback.format_exc(), file=log_file)
            table7_data = pd.DataFrame()
    else:
        print("No Table 7 data extracted.", file=log_file)
        table7_data = pd.DataFrame()

    return table7_data

def scrape_alternative_tables(pdf_path, log_file, specific_phrases):
    """
    Scrapes all tables in the PDF that contain any of the specific phrases in their cells.

    Args:
        pdf_path (str): Path to the PDF file.
        log_file (file object): Log file to write print statements.
        specific_phrases (list): List of specific phrases to search for.

    Returns:
        pd.DataFrame: Extracted data from tables containing the specific phrases.
    """
    print(f"\nProcessing {pdf_path} for alternative table scraping...", file=log_file)
    extracted_tables = []

    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page_number, page in enumerate(pdf.pages, start=1):
                tables = page.find_tables(table_settings={
                    "horizontal_strategy": "lines",
                    "vertical_strategy": "lines",
                })
                for table_index, table in enumerate(tables, start=1):
                    tab = table.extract()
                    if not tab:
                        continue
                    # Check if any cell contains any of the specific phrases
                    match_found = False
                    for row in tab:
                        for cell in row:
                            if cell and any(re.search(rf"\b{re.escape(phrase)}\b", cell, re.IGNORECASE) for phrase in specific_phrases):
                                match_found = True
                                break
                        if match_found:
                            break
                    if match_found:
                        headers = clean_column_headers(tab[0])
                        headers = make_unique_headers(headers)  # Ensure headers are unique
                        data_rows = tab[1:]
                        try:
                            df = pd.DataFrame(data_rows, columns=headers)
                            extracted_tables.append(df)
                            print(f"Extracted alternative table from page {page_number}, table {table_index}.", file=log_file)
                        except ValueError as ve:
                            print(f"Error creating DataFrame for alternative table on page {page_number}, table {table_index}: {ve}", file=log_file)
                            continue

    except Exception as e:
        print(f"Error scraping alternative tables in {pdf_path}: {e}", file=log_file)
        print(traceback.format_exc(), file=log_file)
        return pd.DataFrame()

    if extracted_tables:
        all_columns = set()
        for df in extracted_tables:
            all_columns.update(df.columns.tolist())

        standardized_tables = []
        for df in extracted_tables:
            # Ensure columns are unique before reindexing
            standardized_df = df.reindex(columns=all_columns)
            standardized_tables.append(standardized_df)

        print("\nConcatenating all extracted alternative tables...", file=log_file)
        try:
            alternative_data = pd.concat(standardized_tables, ignore_index=True, sort=False)
            print(f"Successfully concatenated {len(standardized_tables)} alternative tables.", file=log_file)
            return alternative_data
        except Exception as e:
            print(f"Error concatenating alternative tables: {e}", file=log_file)
            print(traceback.format_exc(), file=log_file)
            return pd.DataFrame()
    else:
        print("No alternative tables found containing specific phrases.", file=log_file)
        return pd.DataFrame()


def extract_table7_and_replace_none(pdf_path, project_id, log_file, is_addendum=False):
    """Extracts Table 7 data and merges with base data."""
    base_data = extract_base_data(pdf_path, project_id, log_file)
    table7_data = extract_table7(pdf_path, log_file, is_addendum)

    if table7_data.empty:
        if is_addendum and original_has_table7.get(project_id, False):
            # Scrape alternative tables based on specific phrases
            specific_phrases = [
                "PTO",
                "Reliability Network Upgrade",
                "Area Delivery Network Upgrade",
                "Local Delivery Network",
                "Other Potential Network Upgrade",
                "Area Delivery Network Upgrades",
                "Conditionally Assigned Network Upgrades",
                "ADNU",
                "LDNU",
                "RNU"
            ]
            alternative_data = scrape_alternative_tables(pdf_path, log_file, specific_phrases)
            if not alternative_data.empty:
                table7_data = alternative_data
    if table7_data.empty:
        return base_data
    else:
        # Identify overlapping columns excluding 'point_of_interconnection'
        overlapping_columns = base_data.columns.intersection(table7_data.columns).difference(['point_of_interconnection'])
        table7_data = table7_data.drop(columns=overlapping_columns, errors='ignore')
        
        # Repeat base data for each row in table7_data
        base_data_repeated = pd.concat([base_data] * len(table7_data), ignore_index=True)
        
        try:
            # Concatenate base data with Table 7 data along columns
            merged_df = pd.concat([base_data_repeated, table7_data], axis=1, sort=False)
            
            # Ensure 'point_of_interconnection' is present and correctly populated
            if 'point_of_interconnection' not in merged_df.columns:
                merged_df['point_of_interconnection'] = base_data['point_of_interconnection'].iloc[0]
                print(f"Added 'point_of_interconnection' to merged data for {pdf_path}.", file=log_file)
            
            print(f"Merged base data with Table 7 data for {pdf_path}.", file=log_file)
            return merged_df
        except Exception as e:
            print(f"Error merging base data with Table 7 data for {pdf_path}: {e}", file=log_file)
            print(traceback.format_exc(), file=log_file)
            return base_data  # Fallback to base data only

def check_has_table7(pdf_path):
    """Checks if the PDF contains Table 7-1 to 7-5."""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                text = page.extract_text() or ""
                if re.search(r"(Modification\s+of\s+)?Table\s*7[-.]([1-5])\b", text, re.IGNORECASE):
                    return True
    except Exception as e:
        # Handle potential errors when opening PDF
        return False
    return False

def has_network_upgrade_type_column(pdf_path, log_file):
    """Checks if any table in the PDF has a column header 'Network Upgrade Type'."""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page_number, page in enumerate(pdf.pages, start=1):
                tables = page.find_tables()
                for table_index, table in enumerate(tables, start=1):
                    tab = table.extract()
                    if not tab:
                        continue
                    headers = clean_column_headers(tab[0])
                    if "network upgrade type" in headers:
                        print(f"Found 'Network Upgrade Type' in PDF {pdf_path} on page {page_number}, table {table_index}.", file=log_file)
                        return True
    except Exception as e:
        print(f"Error checking 'Network Upgrade Type' in {pdf_path}: {e}", file=log_file)
        print(traceback.format_exc(), file=log_file)
    return False

def is_addendum(pdf_path, log_file):
    """Checks if the PDF is an addendum by searching 'Addendum' or 'Revision' on the first page."""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            if len(pdf.pages) == 0:
                return False
            first_page = pdf.pages[0]
            text = first_page.extract_text() or ""
            print(f"Extracted Text: {text}", file= log_file)  # Debugging step
            # Case-insensitive check for 'Addendum' or 'Revision'
            text_lower = text.lower()
            return "addendum" in text_lower or "revision" in text_lower
    except Exception as e:
        # Handle potential errors when opening PDF
        return False



def make_unique_headers(headers):
    """
    Appends a suffix to duplicate headers to make them unique.

    Args:
        headers (list): List of column headers.

    Returns:
        list: List of unique column headers.
    """
    seen = {}
    unique_headers = []
    for header in headers:
        if header in seen:
            seen[header] += 1
            unique_headers.append(f"{header}_{seen[header]}")
        else:
            seen[header] = 1
            unique_headers.append(header)
    return unique_headers


def process_pdfs_in_folder():
    """Processes all PDFs in the specified project range and directory."""
    global core_originals, core_addendums, total_pdfs_accessed, total_pdfs_scraped, total_pdfs_skipped

    # Ensure the log file directory exists
    os.makedirs(os.path.dirname(LOG_FILE_PATH), exist_ok=True)

    with open(LOG_FILE_PATH, 'w') as log_file:
        for project_id in PROJECT_RANGE:
            project_path = os.path.join(BASE_DIRECTORY, str(project_id), "02_phase_1_study")
            if not os.path.exists(project_path):
                missing_projects.add(project_id)
                print(f"Project path does not exist: {project_path}", file=log_file)
                continue

            project_scraped = False  # Flag to track if any PDF in the project was scraped
            base_data_extracted = False
            base_data = pd.DataFrame()

            

            # **START OF CHANGES**
            # Separate PDFs into originals and addendums
            list_pdfs = [pdf for pdf in os.listdir(project_path) if pdf.endswith(".pdf")]
            originals = []
            addendums = []
            for pdf_name in list_pdfs:
                pdf_path = os.path.join(project_path, pdf_name)
                if is_addendum(pdf_path, log_file):
                    addendums.append(pdf_name)
                else:
                    originals.append(pdf_name)
            # **END OF CHANGES**

            # **START OF CHANGES**
            # Process original PDFs first
            for pdf_name in originals:
                
                pdf_path = os.path.join(project_path, pdf_name)
                total_pdfs_accessed += 1

                is_add = is_addendum(pdf_path, log_file)

                # Check if PDF has 'Network Upgrade Type' column
                if has_network_upgrade_type_column(pdf_path, log_file):
                    style_n_pdfs.append(pdf_name)
                    print(f"Skipping PDF: {pdf_name} from Project {project_id} (Style N)", file=log_file)
                    # Still check if original has table7
                    has_table7 = check_has_table7(pdf_path)
                    original_has_table7[project_id] = has_table7
                    continue  # Skip processing this PDF

                print(f"Accessing Original PDF: {pdf_name} from Project {project_id}", file=log_file)
                original_pdfs.append(pdf_name)

                try:
                    has_table7 = check_has_table7(pdf_path)
                    original_has_table7[project_id] = has_table7

                    if not has_table7:
                        skipped_pdfs.append(pdf_name)
                        print(f"Skipped PDF: {pdf_name} from Project {project_id} (No Table 7)", file=log_file)
                        print(f"Skipped PDF: {pdf_name} from Project {project_id} (No Table 7)")
                        total_pdfs_skipped += 1
                        continue

                    if not base_data_extracted:
                        # Extract base data from original PDF
                        base_data = extract_base_data(pdf_path, project_id, log_file)
                        base_data_extracted = True
                        print(f"Extracted base data from original PDF: {pdf_name}", file=log_file)

                    # Extract Table 7 and merge
                    df = extract_table7_and_replace_none(pdf_path, project_id, log_file, is_addendum=False)
                    if not df.empty:
                        core_originals = pd.concat([core_originals, df], ignore_index=True)
                        scraped_pdfs.append(pdf_name)
                        scraped_projects.add(project_id)
                        project_scraped = True
                        total_pdfs_scraped += 1
                        print(f"Scraped PDF: {pdf_name} from Project {project_id}")
                    else:
                        skipped_pdfs.append(pdf_name)
                        print(f"Skipped PDF: {pdf_name} from Project {project_id} (Empty Data)", file=log_file)
                        print(f"Skipped PDF: {pdf_name} from Project {project_id} (Empty Data)")
                        total_pdfs_skipped += 1

                except Exception as e:
                    skipped_pdfs.append(pdf_name)
                    print(f"Skipped PDF: {pdf_name} from Project {project_id} due to an error: {e}", file=log_file)
                    print(traceback.format_exc(), file=log_file)
                    print(f"Skipped PDF: {pdf_name} from Project {project_id} due to an error: {e}")
                    total_pdfs_skipped += 1
            # **END OF CHANGES**

            # **START OF CHANGES**
            # Then process addendum PDFs
            for pdf_name in addendums:
                pdf_path = os.path.join(project_path, pdf_name)
                total_pdfs_accessed += 1
                is_add = is_addendum(pdf_path, log_file)

                # Check if PDF has 'Network Upgrade Type' column
                if has_network_upgrade_type_column(pdf_path, log_file):
                    style_n_pdfs.append(pdf_name)
                    print(f"Skipping PDF: {pdf_name} from Project {project_id} (Style N)", file=log_file)
                    continue  # Skip processing this PDF

                print(f"Accessing Addendum PDF: {pdf_name} from Project {project_id}", file=log_file)
                addendum_pdfs.append(pdf_name)

                try:
                    has_table7 = check_has_table7(pdf_path)

                    if not has_table7:
                        if original_has_table7.get(project_id, False):
                            # Attempt to scrape alternative tables
                            table7_data = scrape_alternative_tables(pdf_path, log_file, [
                                "PTO",
                                "Reliability Network Upgrade",
                                "Area Delivery Network Upgrade",
                                "Local Delivery Network",
                                "Other Potential Network Upgrade",
                                "Area Delivery Network Upgrades",
                                "Conditionally Assigned Network Upgrades",
                                 
                            ])
                            if not table7_data.empty:
                                # Merge base data with Table 7 data
                                merged_df = pd.concat([base_data] * len(table7_data), ignore_index=True)
                                merged_df = pd.concat([merged_df, table7_data], axis=1, sort=False)
                                core_addendums = pd.concat([core_addendums, merged_df], ignore_index=True)
                                scraped_pdfs.append(pdf_name)
                                scraped_projects.add(project_id)
                                project_scraped = True
                                total_pdfs_scraped += 1
                                print(f"Scraped Addendum PDF: {pdf_name} from Project {project_id}")
                            else:
                                skipped_pdfs.append(pdf_name)
                                print(f"Skipped Addendum PDF: {pdf_name} from Project {project_id} (No relevant tables found)", file=log_file)
                                print(f"Skipped Addendum PDF: {pdf_name} from Project {project_id} (No relevant tables found)")
                                total_pdfs_skipped += 1
                        else:
                            skipped_pdfs.append(pdf_name)
                            print(f"Skipped Addendum PDF: {pdf_name} from Project {project_id} (No Table 7 and original does not have Table 7)", file=log_file)
                            print(f"Skipped Addendum PDF: {pdf_name} from Project {project_id} (No Table 7 and original does not have Table 7)")
                            total_pdfs_skipped += 1
                        continue

                    if not is_add and not base_data_extracted:
                        # Extract base data from original PDF
                        base_data = extract_base_data(pdf_path, project_id, log_file)
                        base_data_extracted = True
                        print(f"Extracted base data from original PDF: {pdf_name}", file=log_file)

                    if is_add and base_data_extracted:
                        # For addendums, use the extracted base data
                        table7_data = extract_table7(pdf_path, log_file, is_addendum=is_add)
                        if table7_data.empty and original_has_table7.get(project_id, False):
                            # Scrape alternative tables
                            table7_data = scrape_alternative_tables(pdf_path, log_file, [
                                "PTO",
                                "Reliability Network Upgrade",
                                "Area Delivery Network Upgrade",
                                "Local Delivery Network",
                                "Other Potential Network Upgrade",
                                "Area Delivery Network Upgrades",
                                "Conditionally Assigned Network Upgrades",
                                "ADNU",
                                "LDNU",
                                "RNU"
                            ])
                        if not table7_data.empty:
                            


                            
                            # Merge base data with Table 7 data
                            merged_df = pd.concat([base_data] * len(table7_data), ignore_index=True)
                            merged_df = pd.concat([merged_df, table7_data], axis=1, sort=False)
                            core_addendums = pd.concat([core_addendums, merged_df], ignore_index=True)
                            scraped_pdfs.append(pdf_name)
                            scraped_projects.add(project_id)
                            project_scraped = True
                            total_pdfs_scraped += 1
                            print(f"Scraped Addendum PDF: {pdf_name} from Project {project_id}")
                        else:
                            skipped_pdfs.append(pdf_name)
                            print(f"Skipped Addendum PDF: {pdf_name} from Project {project_id} (Empty Data)", file=log_file)
                            # Optionally, print to ipynb
                            print(f"Skipped Addendum PDF: {pdf_name} from Project {project_id} (Empty Data)")
                            total_pdfs_skipped += 1
                except Exception as e:
                    skipped_pdfs.append(pdf_name)
                    print(f"Skipped PDF: {pdf_name} from Project {project_id} due to an error: {e}", file=log_file)
                    print(traceback.format_exc(), file=log_file)
                    # Optionally, print to ipynb
                    print(f"Skipped PDF: {pdf_name} from Project {project_id} due to an error: {e}")
                    total_pdfs_skipped += 1
            # **END OF CHANGES**

            # After processing all PDFs for this project, check if any PDF was scraped
            if not project_scraped and os.path.exists(project_path):
                skipped_projects.add(project_id)

    # Rest of the code remains unchanged...


    # After processing all PDFs, save to CSV
    save_to_csv(core_originals, OUTPUT_CSV_PATH_ORIGINAL, "originals")
    save_to_csv(core_addendums, OUTPUT_CSV_PATH_ADDENDUM, "addendums")

    # Calculate total projects processed
    total_projects_processed = len(scraped_projects) + len(skipped_projects)

    # Print summary to ipynb
    print("\n=== Scraping Summary ===")
    print(f"Total Projects Processed: {total_projects_processed}")
    print(f"Total Projects Scraped: {len(scraped_projects)}")
    print(f"Total Projects Skipped: {len(skipped_projects)}")
    print(f"Total Projects Missing: {len(missing_projects)}")
    print(f"Total PDFs Accessed: {total_pdfs_accessed}")
    print(f"Total PDFs Scraped: {total_pdfs_scraped}")
    print(f"Total PDFs Skipped: {total_pdfs_skipped}")

    print("\nList of Scraped Projects:")
    print(sorted(scraped_projects))

    print("\nList of Skipped Projects:")
    print(sorted(skipped_projects))

    print("\nList of Missing Projects:")
    print(sorted(missing_projects))

    print("\nList of Scraped PDFs:")
    print(scraped_pdfs)

    print("\nList of Skipped PDFs:")
    print(skipped_pdfs)

    print("\nList of Addendum PDFs:")
    print(addendum_pdfs)

    print("\nList of Original PDFs:")
    print(original_pdfs)

    print("\nList of Style N PDFs (Skipped due to 'Network Upgrade Type'):")
    print(style_n_pdfs)

    print("\nTotal Number of Style N PDFs:", len(style_n_pdfs))

    print("\nNumber of Original PDFs Scraped:", len([pdf for pdf in scraped_pdfs if pdf in original_pdfs]))
    print("Number of Addendum PDFs Scraped:", len([pdf for pdf in scraped_pdfs if pdf in addendum_pdfs]))

def save_to_csv(df, output_csv_path, data_type):
    """Cleans the DataFrame and saves it to a CSV file."""
    if df.empty:
        print(f"No data to save for {data_type}.")
        return

    # Clean up the entire DataFrame by cleaning string cells
    df = df.applymap(clean_string_cell)

    # Drop rows that contain specific phrases (e.g., "Type of Upgrade")
    df = df[~df.apply(lambda row: contains_phrase(row, "Type of Upgrade"), axis=1)]

    # Reorder columns as specified
    df = reorder_columns(df)
    print(f"\nColumns reordered for {data_type} as per specification.")

    # Ensure q_id is numeric for sorting, replace missing values with None
    if 'q_id' in df.columns:
        df['q_id'] = pd.to_numeric(df['q_id'], errors='coerce')

    # Save the DataFrame to CSV
    try:
        df.to_csv(output_csv_path, index=False)
        print(f"\nData successfully saved to {output_csv_path}")
    except Exception as e:
        print(f"Error saving {data_type} data to CSV: {e}")
        print(traceback.format_exc())

def main():
    """Main function to execute the PDF scraping process."""
    process_pdfs_in_folder()

if __name__ == "__main__":
    main()
# Out:
# Scraped PDF: Q1541-Bright Star Hybrid-Appendix_A-C12PhI.pdf from Project 1541
# Scraped PDF: Q1542-Capetown 2 Hybrid-Appendix_A-C12PhI.pdf from Project 1542
# Scraped Addendum PDF: Q1542-Capetown 2 Hybrid-Appendix_A-C12PhI-Revision1.pdf from Project 1542
# Scraped PDF: Q1543-Beauchamp 2 Solar-Appendix_A-C12PhI.pdf from Project 1543
# Scraped Addendum PDF: Q1543-Beauchamp 2 Solar-Appendix_A-C12PhI-Addendum1.pdf from Project 1543
# Scraped PDF: Q1546-Tatton Storage 1-Appendix_A-C12PhI.pdf from Project 1546
# Scraped Addendum PDF: Q1546-Tatton Storage 1-Appendix_A-C12PhI-Addendum1.pdf from Project 1546
# Scraped PDF: Q1548-Loriner Storage-Appendix_A-C12PhI.pdf from Project 1548
# Scraped PDF: Q1549-Miranda ESS-Appendix_A-C12PhI.pdf from Project 1549
# Scraped Addendum PDF: Q1549-Miranda ESS-Appendix_A-C12PhI-Revision1.pdf from Project 1549
# Scraped Addendum PDF: Q1549-Miranda ESS-Appendix_A-C12PhI-Addendum1.pdf from Project 1549
# Scraped PDF: Q1550-Tanager Storage-Appendix_A-C12PhI.pdf from Project 1550
# Scraped Addendum PDF: Q1550Tanager_Storage_Appendix_A_Addendum3.pdf from Project 1550
# Scraped Addendum PDF: Q1550-Tanager Storage-Appendix_A-C12PhI-Addendum1.pdf from Project 1550
# Scraped PDF: Q1552-Cormorant Storage-Appendix_A-C12PhI.pdf from Project 1552
# Scraped Addendum PDF: Q1552-Cormorant Storage-Appendix_A-C12PhI-Addendum1.pdf from Project 1552
# Scraped PDF: Q1553-Jewelflower Storage-Appendix_A-C12PhI.pdf from Project 1553
# Scraped PDF: Q1554-Herculis-Appendix_A-C12PhI.pdf from Project 1554
# Scraped Addendum PDF: Q1554-Herculis-Appendix_A-C12PhI-Revision1.pdf from Project 1554
# Scraped PDF: Q1555-Steel City Energy Storage-Appendix_A-C12PhI.pdf from Project 1555
# Scraped Addendum PDF: Q1555-Steel City Energy Storage-Appendix_A-C12PhI-Revision1.pdf from Project 1555
# Scraped PDF: Q1557-Noosa Energy Storage-Appendix_A-C12PhI.pdf from Project 1557
# Scraped PDF: Q1558-Hydaspes-Appendix_A-C12PhI.pdf from Project 1558
# Scraped PDF: Q1559-Tempest Generation-Appendix_A-C12PhI.pdf from Project 1559
# Scraped PDF: Q1561-Tesoster-Appendix_A-C12PhI.pdf from Project 1561
# Scraped PDF: Q1564-Trim BESS-Appendix_A-C12PhI.pdf from Project 1564
# Scraped Addendum PDF: Q1564-Trim BESS-Appendix_A-C12PhI-Addendum1.pdf from Project 1564
# Scraped PDF: Q1565-Dynamo Solar-Appendix_A-C12PhI.pdf from Project 1565
# Scraped Addendum PDF: Q1565-Dynamo Solar-Appendix_A-C12PhI-Addendum1.pdf from Project 1565
# Scraped PDF: Q1566-Tyre-Appendix_A-C12PhI.pdf from Project 1566
# Scraped PDF: Q1568-Air Station 1-Appendix_A-C12PhI.pdf from Project 1568
# Scraped Addendum PDF: Q1568-Air Station 1-Appendix_A-C12PhI-Addendum1.pdf from Project 1568
# Scraped PDF: Q1573-Boyce Solar Hybrid-Appendix_A-C12PhI.pdf from Project 1573
# Scraped PDF: Q1574-Big Duck Storage-Appendix_A-C12PhI.pdf from Project 1574
# Scraped Addendum PDF: Q1574-Big Duck Storage-Appendix_A-C12PhI-Addendum1.pdf from Project 1574
# Scraped PDF: Q1578-Journey Storage-Appendix_A-C12PhI.pdf from Project 1578
# Scraped Addendum PDF: Q1578-Journey Storage-Appendix_A-C12PhI-Addendum1.pdf from Project 1578
# Scraped PDF: Q1581-Pinebrook Solar Hybrid Energy Center-Appendix_A-C12PhI.pdf from Project 1581
# Scraped PDF: Q1582-Sugarloaf Hybrid Solar-Appendix_A-C12PhI.pdf from Project 1582
# Scraped Addendum PDF: Q1582-Sugarloaf Hybrid Solar-Appendix_A-C12PhI-Revision1.pdf from Project 1582
# Scraped Addendum PDF: Q1582-Sugarloaf Hybrid Solar-Appendix_A-C12PhI-Revision2.pdf from Project 1582
# Scraped PDF: Q1584-Riviera Solar-Appendix_A-C12PhI.pdf from Project 1584
# Scraped Addendum PDF: Q1584-Riviera Solar-Appendix_A-C12PhI-Addendum1.pdf from Project 1584
# Scraped PDF: Q1586-Arcturus-Appendix_A-C12PhI.pdf from Project 1586
# Scraped Addendum PDF: Q1586Arcturus_Appendix_A_Addendum3.pdf from Project 1586
# Scraped Addendum PDF: Q1586-Arcturus-Appendix_A-C12PhI-Addendum1.pdf from Project 1586
# Scraped PDF: Q1587-Kingsroad Hybrid Solar-Appendix_A-C12PhI.pdf from Project 1587
# Scraped Addendum PDF: Q1587-Kingsroad Hybrid Solar-Appendix_A-C12PhI-Addendum1.pdf from Project 1587
# Scraped PDF: Q1590-Nimitz 2 Generation-Appendix_A-C12PhI.pdf from Project 1590
# Scraped PDF: Q1591-Carthage-Appendix_A-C12PhI.pdf from Project 1591
# Scraped Addendum PDF: Q1591-Carthage-Appendix_A-C12PhI-Addendum1.pdf from Project 1591
# Scraped PDF: Q1592-Oatfield Hybrid Solar-Appendix_A-C12PhI.pdf from Project 1592
# Scraped Addendum PDF: Q1592-Oatfield Hybrid Solar-Appendix_A-C12PhI-Addendum1.pdf from Project 1592
# Scraped PDF: Q1593-Pelicans Jaw Hybrid Solar-Appendix_A-C12PhI.pdf from Project 1593
# Scraped Addendum PDF: Q1593-Pelicans Jaw Hybrid Solar-Appendix_A-C12PhI-Revision1.pdf from Project 1593
# Scraped PDF: Q1594-Grand Lake Hybrid Solar-Appendix_A-C12PhI.pdf from Project 1594
# Scraped Addendum PDF: Q1594-Grand Lake Hybrid Solar-Appendix_A-C12PhI-Revision1.pdf from Project 1594
# Scraped PDF: Q1595-Oso Rojo Peony-Appendix_A-C12PhI.pdf from Project 1595
# Scraped Addendum PDF: Q1595-Oso Rojo Peony-Appendix_A-C12PhI-Addendum1.pdf from Project 1595
# Scraped PDF: Q1596-Buttonbush Solar Hybrid Energy Center-Appendix_A-C12PhI.pdf from Project 1596
# Scraped Addendum PDF: Q1596-Buttonbush Solar Hybrid Energy Center-Appendix_A-C12PhI-Addendum1.pdf from Project 1596
# Scraped Addendum PDF: Q1596_ButtonbushSolarHybridEnergyCenter_Appendix_A_Addendum5.pdf from Project 1596
# Scraped PDF: Q1597-Oso Rojo Golf Course-Appendix_A-C12PhI.pdf from Project 1597
# Scraped PDF: Q1598-Agua Amarga Wind-Appendix_A-C12PhI.pdf from Project 1598
# Scraped Addendum PDF: Q1598-Agua Amarga Wind-Appendix_A-C12PhI-Addendum1.pdf from Project 1598
# Scraped PDF: Q1599-Lion Rock Offshore Wind-Appendix_A-C12PhI.pdf from Project 1599
# Scraped Addendum PDF: Q1599-Lion Rock Offshore Wind-Appendix_A-C12PhI-Addendum1.pdf from Project 1599
# Scraped PDF: Q1600-Seawolf Generation-Appendix_A-C12PhI.pdf from Project 1600
# Scraped PDF: Q1601-Familia Hybrid Solar-Appendix_A-C12PhI.pdf from Project 1601
# Scraped Addendum PDF: Q1601-Familia Hybrid Solar-Appendix_A-C12PhI-Addendum1.pdf from Project 1601
# Skipped PDF: QC12PI-SCE-NOL-Q1603-TOT936-Rigal-AppendixA-Attachment_1.pdf from Project 1603 (No Table 7)
# Skipped PDF: QC12PI-SCE-NOL-Q1603-TOT936-Rigal-AppendixA-Attachment_2.pdf from Project 1603 (No Table 7)
# Skipped PDF: QC12PI-SCE-NOL-Q1603-TOT936-Rigal-AppendixA.pdf from Project 1603 (No Table 7)
# Skipped PDF: QC12PI-SCE-NOL-Q1604-TOT904-Aratina-AppendixA.pdf from Project 1604 (No Table 7)
# Skipped PDF: QC12PI-SCE-NOL-Q1604-TOT904-Aratina-AppendixA-Attachment_1.pdf from Project 1604 (No Table 7)
# Skipped PDF: QC12PI-SCE-NOL-Q1604-TOT904-Aratina-AppendixA-Attachment_2.pdf from Project 1604 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1605-TOT960-Cayenne-Appendix A.pdf from Project 1605 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1605-TOT960-Cayenne-Appendix A-Attachment 2.pdf from Project 1605 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1605-TOT960-Cayenne-Appendix A-Attachment 1.pdf from Project 1605 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1608-TOT906-Avocet-Appendix A-Attachment 2.pdf from Project 1608 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1608-TOT906-Avocet-Appendix A-Attachment 1.pdf from Project 1608 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1608-TOT906-Avocet-Appendix A.pdf from Project 1608 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1609-TOT939-Hinson-Appendix A-Attachment 2.pdf from Project 1609 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1609-TOT939-Hinson-Appendix A-Attachment 1.pdf from Project 1609 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1609-TOT939-Hinson-Appendix A.pdf from Project 1609 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1610-TOT955-Superba-Appendix A.pdf from Project 1610 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1610-TOT955-Superba-Appendix A-Attachment 2.pdf from Project 1610 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1610-TOT955-Superba-Appendix A-Attachment 1.pdf from Project 1610 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1611-TOT927-Commerce-Appendix A-Attachment 2.pdf from Project 1611 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1611-TOT927-Commerce-Appendix A-Attachment 1.pdf from Project 1611 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1611-TOT927-Commerce-Appendix A.pdf from Project 1611 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1612-TOT920-Speedway-Appendix A-Attachment 2.pdf from Project 1612 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1612-TOT920-Speedway-Appendix A-Attachment 1.pdf from Project 1612 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1612-TOT920-Speedway-Appendix A.pdf from Project 1612 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1613-TOT957-Trestles-Appendix A-Attachment 1.pdf from Project 1613 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1613-TOT957-Trestles-Appendix A-Attachment 2.pdf from Project 1613 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1613-TOT957-Trestles-Appendix A.pdf from Project 1613 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1615-TOT907-Kestrel-Appendix A.pdf from Project 1615 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1615-TOT907-Kestrel-Appendix A-Attachment 1-reissue.pdf from Project 1615 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1615-TOT907-Kestrel-Appendix A-Attachment 1.pdf from Project 1615 (No Table 7)
# Skipped PDF: C12PI-Metro-Q1615-TOT907-Kestrel-Appendix A-Attachment 2.pdf from Project 1615 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1616-TOT948-Highwind-Appendix A.pdf from Project 1616 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1616-TOT948-Highwind-Appendix A-Attachment 2.pdf from Project 1616 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1616-TOT948-Highwind-Appendix A-Attachment 1.pdf from Project 1616 (No Table 7)
# Skipped PDF: QC12PI-SCE-NOL-Q1617-TOT914-SEGS_Expansion-AppendixA-Attachment_1.pdf from Project 1617 (No Table 7)
# Skipped PDF: QC12PI-SCE-NOL-Q1617-TOT914-SEGS_Expansion-AppendixA-Attachment_2.pdf from Project 1617 (No Table 7)
# Skipped PDF: QC12PI-SCE-NOL-Q1617-TOT914-SEGS_Expansion-AppendixA.pdf from Project 1617 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1618-TOT911-Doradus-Appendix A-Attachment 2.pdf from Project 1618 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1618-TOT911-Doradus-Appendix A-Attachment 1.pdf from Project 1618 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1618-TOT911-Doradus-Appendix A.pdf from Project 1618 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1619-TOT943-Goldback-Appendix A-Attachment 1.pdf from Project 1619 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1619-TOT943-Goldback-Appendix A-Attachment 2.pdf from Project 1619 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1619-TOT943-Goldback-Appendix A.pdf from Project 1619 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1620-TOT924-Rocky_Hill-Appendix A-Attachment 2.pdf from Project 1620 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1620-TOT924-Rocky_Hill-Appendix A-Attachment 1.pdf from Project 1620 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1620-TOT924-Rocky_Hill-Appendix A.pdf from Project 1620 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1621-TOT932-Yellow_Hay-Appendix A.pdf from Project 1621 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1621-TOT932-Yellow_Hay-Appendix A-Attachment 1.pdf from Project 1621 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1621-TOT932-Yellow_Hay-Appendix A-Attachment 2.pdf from Project 1621 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1622-TOT952-Barrenspring-Appendix A.pdf from Project 1622 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1622-TOT952-Barrenspring-Appendix A-Attachment 2.pdf from Project 1622 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1622-TOT952-Barrenspring-Appendix A-Attachment 1.pdf from Project 1622 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1625-TOT903-Angeleno-Appendix A-Attachment 2.pdf from Project 1625 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1625-TOT903-Angeleno-Appendix A-Attachment 1.pdf from Project 1625 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1625-TOT903-Angeleno-Appendix A.pdf from Project 1625 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1626-TOT916-Sagebrush6-Appendix A-Attachment 1.pdf from Project 1626 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1626-TOT916-Sagebrush6-Appendix A-Attachment 2.pdf from Project 1626 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1626-TOT916-Sagebrush6-Appendix A.pdf from Project 1626 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1628-TOT937-Fort_Tejon-Appendix A.pdf from Project 1628 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1628-TOT937-Fort_Tejon-Appendix A-Attachment 2.pdf from Project 1628 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1628-TOT937-Fort_Tejon-Appendix A-Attachment 1.pdf from Project 1628 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1629-TOT959-Humidor1-Appendix A.pdf from Project 1629 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1629-TOT959-Humidor1-Appendix A-Attachment 2.pdf from Project 1629 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1629-TOT959-Humidor1-Appendix A-Attachment 1.pdf from Project 1629 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1631-TOT909-GlenFeliz-Appendix A.pdf from Project 1631 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1631-TOT909-GlenFeliz-Appendix A-Attachment 2.pdf from Project 1631 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1631-TOT909-GlenFeliz-Appendix A-Attachment 1.pdf from Project 1631 (No Table 7)
# Skipped Addendum PDF: QC12PI-SCE-Northern-Q1631-TOT909-GlenFeliz-Appendix A-Revison.pdf from Project 1631 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-SCE-Northern-Q1631-TOT909-GlenFeliz-Appendix A-Attachment 2-Revison.pdf from Project 1631 (No Table 7 and original does not have Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1632-TOT915-Sanborn3-Appendix A.pdf from Project 1632 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1632-TOT915-Sanborn3-Appendix A-Attachment 1.pdf from Project 1632 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1632-TOT915-Sanborn3-Appendix A-Attachment 2.pdf from Project 1632 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1635-TOT956-Yeager-Appendix A.pdf from Project 1635 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1635-TOT956-Yeager-Appendix A-Attachment 2.pdf from Project 1635 (No Table 7)
# Skipped PDF: QC12PI-SCE-Northern-Q1635-TOT956-Yeager-Appendix A-Attachment 1.pdf from Project 1635 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment 2 Q1636-TOT923.pdf from Project 1636 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Q1636-TOT923-Calypso.pdf from Project 1636 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment1-TOT923 Q1636.pdf from Project 1636 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment 2 Q1637-TOT918.pdf from Project 1637 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Q1637-TOT918-Solo.pdf from Project 1637 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment1-TOT918 Q1637.pdf from Project 1637 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Q1640-TOT944-Sunnynook.pdf from Project 1640 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment 2 Q1640-TOT944 SCE build.pdf from Project 1640 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment 2 Q1640-TOT944 IC build.pdf from Project 1640 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment1-TOT944 Q1640 SCE BUILD.pdf from Project 1640 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment1-TOT944 Q1640 IC BUILD.pdf from Project 1640 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment1-TOT913 Q1641.pdf from Project 1641 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Q1641-TOT913-Rampa.pdf from Project 1641 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment 2 Q1641-TOT913.pdf from Project 1641 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment 2 Q1642-TOT910.pdf from Project 1642 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Q1642-TOT910-Oberon.pdf from Project 1642 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment1-TOT910 Q1642.pdf from Project 1642 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Q1643-TOT921-Lycan.pdf from Project 1643 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment 2 Q1643-TOT921.pdf from Project 1643 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment1-TOT921 Q1643.pdf from Project 1643 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Q1644-TOT938-San_Bernardino.pdf from Project 1644 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment1-TOT938 Q1644.pdf from Project 1644 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment 2 Q1644-TOT938.pdf from Project 1644 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment1-TOT934 Q1645.pdf from Project 1645 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Q1645-TOT934-Nova.pdf from Project 1645 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment 2 Q1645-TOT934.pdf from Project 1645 (No Table 7)
# Skipped Addendum PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Addendum-Q1645-TOT934-Nova.pdf from Project 1645 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Addendum-Attachment1-TOT934 Q1645.pdf from Project 1645 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Addendum-Attachment 2 Q1645-TOT934.pdf from Project 1645 (No Table 7 and original does not have Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Q1646-TOT935-Double_Butte.pdf from Project 1646 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment1-TOT935 Q1646.pdf from Project 1646 (No Table 7)
# Skipped PDF: QC12PI-SCE-Eastern-Area Report-Appendix A-Attachment 2 Q1646-TOT935.pdf from Project 1646 (No Table 7)
# Skipped Addendum PDF: QC12PI-SCE-EOP-Q1647-TOT905-Angora-ApendixA-Attachment2-Revision-01.pdf from Project 1647 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-SCE-EOP-Q1647-TOT905-Angora-ApendixA-Revision-01.pdf from Project 1647 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-SCE-EOP-Q1647-TOT905-Angora-ApendixA-Attachment1-Revision-01.pdf from Project 1647 (No Table 7 and original does not have Table 7)
# Skipped PDF: QC12PI-SCE-EOP-Q1648-TOT930-Bullhead-AppendixA.pdf from Project 1648 (No Table 7)
# Skipped PDF: QC12PI-SCE-EOP-Q1648-TOT930-Bullhead-AppendixA-Attachment2.pdf from Project 1648 (No Table 7)
# Skipped PDF: QC12PI-SCE-EOP-Q1648-TOT930-Bullhead-AppendixA-Attachment1.pdf from Project 1648 (No Table 7)
# Skipped PDF: QC12PI-GLW-Q1649-Appendix A-GLW-Attachment2.pdf from Project 1649 (No Table 7)
# Skipped PDF: QC12PI-GLW-Q1649-AppendixA-SCE-Attachment2.pdf from Project 1649 (No Table 7)
# Skipped PDF: QC12P1-GLW-Q1649-AppendixA.pdf from Project 1649 (No Table 7)
# Skipped PDF: QC12PI-GLW-Q1649-AppendixA-Attachment1.pdf from Project 1649 (No Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1649-AppendixA-Attachment1-addendum01.pdf from Project 1649 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1649-AppendixA-GLW-Attachment2-Addendum01.pdf from Project 1649 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1649-AppendixA-SCE-Attachment2-Addendum01.pdf from Project 1649 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1649-AppendixA-Addendum01.pdf from Project 1649 (No Table 7 and original does not have Table 7)
# Skipped PDF: QC12PI-GLW-Q1650-Appendix A-GLW-Attachment2.pdf from Project 1650 (No Table 7)
# Skipped PDF: QC12PI-GLW-Q1650-AppendixA.pdf from Project 1650 (No Table 7)
# Skipped PDF: QC12PI-GLW-Q1650-AppendixA-Attachment1.pdf from Project 1650 (No Table 7)
# Skipped PDF: QC12PI-GLW-Q1650-AppendixA-SCE-Attachment2.pdf from Project 1650 (No Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1650-AppendixA-SCE-Attachment2-Addendum01.pdf from Project 1650 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1650-AppendixA-Addendum01.pdf from Project 1650 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1650-AppendixA-Attachment1-Addendum01.pdf from Project 1650 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1650-AppendixA-GLW-Attachment2-Addendum01.pdf from Project 1650 (No Table 7 and original does not have Table 7)
# Skipped PDF: QC12P1-GLW-Q1653-AppendixA-SCE-Attachment2.pdf from Project 1653 (No Table 7)
# Skipped PDF: QC12P1-GLW-Q1653-AppendixA.pdf from Project 1653 (No Table 7)
# Skipped PDF: QC12P1-GLW-Q1653-AppendixA-GLW-Attachment2.pdf from Project 1653 (No Table 7)
# Skipped PDF: QC12P1-GLW-Q1653-AppendixA-Attachment1.pdf from Project 1653 (No Table 7)
# Skipped PDF: QC12PI-GLW-Q1654-AppendixA-GLW-Attachment2.pdf from Project 1654 (No Table 7)
# Skipped PDF: QC12PI-GLW-Q1654-AppendixA.pdf from Project 1654 (No Table 7)
# Skipped PDF: QC12PI-GLW-Q1654-AppendixA-SCE-Attachment2.pdf from Project 1654 (No Table 7)
# Skipped PDF: QC12PI-GLW-Q1654-AppendixA-Attachment1.pdf from Project 1654 (No Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1654-AppendixA-SCE-Attachment2-Addendum01.pdf from Project 1654 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1654-AppendixA-Addendum01.pdf from Project 1654 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1654-AppendixA-Attachment1-Addendum01.pdf from Project 1654 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1654-AppendixA-GLW-Attachment2-Addendum01.pdf from Project 1654 (No Table 7 and original does not have Table 7)
# Skipped PDF: QC12PI-GLW-Q1655-AppendixA-Attachment1.pdf from Project 1655 (No Table 7)
# Skipped PDF: QC12PI-GLW-Q1655-AppendixA-GLW-Attachment2.pdf from Project 1655 (No Table 7)
# Skipped PDF: QC12PI-GLW-Q1655-AppendixA.pdf from Project 1655 (No Table 7)
# Skipped PDF: QC12PI-GLW-Q1655-AppendixA-SCE-Attachment2.pdf from Project 1655 (No Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1655-AppendixA-Addendum01.pdf from Project 1655 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1655-AppendixA-GLW-Attachment2-Addendum01.pdf from Project 1655 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1655-AppendixA-Attachment1-Addendum01.pdf from Project 1655 (No Table 7 and original does not have Table 7)
# Skipped Addendum PDF: QC12PI-GLW-Q1655-AppendixA-SCE-Attachment2-Addendum01.pdf from Project 1655 (No Table 7 and original does not have Table 7)
#
# Columns reordered for originals as per specification.
#
# Data successfully saved to /Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/output/Cluster 12/03_raw/rawdata_cluster12_style_G_originals.csv
#
# Columns reordered for addendums as per specification.
#
# Data successfully saved to /Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/output/Cluster 12/03_raw/rawdata_cluster12_style_G_addendums.csv
#
# === Scraping Summary ===
# Total Projects Processed: 98
# Total Projects Scraped: 39
# Total Projects Skipped: 59
# Total Projects Missing: 37
# Total PDFs Accessed: 236
# Total PDFs Scraped: 70
# Total PDFs Skipped: 149
#
# List of Scraped Projects:
# [1541, 1542, 1543, 1546, 1548, 1549, 1550, 1552, 1553, 1554, 1555, 1557, 1558, 1559, 1561, 1564, 1565, 1566, 1568, 1573, 1574, 1578, 1581, 1582, 1584, 1586, 1587, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598, 1599, 1600, 1601]
#
# List of Skipped Projects:
# [1556, 1603, 1604, 1605, 1608, 1609, 1610, 1611, 1612, 1613, 1615, 1616, 1617, 1618, 1619, 1620, 1621, 1622, 1625, 1626, 1628, 1629, 1631, 1632, 1635, 1636, 1637, 1640, 1641, 1642, 1643, 1644, 1645, 1646, 1647, 1648, 1649, 1650, 1653, 1654, 1655, 1656, 1657, 1658, 1661, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675]
#
# List of Missing Projects:
# [1544, 1545, 1547, 1551, 1560, 1562, 1563, 1567, 1569, 1570, 1571, 1572, 1575, 1576, 1577, 1579, 1580, 1583, 1585, 1588, 1589, 1602, 1606, 1607, 1614, 1623, 1624, 1627, 1630, 1633, 1634, 1638, 1639, 1651, 1652, 1659, 1660]
#
# List of Scraped PDFs:
# ['Q1541-Bright Star Hybrid-Appendix_A-C12PhI.pdf', 'Q1542-Capetown 2 Hybrid-Appendix_A-C12PhI.pdf', 'Q1542-Capetown 2 Hybrid-Appendix_A-C12PhI-Revision1.pdf', 'Q1543-Beauchamp 2 Solar-Appendix_A-C12PhI.pdf', 'Q1543-Beauchamp 2 Solar-Appendix_A-C12PhI-Addendum1.pdf', 'Q1546-Tatton Storage 1-Appendix_A-C12PhI.pdf', 'Q1546-Tatton Storage 1-Appendix_A-C12PhI-Addendum1.pdf', 'Q1548-Loriner Storage-Appendix_A-C12PhI.pdf', 'Q1549-Miranda ESS-Appendix_A-C12PhI.pdf', 'Q1549-Miranda ESS-Appendix_A-C12PhI-Revision1.pdf', 'Q1549-Miranda ESS-Appendix_A-C12PhI-Addendum1.pdf', 'Q1550-Tanager Storage-Appendix_A-C12PhI.pdf', 'Q1550Tanager_Storage_Appendix_A_Addendum3.pdf', 'Q1550-Tanager Storage-Appendix_A-C12PhI-Addendum1.pdf', 'Q1552-Cormorant Storage-Appendix_A-C12PhI.pdf', 'Q1552-Cormorant Storage-Appendix_A-C12PhI-Addendum1.pdf', 'Q1553-Jewelflower Storage-Appendix_A-C12PhI.pdf', 'Q1554-Herculis-Appendix_A-C12PhI.pdf', 'Q1554-Herculis-Appendix_A-C12PhI-Revision1.pdf', 'Q1555-Steel City Energy Storage-Appendix_A-C12PhI.pdf', 'Q1555-Steel City Energy Storage-Appendix_A-C12PhI-Revision1.pdf', 'Q1557-Noosa Energy Storage-Appendix_A-C12PhI.pdf', 'Q1558-Hydaspes-Appendix_A-C12PhI.pdf', 'Q1559-Tempest Generation-Appendix_A-C12PhI.pdf', 'Q1561-Tesoster-Appendix_A-C12PhI.pdf', 'Q1564-Trim BESS-Appendix_A-C12PhI.pdf', 'Q1564-Trim BESS-Appendix_A-C12PhI-Addendum1.pdf', 'Q1565-Dynamo Solar-Appendix_A-C12PhI.pdf', 'Q1565-Dynamo Solar-Appendix_A-C12PhI-Addendum1.pdf', 'Q1566-Tyre-Appendix_A-C12PhI.pdf', 'Q1568-Air Station 1-Appendix_A-C12PhI.pdf', 'Q1568-Air Station 1-Appendix_A-C12PhI-Addendum1.pdf', 'Q1573-Boyce Solar Hybrid-Appendix_A-C12PhI.pdf', 'Q1574-Big Duck Storage-Appendix_A-C12PhI.pdf', 'Q1574-Big Duck Storage-Appendix_A-C12PhI-Addendum1.pdf', 'Q1578-Journey Storage-Appendix_A-C12PhI.pdf', 'Q1578-Journey Storage-Appendix_A-C12PhI-Addendum1.pdf', 'Q1581-Pinebrook Solar Hybrid Energy Center-Appendix_A-C12PhI.pdf', 'Q1582-Sugarloaf Hybrid Solar-Appendix_A-C12PhI.pdf', 'Q1582-Sugarloaf Hybrid Solar-Appendix_A-C12PhI-Revision1.pdf', 'Q1582-Sugarloaf Hybrid Solar-Appendix_A-C12PhI-Revision2.pdf', 'Q1584-Riviera Solar-Appendix_A-C12PhI.pdf', 'Q1584-Riviera Solar-Appendix_A-C12PhI-Addendum1.pdf', 'Q1586-Arcturus-Appendix_A-C12PhI.pdf', 'Q1586Arcturus_Appendix_A_Addendum3.pdf', 'Q1586-Arcturus-Appendix_A-C12PhI-Addendum1.pdf', 'Q1587-Kingsroad Hybrid Solar-Appendix_A-C12PhI.pdf', 'Q1587-Kingsroad Hybrid Solar-Appendix_A-C12PhI-Addendum1.pdf', 'Q1590-Nimitz 2 Generation-Appendix_A-C12PhI.pdf', 'Q1591-Carthage-Appendix_A-C12PhI.pdf', 'Q1591-Carthage-Appendix_A-C12PhI-Addendum1.pdf', 'Q1592-Oatfield Hybrid Solar-Appendix_A-C12PhI.pdf', 'Q1592-Oatfield Hybrid Solar-Appendix_A-C12PhI-Addendum1.pdf', 'Q1593-Pelicans Jaw Hybrid Solar-Appendix_A-C12PhI.pdf', 'Q1593-Pelicans Jaw Hybrid Solar-Appendix_A-C12PhI-Revision1.pdf', 'Q1594-Grand Lake Hybrid Solar-Appendix_A-C12PhI.pdf', 'Q1594-Grand Lake Hybrid Solar-Appendix_A-C12PhI-Revision1.pdf', 'Q1595-Oso Rojo Peony-Appendix_A-C12PhI.pdf', 'Q1595-Oso Rojo Peony-Appendix_A-C12PhI-Addendum1.pdf', 'Q1596-Buttonbush Solar Hybrid Energy Center-Appendix_A-C12PhI.pdf', 'Q1596-Buttonbush Solar Hybrid Energy Center-Appendix_A-C12PhI-Addendum1.pdf', 'Q1596_ButtonbushSolarHybridEnergyCenter_Appendix_A_Addendum5.pdf', 'Q1597-Oso Rojo Golf Course-Appendix_A-C12PhI.pdf', 'Q1598-Agua Amarga Wind-Appendix_A-C12PhI.pdf', 'Q1598-Agua Amarga Wind-Appendix_A-C12PhI-Addendum1.pdf', 'Q1599-Lion Rock Offshore Wind-Appendix_A-C12PhI.pdf', 'Q1599-Lion Rock Offshore Wind-Appendix_A-C12PhI-Addendum1.pdf', 'Q1600-Seawolf Generation-Appendix_A-C12PhI.pdf', 'Q1601-Familia Hybrid Solar-Appendix_A-C12PhI.pdf', 'Q1601-Familia Hybrid Solar-Appendix_A-C12PhI-Addendum1.pdf']
#
# List of Skipped PDFs:
# ['QC12PI-SCE-NOL-Q1603-TOT936-Rigal-AppendixA-Attachment_1.pdf', 'QC12PI-SCE-NOL-Q1603-TOT936-Rigal-AppendixA-Attachment_2.pdf', 'QC12PI-SCE-NOL-Q1603-TOT936-Rigal-AppendixA.pdf', 'QC12PI-SCE-NOL-Q1604-TOT904-Aratina-AppendixA.pdf', 'QC12PI-SCE-NOL-Q1604-TOT904-Aratina-AppendixA-Attachment_1.pdf', 'QC12PI-SCE-NOL-Q1604-TOT904-Aratina-AppendixA-Attachment_2.pdf', 'C12PI-Metro-Q1605-TOT960-Cayenne-Appendix A.pdf', 'C12PI-Metro-Q1605-TOT960-Cayenne-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1605-TOT960-Cayenne-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1608-TOT906-Avocet-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1608-TOT906-Avocet-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1608-TOT906-Avocet-Appendix A.pdf', 'C12PI-Metro-Q1609-TOT939-Hinson-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1609-TOT939-Hinson-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1609-TOT939-Hinson-Appendix A.pdf', 'C12PI-Metro-Q1610-TOT955-Superba-Appendix A.pdf', 'C12PI-Metro-Q1610-TOT955-Superba-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1610-TOT955-Superba-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1611-TOT927-Commerce-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1611-TOT927-Commerce-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1611-TOT927-Commerce-Appendix A.pdf', 'C12PI-Metro-Q1612-TOT920-Speedway-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1612-TOT920-Speedway-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1612-TOT920-Speedway-Appendix A.pdf', 'C12PI-Metro-Q1613-TOT957-Trestles-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1613-TOT957-Trestles-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1613-TOT957-Trestles-Appendix A.pdf', 'C12PI-Metro-Q1615-TOT907-Kestrel-Appendix A.pdf', 'C12PI-Metro-Q1615-TOT907-Kestrel-Appendix A-Attachment 1-reissue.pdf', 'C12PI-Metro-Q1615-TOT907-Kestrel-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1615-TOT907-Kestrel-Appendix A-Attachment 2.pdf', 'QC12PI-SCE-Northern-Q1616-TOT948-Highwind-Appendix A.pdf', 'QC12PI-SCE-Northern-Q1616-TOT948-Highwind-Appendix A-Attachment 2.pdf', 'QC12PI-SCE-Northern-Q1616-TOT948-Highwind-Appendix A-Attachment 1.pdf', 'QC12PI-SCE-NOL-Q1617-TOT914-SEGS_Expansion-AppendixA-Attachment_1.pdf', 'QC12PI-SCE-NOL-Q1617-TOT914-SEGS_Expansion-AppendixA-Attachment_2.pdf', 'QC12PI-SCE-NOL-Q1617-TOT914-SEGS_Expansion-AppendixA.pdf', 'QC12PI-SCE-Northern-Q1618-TOT911-Doradus-Appendix A-Attachment 2.pdf', 'QC12PI-SCE-Northern-Q1618-TOT911-Doradus-Appendix A-Attachment 1.pdf', 'QC12PI-SCE-Northern-Q1618-TOT911-Doradus-Appendix A.pdf', 'QC12PI-SCE-Northern-Q1619-TOT943-Goldback-Appendix A-Attachment 1.pdf', 'QC12PI-SCE-Northern-Q1619-TOT943-Goldback-Appendix A-Attachment 2.pdf', 'QC12PI-SCE-Northern-Q1619-TOT943-Goldback-Appendix A.pdf', 'QC12PI-SCE-Northern-Q1620-TOT924-Rocky_Hill-Appendix A-Attachment 2.pdf', 'QC12PI-SCE-Northern-Q1620-TOT924-Rocky_Hill-Appendix A-Attachment 1.pdf', 'QC12PI-SCE-Northern-Q1620-TOT924-Rocky_Hill-Appendix A.pdf', 'QC12PI-SCE-Northern-Q1621-TOT932-Yellow_Hay-Appendix A.pdf', 'QC12PI-SCE-Northern-Q1621-TOT932-Yellow_Hay-Appendix A-Attachment 1.pdf', 'QC12PI-SCE-Northern-Q1621-TOT932-Yellow_Hay-Appendix A-Attachment 2.pdf', 'QC12PI-SCE-Northern-Q1622-TOT952-Barrenspring-Appendix A.pdf', 'QC12PI-SCE-Northern-Q1622-TOT952-Barrenspring-Appendix A-Attachment 2.pdf', 'QC12PI-SCE-Northern-Q1622-TOT952-Barrenspring-Appendix A-Attachment 1.pdf', 'QC12PI-SCE-Northern-Q1625-TOT903-Angeleno-Appendix A-Attachment 2.pdf', 'QC12PI-SCE-Northern-Q1625-TOT903-Angeleno-Appendix A-Attachment 1.pdf', 'QC12PI-SCE-Northern-Q1625-TOT903-Angeleno-Appendix A.pdf', 'QC12PI-SCE-Northern-Q1626-TOT916-Sagebrush6-Appendix A-Attachment 1.pdf', 'QC12PI-SCE-Northern-Q1626-TOT916-Sagebrush6-Appendix A-Attachment 2.pdf', 'QC12PI-SCE-Northern-Q1626-TOT916-Sagebrush6-Appendix A.pdf', 'QC12PI-SCE-Northern-Q1628-TOT937-Fort_Tejon-Appendix A.pdf', 'QC12PI-SCE-Northern-Q1628-TOT937-Fort_Tejon-Appendix A-Attachment 2.pdf', 'QC12PI-SCE-Northern-Q1628-TOT937-Fort_Tejon-Appendix A-Attachment 1.pdf', 'QC12PI-SCE-Northern-Q1629-TOT959-H ...
#
# List of Addendum PDFs:
# ['Q1542-Capetown 2 Hybrid-Appendix_A-C12PhI-Revision1.pdf', 'Q1543-Beauchamp 2 Solar-Appendix_A-C12PhI-Addendum1.pdf', 'Q1546-Tatton Storage 1-Appendix_A-C12PhI-Addendum1.pdf', 'Q1549-Miranda ESS-Appendix_A-C12PhI-Revision1.pdf', 'Q1549-Miranda ESS-Appendix_A-C12PhI-Addendum1.pdf', 'Q1550Tanager_Storage_Appendix_A_Addendum3.pdf', 'Q1550-Tanager Storage-Appendix_A-C12PhI-Addendum1.pdf', 'Q1552-Cormorant Storage-Appendix_A-C12PhI-Addendum1.pdf', 'Q1554-Herculis-Appendix_A-C12PhI-Revision1.pdf', 'Q1555-Steel City Energy Storage-Appendix_A-C12PhI-Revision1.pdf', 'Q1564-Trim BESS-Appendix_A-C12PhI-Addendum1.pdf', 'Q1565-Dynamo Solar-Appendix_A-C12PhI-Addendum1.pdf', 'Q1568-Air Station 1-Appendix_A-C12PhI-Addendum1.pdf', 'Q1574-Big Duck Storage-Appendix_A-C12PhI-Addendum1.pdf', 'Q1578-Journey Storage-Appendix_A-C12PhI-Addendum1.pdf', 'Q1582-Sugarloaf Hybrid Solar-Appendix_A-C12PhI-Revision1.pdf', 'Q1582-Sugarloaf Hybrid Solar-Appendix_A-C12PhI-Revision2.pdf', 'Q1584-Riviera Solar-Appendix_A-C12PhI-Addendum1.pdf', 'Q1586Arcturus_Appendix_A_Addendum3.pdf', 'Q1586-Arcturus-Appendix_A-C12PhI-Addendum1.pdf', 'Q1587-Kingsroad Hybrid Solar-Appendix_A-C12PhI-Addendum1.pdf', 'Q1591-Carthage-Appendix_A-C12PhI-Addendum1.pdf', 'Q1592-Oatfield Hybrid Solar-Appendix_A-C12PhI-Addendum1.pdf', 'Q1593-Pelicans Jaw Hybrid Solar-Appendix_A-C12PhI-Revision1.pdf', 'Q1594-Grand Lake Hybrid Solar-Appendix_A-C12PhI-Revision1.pdf', 'Q1595-Oso Rojo Peony-Appendix_A-C12PhI-Addendum1.pdf', 'Q1596-Buttonbush Solar Hybrid Energy Center-Appendix_A-C12PhI-Addendum1.pdf', 'Q1596_ButtonbushSolarHybridEnergyCenter_Appendix_A_Addendum5.pdf', 'Q1598-Agua Amarga Wind-Appendix_A-C12PhI-Addendum1.pdf', 'Q1599-Lion Rock Offshore Wind-Appendix_A-C12PhI-Addendum1.pdf', 'Q1601-Familia Hybrid Solar-Appendix_A-C12PhI-Addendum1.pdf', 'QC12PI-SCE-Northern-Q1631-TOT909-GlenFeliz-Appendix A-Revison.pdf', 'QC12PI-SCE-Northern-Q1631-TOT909-GlenFeliz-Appendix A-Attachment 2-Revison.pdf', 'QC12PI-SCE-Eastern-Area Report-Appendix A-Addendum-Q1645-TOT934-Nova.pdf', 'QC12PI-SCE-Eastern-Area Report-Appendix A-Addendum-Attachment1-TOT934 Q1645.pdf', 'QC12PI-SCE-Eastern-Area Report-Appendix A-Addendum-Attachment 2 Q1645-TOT934.pdf', 'QC12PI-SCE-EOP-Q1647-TOT905-Angora-ApendixA-Attachment2-Revision-01.pdf', 'QC12PI-SCE-EOP-Q1647-TOT905-Angora-ApendixA-Revision-01.pdf', 'QC12PI-SCE-EOP-Q1647-TOT905-Angora-ApendixA-Attachment1-Revision-01.pdf', 'QC12PI-GLW-Q1649-AppendixA-Attachment1-addendum01.pdf', 'QC12PI-GLW-Q1649-AppendixA-GLW-Attachment2-Addendum01.pdf', 'QC12PI-GLW-Q1649-AppendixA-SCE-Attachment2-Addendum01.pdf', 'QC12PI-GLW-Q1649-AppendixA-Addendum01.pdf', 'QC12PI-GLW-Q1650-AppendixA-SCE-Attachment2-Addendum01.pdf', 'QC12PI-GLW-Q1650-AppendixA-Addendum01.pdf', 'QC12PI-GLW-Q1650-AppendixA-Attachment1-Addendum01.pdf', 'QC12PI-GLW-Q1650-AppendixA-GLW-Attachment2-Addendum01.pdf', 'QC12PI-GLW-Q1654-AppendixA-SCE-Attachment2-Addendum01.pdf', 'QC12PI-GLW-Q1654-AppendixA-Addendum01.pdf', 'QC12PI-GLW-Q1654-AppendixA-Attachment1-Addendum01.pdf', 'QC12PI-GLW-Q1654-AppendixA-GLW-Attachment2-Addendum01.pdf', 'QC12PI-GLW-Q1655-AppendixA-Addendum01.pdf', 'QC12PI-GLW-Q1655-AppendixA-GLW-Attachment2-Addendum01.pdf', 'QC12PI-GLW-Q1655-AppendixA-Attachment1-Addendum01.pdf', 'QC12PI-GLW-Q1655-AppendixA-SCE-Attachment2-Addendum01.pdf']
#
# List of Original PDFs:
# ['Q1541-Bright Star Hybrid-Appendix_A-C12PhI.pdf', 'Q1542-Capetown 2 Hybrid-Appendix_A-C12PhI.pdf', 'Q1543-Beauchamp 2 Solar-Appendix_A-C12PhI.pdf', 'Q1546-Tatton Storage 1-Appendix_A-C12PhI.pdf', 'Q1548-Loriner Storage-Appendix_A-C12PhI.pdf', 'Q1549-Miranda ESS-Appendix_A-C12PhI.pdf', 'Q1550-Tanager Storage-Appendix_A-C12PhI.pdf', 'Q1552-Cormorant Storage-Appendix_A-C12PhI.pdf', 'Q1553-Jewelflower Storage-Appendix_A-C12PhI.pdf', 'Q1554-Herculis-Appendix_A-C12PhI.pdf', 'Q1555-Steel City Energy Storage-Appendix_A-C12PhI.pdf', 'Q1557-Noosa Energy Storage-Appendix_A-C12PhI.pdf', 'Q1558-Hydaspes-Appendix_A-C12PhI.pdf', 'Q1559-Tempest Generation-Appendix_A-C12PhI.pdf', 'Q1561-Tesoster-Appendix_A-C12PhI.pdf', 'Q1564-Trim BESS-Appendix_A-C12PhI.pdf', 'Q1565-Dynamo Solar-Appendix_A-C12PhI.pdf', 'Q1566-Tyre-Appendix_A-C12PhI.pdf', 'Q1568-Air Station 1-Appendix_A-C12PhI.pdf', 'Q1573-Boyce Solar Hybrid-Appendix_A-C12PhI.pdf', 'Q1574-Big Duck Storage-Appendix_A-C12PhI.pdf', 'Q1578-Journey Storage-Appendix_A-C12PhI.pdf', 'Q1581-Pinebrook Solar Hybrid Energy Center-Appendix_A-C12PhI.pdf', 'Q1582-Sugarloaf Hybrid Solar-Appendix_A-C12PhI.pdf', 'Q1584-Riviera Solar-Appendix_A-C12PhI.pdf', 'Q1586-Arcturus-Appendix_A-C12PhI.pdf', 'Q1587-Kingsroad Hybrid Solar-Appendix_A-C12PhI.pdf', 'Q1590-Nimitz 2 Generation-Appendix_A-C12PhI.pdf', 'Q1591-Carthage-Appendix_A-C12PhI.pdf', 'Q1592-Oatfield Hybrid Solar-Appendix_A-C12PhI.pdf', 'Q1593-Pelicans Jaw Hybrid Solar-Appendix_A-C12PhI.pdf', 'Q1594-Grand Lake Hybrid Solar-Appendix_A-C12PhI.pdf', 'Q1595-Oso Rojo Peony-Appendix_A-C12PhI.pdf', 'Q1596-Buttonbush Solar Hybrid Energy Center-Appendix_A-C12PhI.pdf', 'Q1597-Oso Rojo Golf Course-Appendix_A-C12PhI.pdf', 'Q1598-Agua Amarga Wind-Appendix_A-C12PhI.pdf', 'Q1599-Lion Rock Offshore Wind-Appendix_A-C12PhI.pdf', 'Q1600-Seawolf Generation-Appendix_A-C12PhI.pdf', 'Q1601-Familia Hybrid Solar-Appendix_A-C12PhI.pdf', 'QC12PI-SCE-NOL-Q1603-TOT936-Rigal-AppendixA-Attachment_1.pdf', 'QC12PI-SCE-NOL-Q1603-TOT936-Rigal-AppendixA-Attachment_2.pdf', 'QC12PI-SCE-NOL-Q1603-TOT936-Rigal-AppendixA.pdf', 'QC12PI-SCE-NOL-Q1604-TOT904-Aratina-AppendixA.pdf', 'QC12PI-SCE-NOL-Q1604-TOT904-Aratina-AppendixA-Attachment_1.pdf', 'QC12PI-SCE-NOL-Q1604-TOT904-Aratina-AppendixA-Attachment_2.pdf', 'C12PI-Metro-Q1605-TOT960-Cayenne-Appendix A.pdf', 'C12PI-Metro-Q1605-TOT960-Cayenne-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1605-TOT960-Cayenne-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1608-TOT906-Avocet-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1608-TOT906-Avocet-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1608-TOT906-Avocet-Appendix A.pdf', 'C12PI-Metro-Q1609-TOT939-Hinson-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1609-TOT939-Hinson-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1609-TOT939-Hinson-Appendix A.pdf', 'C12PI-Metro-Q1610-TOT955-Superba-Appendix A.pdf', 'C12PI-Metro-Q1610-TOT955-Superba-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1610-TOT955-Superba-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1611-TOT927-Commerce-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1611-TOT927-Commerce-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1611-TOT927-Commerce-Appendix A.pdf', 'C12PI-Metro-Q1612-TOT920-Speedway-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1612-TOT920-Speedway-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1612-TOT920-Speedway-Appendix A.pdf', 'C12PI-Metro-Q1613-TOT957-Trestles-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1613-TOT957-Trestles-Appendix A-Attachment 2.pdf', 'C12PI-Metro-Q1613-TOT957-Trestles-Appendix A.pdf', 'C12PI-Metro-Q1615-TOT907-Kestrel-Appendix A.pdf', 'C12PI-Metro-Q1615-TOT907-Kestrel-Appendix A-Attachment 1-reissue.pdf', 'C12PI-Metro-Q1615-TOT907-Kestrel-Appendix A-Attachment 1.pdf', 'C12PI-Metro-Q1615-TOT907-Kestrel-Appendix A-Attachment 2.pdf', 'QC12PI-SCE-Northern-Q1616-TOT948-Highwind-Appendix A.pdf', 'QC12PI-SCE-Northern-Q1616-TOT948-Highwind-Appendix A-Attachment 2.pdf', 'QC12PI-SCE-Northern-Q1616-TOT948-Highwind-Appendix A-Attachment 1.pdf', 'QC12PI-SC ...
#
# List of Style N PDFs (Skipped due to 'Network Upgrade Type'):
# ['QC12PhI_Q1656_Gypsy_ESS_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1657_Sandpiper_Storage_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1658_Cardinal_Storage_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1662_Ventasso_Energy_Storage_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1663_Hoodini_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1664_Cucapa_Energia_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1665_Kingsley_Solar_Farm_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1666_Salton_Solar_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1667_Wistaria_Ranch_Solar_2_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1668_Suffolk_Storage_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1669_Pome_BESS_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1670_Peregrine_Storage_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1671_Marine_Depot_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1672_Boulder_Oaks_Hybrid_Appendix A_Rev1_03-03-2020.pdf', 'QC12PhI_Q1673_Nighthawk_Storage_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1674_SV_Energy_Storage_Facility_Appendix_A_01-15-2020.pdf', 'QC12PhI_Q1675_Resava_Energy_Storage_Appendix_A_01-15-2020.pdf']
#
# Total Number of Style N PDFs: 17
#
# Number of Original PDFs Scraped: 39
# Number of Addendum PDFs Scraped: 31
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_59501/616871467.py:1159: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(clean_string_cell)
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_59501/616871467.py:1159: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(clean_string_cell)

# %% [markdown]
# # Code to created itemized and totals dataset

# %%
import pandas as pd
import re
import unicodedata

# Load the CSV file
df = pd.read_csv('/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/03_raw/rawdata_cluster12_style_G_originals.csv', dtype={'estimated_time_to_construct': str})

df['q_id'] = df['q_id'].astype('Int64')
df['cluster'] = df['cluster'].astype('Int64')

def merge_columns(df):
    merge_columns_dict = {
        "escalated_cost_x_1000": [
            "escalated costs x 1000",
            "estimated cost x 1000 escalated",
            "estimated cost x 1000 escalated without itcca",
            "escalated cost x 1000",
            "sum of allocated escalated cost"
        ],
        "estimated_cost_x_1000": [
            "estimated cost x 1000",
            "allocated_cost",
            "sum of allocated constant cost"
        ],
        "estimated_time_to_construct": [
            "estimated time to construct",
            "estimated time  to construct"
        ],
        "total_estimated_cost_x_1000_escalated": [
            "total estimated cost x 1000 escalalted",
            "total estimated cost x 1000 escalated"
        ],
        "total_estimated_cost_x_1000": [
            "total nu cost",
            "total cost constant"
        ],
        "adnu_cost_rate_x_1000": [
            "adnu cost rate x 1000",
            "cost rate x 1000",
            "cost rate",
            "cost rate constant"
        ],
        "description": ["description"],
        "capacity": [
            "capacity",
            "project size",
            "project mw",
            "mw at poi"

        ],
        "cost_allocation_factor": [
            "cost allocation factor",
            "cost allocatio n factor",
            "cost allocati on factor",
        ],
    }

    # Identify unnamed columns
    unnamed_columns = [col for col in df.columns if pd.isna(col) or col.strip() == "" or col.startswith("Unnamed")]
    if unnamed_columns:
        merge_columns_dict["description"].extend(unnamed_columns)

    for new_col, old_cols in merge_columns_dict.items():
        existing_cols = [col for col in old_cols if col in df.columns]
        if existing_cols:
            df[new_col] = df[existing_cols].bfill(axis=1).iloc[:, 0]
            cols_to_drop = [col for col in existing_cols if col != new_col]
            if cols_to_drop:
                df.drop(columns=cols_to_drop, inplace=True)

    return df

df = merge_columns(df)
df.drop('incremental deliverability', axis=1, inplace=True)

def convert_to_snake_case(column_name):
    column_name = column_name.strip().lower()
    column_name = re.sub(r'[\s\-]+', '_', column_name)
    column_name = re.sub(r'[^\w]', '', column_name)
    return column_name

def clean_string_cell(value):
    if isinstance(value, str):
        value = unicodedata.normalize('NFKD', value).encode('ascii', 'ignore').decode('ascii')
        value = value.replace('\n', ' ').strip()
    return value

df = df.map(clean_string_cell)
df.columns = [convert_to_snake_case(col) for col in df.columns]

required_columns = ['type_of_upgrade', 'cost_allocation_factor']
for col in required_columns:
    if col not in df.columns:
        df[col] = None


    


'''
# ## ADNU GROUPING LOGIC START
# If type_of_upgrade == 'ADNU' and multiple rows have the same 'upgrade' with no estimated_cost_x_1000,
# we group them into a single row by keeping the first and dropping the rest.
if 'type_of_upgrade' in df.columns and 'upgrade' in df.columns and 'estimated_cost_x_1000' in df.columns:
    to_drop = []
    for (qid, toup, upg), grp in df.groupby(['q_id', 'type_of_upgrade', 'upgrade'], sort=False):
        if isinstance(toup, str) and toup.lower() == 'adnu':
            # Check if all estimated_cost_x_1000 are empty/None/'None'
            is_empty_est = grp['estimated_cost_x_1000'].apply(lambda x: pd.isna(x) or x == '' or x == 'None')
            if len(grp) > 1 and is_empty_est.all():
                # Keep the first row, drop the rest
                idxs = grp.index.tolist()
                drop_idxs = idxs[1:]
                to_drop.extend(drop_idxs)
    if to_drop:
        df.drop(to_drop, inplace=True)
        df.reset_index(drop=True, inplace=True)
# ## ADNU GROUPING LOGIC END
'''



# Step 1: Rename 'Grand Total' to 'Total' in total_estimated_cost_x_1000
if 'total_estimated_cost_x_1000' in df.columns:
    df['total_estimated_cost_x_1000'] = df['total_estimated_cost_x_1000'].replace('Grand Total', 'Total')

# Step 2: Move 'Total' from total_estimated_cost_x_1000 to cost_allocation_factor
if 'total_estimated_cost_x_1000' in df.columns and 'cost_allocation_factor' in df.columns:
    df['cost_allocation_factor'] = df.apply(
        lambda row: 'Total' if str(row['total_estimated_cost_x_1000']) == 'Total' else row['cost_allocation_factor'],
        axis=1
    )

    # Clear the moved 'Total' from total_estimated_cost_x_1000
    df['total_estimated_cost_x_1000'] = df['total_estimated_cost_x_1000'].replace('Total', None)

# Step 4: For each q_id and type_of_upgrade, if only one row and no total present, create new Total row
new_rows = []

# Group by q_id and iterate over each group
for q_id, group in df.groupby('q_id', as_index=False):
    unique_upgrades = group['type_of_upgrade'].dropna().unique()

    # For each type_of_upgrade, check if it qualifies for a Total row
    for upgrade in unique_upgrades:
        if pd.isna(upgrade) or 'Total' in upgrade:
            continue

        # Filter rows for the current type_of_upgrade
        rows = group[group['type_of_upgrade'] == upgrade]

        # If only one row exists for this upgrade, create a "Total" row
        if len(rows) == 1:
            original_row = rows.iloc[0].copy()
            total_row = original_row.copy()

            # Modify the type_of_upgrade and item fields
            total_row['type_of_upgrade'] = f"Total"
            total_row['item'] = 'no'

            # Append the total_row to new_rows
            new_rows.append(total_row.to_dict())  # Ensure consistency by converting to a dictionary

# Create a DataFrame from the new rows
if new_rows:
    total_rows_df = pd.DataFrame(new_rows)

    # Ensure that all columns in the new rows match the original DataFrame
    for col in df.columns:
        if col not in total_rows_df.columns:
            total_rows_df[col] = None  # Add missing columns
    total_rows_df = total_rows_df[df.columns]  # Align column order with the original DataFrame

    # Concatenate the new rows with the original DataFrame
    df = pd.concat([df, total_rows_df], ignore_index=True)

# Reset index to ensure consistency
df.reset_index(drop=True, inplace=True)



# Step 1: Create the 'item' column
df['item'] = df.apply(
    lambda row: 'no' if (
        (pd.notna(row.get('type_of_upgrade')) and 'Total' in str(row['type_of_upgrade'])) or
        (pd.notna(row.get('cost_allocation_factor')) and 'Total' in str(row['cost_allocation_factor']))
    ) else 'yes',
    axis=1
)

# Step 2: Move 'item' column next to 'type_of_upgrade'
if 'item' in df.columns and 'type_of_upgrade' in df.columns:
    cols = df.columns.tolist()
    item_index = cols.index('item')
    type_index = cols.index('type_of_upgrade')
    if item_index < type_index:
        cols.insert(type_index + 1, cols.pop(item_index))
    else:
        cols.insert(type_index + 1, cols.pop(item_index))
    df = df[cols]

# Step 3: Remove "Total" values from cost_allocation_factor if they appear in type_of_upgrade
if 'cost_allocation_factor' in df.columns and 'type_of_upgrade' in df.columns:
    df['cost_allocation_factor'] = df.apply(
        lambda row: None if (
            pd.notna(row['type_of_upgrade']) and 'Total' in str(row['type_of_upgrade'])
        ) else row.get('cost_allocation_factor'),
        axis=1
    )


    

if 'cost_allocation_factor' in df.columns and 'type_of_upgrade' in df.columns:
    df['cost_allocation_factor'] = df.apply(
        lambda row: None if 'Total' in str(row.get('cost_allocation_factor', '')) else row.get('cost_allocation_factor'),
        axis=1
    )

def clean_estimated_time(value):
    if isinstance(value, str):
        value = re.sub(r'(\d+(?:-\w+)*)\s+\w+.*$', r'\1', value, flags=re.IGNORECASE).strip()
    return value

if 'estimated_time_to_construct' in df.columns:
    df['estimated_time_to_construct'] = df['estimated_time_to_construct'].apply(clean_estimated_time)

if 'type_of_upgrade' in df.columns:
    df['type_of_upgrade'] = df['type_of_upgrade'].apply(
        lambda x: re.sub(r'\s*\(note \d+\)', '', x, flags=re.IGNORECASE).strip() if isinstance(x, str) else x
    )

mappings = {
    'Reliability Network Upgrade': 'RNU',
    'Reliability Network upgrade': 'RNU',
    'Local Delivery Network Upgrade': 'LDNU',
    'Local Delivery Network': 'LDNU',
    'Potential Local Delivery Network Upgrade': 'LDNU',
    "PTOs Interconnection Facilities": 'PTO_IF',
    'Area Delivery Network Upgrade': 'ADNU',
    'Area Delivery Network upgrade': 'ADNU',
    'Reliability Network upgrade to Physically Interconnect': 'RNU',
    "Reliability Network upgrade To Physically Interconnect": "RNU",
    "CANUs": "CANU",
    "Conditionally Assigned Network upgrade": "CANU",
    "Conditionally Assigned Network Upgrades": "CANU",
    'PTO': 'PTO_IF',
    "Other Potential Network Upgrade": "OPNU",

}

if 'type_of_upgrade' in df.columns:
    df['type_of_upgrade'] = df['type_of_upgrade'].apply(
        lambda x: re.sub(r'\bupgrades\b', 'upgrade', x, flags=re.IGNORECASE).strip() if isinstance(x, str) else x
    )
    df['type_of_upgrade'] = df['type_of_upgrade'].apply(
        lambda x: mappings.get(x, x) if isinstance(x, str) else x
    )
    df['type_of_upgrade'] = df['type_of_upgrade'].ffill()

if 'upgrade' in df.columns and 'type_of_upgrade' in df.columns and 'q_id' in df.columns:
    df['upgrade'] = df.groupby(['q_id', 'type_of_upgrade'])['upgrade'].ffill()

if 'type_of_upgrade' in df.columns:
    previous_type_of_upgrade = None
    for i in range(len(df)):
        if df.at[i, 'type_of_upgrade'] == 'Total':
            if previous_type_of_upgrade is not None:
                df.at[i, 'type_of_upgrade'] = previous_type_of_upgrade
        else:
            previous_type_of_upgrade = df.at[i, 'type_of_upgrade']

numeric_columns = [
    'cost_allocation_factor',
    'estimated_cost_x_1000',
    'estimated_time_to_construct',
    'total_estimated_cost_x_1000_escalated',
    'adnu_cost_rate_x_1000',
    'escalated_cost_x_1000',
    'estimated_cost_x_1000_escalated_without_itcca',
    'adnu_cost_rate_x_1000_escalated'
]
non_numeric_columns = ['type_of_upgrade', 'upgrade', 'description']

for col in non_numeric_columns:
    if col in df.columns:
        df[col] = df[col].apply(lambda x: 'None' if pd.isna(x) else x)

for col in numeric_columns:
    if col in df.columns:
        df[col] = df[col].replace('-', pd.NA)
        df[col] = df[col].fillna(0)

if 'original_order' in df.columns and 'q_id' in df.columns:
    df['original_order'] = df.index
    df = df.sort_values(by=['q_id', 'original_order'], ascending=[True, True])
    df = df.drop(columns=['original_order'])


def reorder_columns(df):
    """
    Reorders the columns of the DataFrame based on the specified order.

    Args:
        df (pd.DataFrame): The DataFrame to reorder.

    Returns:
        pd.DataFrame: The reordered DataFrame.
    """
    desired_order = [
        "q_id",
        "cluster",
        "req_deliverability",
        "latitude",
        "longitude",
        "capacity",
        "point_of_interconnection",
        "type_of_upgrade",
        "upgrade classification",
        "upgrade",
        "description",
        "cost_allocation_factor",
        "estimated_cost_x_1000",
        "escalated_cost_x_1000",
        "total_estimated_cost_x_1000",
        "total_estimated_cost_x_1000_escalated",
        "estimated_time_to_construct",
    ]

    # Start with desired columns that exist in the DataFrame
    existing_desired = [col for col in desired_order if col in df.columns]

    # Then add the remaining columns
    remaining = [col for col in df.columns if col not in existing_desired]

    # Combine the two lists
    new_order = existing_desired + remaining

    # Reorder the DataFrame
    df = df[new_order]

    return df        


df= reorder_columns(df)



if 'item' in df.columns:
    itemized_df = df[df['item'] == 'yes']
     
     
    itemized_df.to_csv('/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_itemized.csv', index=False)

    totals_columns = ['upgrade', 'description', 'cost_allocation_factor', 'estimated_time_to_construct']
    existing_totals_columns = [col for col in totals_columns if col in df.columns]
    totals_df = df[df['item'] == 'no'].drop(columns=existing_totals_columns, errors='ignore')
    
    totals_df.to_csv('/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_totals.csv', index=False)

print(f"Itemized rows saved to 'costs_phase_1_cluster_12_itemized.csv'.")
print(f"Filtered Total rows saved to 'costs_phase_1_cluster_12_total.csv'.")

if 'type_of_upgrade' in df.columns:
    print(df['type_of_upgrade'].unique())

if 'q_id' in df.columns:
    print(df['q_id'].unique())

if 'cluster' in df.columns:
    print(df['cluster'].unique())
# Out:
# Itemized rows saved to 'costs_phase_1_cluster_12_itemized.csv'.
# Filtered Total rows saved to 'costs_phase_1_cluster_12_total.csv'.
# ['PTO_IF' 'RNU' 'LDNU' 'ADNU' 'CANU']
# [1541 1542 1543 1546 1548 1549 1550 1552 1553 1554 1555 1557 1558 1559
#  1561 1564 1565 1566 1568 1573 1574 1578 1581 1582 1584 1586 1587 1590
#  1591 1592 1593 1594 1595 1596 1597 1598 1599 1600 1601]
# [12]

# %% [markdown]
# # Originals

# %%
import pandas as pd
import re
import unicodedata

# Load the CSV file
df = pd.read_csv('/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/03_raw/rawdata_cluster12_style_G_originals.csv', dtype={'estimated_time_to_construct': str})

df['q_id'] = df['q_id'].astype('Int64')
df['cluster'] = df['cluster'].astype('Int64')


######################################################################################################################################
########################################
#STEP 1 MERGE COLUMNS

def merge_columns(df):
    merge_columns_dict = {
        "escalated_cost_x_1000": [
            "escalated costs x 1000",
            "estimated cost x 1000 escalated",
            "estimated cost x 1000 escalated without itcca",
            "escalated cost x 1000",
            "sum of allocated escalated cost"
        ],
        "estimated_cost_x_1000": [
            "estimated cost x 1000",
            "allocated_cost",
            "sum of allocated constant cost"
        ],
        "estimated_time_to_construct": [
            "estimated time to construct",
            "estimated time  to construct"
        ],
        "total_estimated_cost_x_1000_escalated": [
            "total estimated cost x 1000 escalalted",
            "total estimated cost x 1000 escalated"
        ],
        "total_estimated_cost_x_1000": [
            "total nu cost",
            "total cost constant"
        ],
        "adnu_cost_rate_x_1000": [
            "adnu cost rate x 1000",
            "cost rate x 1000",
            "cost rate",
            "cost rate constant"
        ],
        "description": ["description"],
        "capacity": [
            "capacity",
            "project size",
            "project mw",
            "mw at poi"
        ],
        "cost_allocation_factor": [
            "cost allocation factor",
            "cost allocatio n factor",
            "cost allocati on factor",
        ],
    }

    # Identify unnamed columns
    unnamed_columns = [col for col in df.columns if pd.isna(col) or col.strip() == "" or col.startswith("Unnamed")]
    if unnamed_columns:
        merge_columns_dict["description"].extend(unnamed_columns)

    for new_col, old_cols in merge_columns_dict.items():
        existing_cols = [col for col in old_cols if col in df.columns]
        if existing_cols:
            df[new_col] = df[existing_cols].bfill(axis=1).iloc[:, 0]
            cols_to_drop = [col for col in existing_cols if col != new_col]
            if cols_to_drop:
                df.drop(columns=cols_to_drop, inplace=True)

    return df

df = merge_columns(df)
df.drop('incremental deliverability', axis=1, inplace=True)

#STEP 2: NAMING CONVENTION
def convert_to_snake_case(column_name):
    column_name = column_name.strip().lower()
    column_name = re.sub(r'[\s\-]+', '_', column_name)
    column_name = re.sub(r'[^\w]', '', column_name)
    return column_name

def clean_string_cell(value):
    if isinstance(value, str):
        value = unicodedata.normalize('NFKD', value).encode('ascii', 'ignore').decode('ascii')
        value = value.replace('\n', ' ').strip()
    return value

df = df.map(clean_string_cell)
df.columns = [convert_to_snake_case(col) for col in df.columns]

required_columns = ['type_of_upgrade', 'cost_allocation_factor']
for col in required_columns:
    if col not in df.columns:
        df[col] = None

 
 
# Step 3: Rename 'Grand Total' to 'Total' in total_estimated_cost_x_1000
if 'total_estimated_cost_x_1000' in df.columns:
    df['total_estimated_cost_x_1000'] = df['total_estimated_cost_x_1000'].replace('Grand Total', 'Total')

# Step 4: Move 'Total' from total_estimated_cost_x_1000 to cost_allocation_factor
if 'total_estimated_cost_x_1000' in df.columns and 'cost_allocation_factor' in df.columns:
    df['cost_allocation_factor'] = df.apply(
        lambda row: 'Total' if str(row['total_estimated_cost_x_1000']) == 'Total' else row['cost_allocation_factor'],
        axis=1
    )
    df['total_estimated_cost_x_1000'] = df['total_estimated_cost_x_1000'].replace('Total', None)


df['item'] = df.apply(
    lambda row: 'no' if (
        (pd.notna(row.get('type_of_upgrade')) and 'Total' in str(row['type_of_upgrade'])) or
        (pd.notna(row.get('cost_allocation_factor')) and 'Total' in str(row['cost_allocation_factor']))
    ) else 'yes',
    axis=1
)
   


# Step 5: Clean the type of upgrade column
   
 
df['type_of_upgrade'] = (
    df['type_of_upgrade']
    .fillna('')  # Temporarily replace NaN with an empty string
    .str.replace(r'\(Note \d+\)', '', regex=True)  # Remove (Note digit)
    .str.strip()  # Strip leading/trailing whitespace
    .str.title()  # Capitalize the first letter of each word
    .str.replace(r'Upgrades$', 'Upgrade', regex=True)  # Fix plural endings
    .replace('', pd.NA)  # Convert empty strings back to NaN
)





mappings = {
    'Reliability Network Upgrade': 'RNU',
    'Local Delivery Network Upgrade': 'LDNU',
    'Local Delivery Network': 'LDNU',
    'Potential Local Delivery Network Upgrade': 'LDNU',
    "Ptos Interconnection Facilities": 'PTO_IF',
    'Area Delivery Network Upgrade': 'ADNU',
    'Reliability Network Upgrade To Physically Interconnect': 'RNU',
    "Reliability Network upgrade To Physically Interconnect": "RNU",
     'Pto': 'PTO_IF',
    "Other Potential Network Upgrade": "OPNU",
    "Conditionally Assigned Network Upgrade": "CANU",
    "Canus": "CANU",
    'Total PTO_IF': 'PTO_IF',
 'Total RNU': 'RNU',
 'Total LDNU': 'LDNU',
 'Total OPNU' : 'OPNU',
 
  
 'Total ADNU': 'ADNU',
  

 
}


#Step 6: Apply mapping and ffill type of upgrade column

if 'type_of_upgrade' in df.columns:
    df['type_of_upgrade'] = df['type_of_upgrade'].apply(
        lambda x: re.sub(r'\bupgrades\b', 'upgrade', x, flags=re.IGNORECASE).strip() if isinstance(x, str) else x
    )
    df['type_of_upgrade'] = df['type_of_upgrade'].apply(
        lambda x: mappings.get(x, x) if isinstance(x, str) else x
    )
    df['type_of_upgrade'] = df['type_of_upgrade'].ffill()   

    
# Step 7: Remove $ signs and convert to numeric
import re

def clean_currency(value):
    """
    Cleans a string by explicitly removing $, *, (Note 2), and similar patterns,
    then converts it to a numeric value.
    """
    if isinstance(value, str):
        # Explicitly remove $, *, and any "(Note ...)"
        value = value.replace('$', '').replace('*', '')
        value = re.sub(r'\(Note \d+\)', '', value)  # Remove patterns like "(Note 2)"
        value = value.replace(',', '').strip()  # Remove commas and extra spaces
    try:
        return pd.to_numeric(value)
    except ValueError:
        return pd.NA  # Return NaN for invalid entries


# Clean the specific columns
for col in ['estimated_cost_x_1000', 'escalated_cost_x_1000', 'total_estimated_cost_x_1000_escalated', 'total_estimated_cost_x_1000', 'adnu_cost_rate_x_1000', 'adnu_cost_rate_x_1000_escalated']:
    if col in df.columns:
        df[col] = df[col].apply(clean_currency)

# Create Total rows
new_rows = []
columns_to_sum = ['estimated_cost_x_1000', 'escalated_cost_x_1000', 'total_estimated_cost_x_1000_escalated',   'adnu_cost_rate_x_1000_escalated']
columns_to_populate = ['cluster', 'req_deliverability', 'latitude', 'longitude', 'capacity', 'point_of_interconnection']

for q_id, group in df.groupby('q_id', as_index=False):
    unique_upgrades = group['type_of_upgrade'].dropna().unique()
    for upgrade in unique_upgrades:
        if pd.isna(upgrade):
            continue
        
        rows = group[group['type_of_upgrade'] == upgrade]

                # Check if a Total row already exists for this (q_id, upgrade)
        total_exists = group[
            (group['type_of_upgrade'] == upgrade) & (group['item'] == 'no')
        ].shape[0] > 0
        
        if total_exists:
             
            continue


 
        
        
        if not total_exists:
            # If only one row exists, duplicate it as the total row
            if len(rows) == 1:

                total_row = {col: '' for col in df.columns}  # Initialize all columns as empty strings

                # Populate the necessary fields
                total_row['q_id'] = q_id
                total_row['type_of_upgrade'] = f"Total {upgrade}"
                total_row['item'] = 'no'

                # Populate specified columns from the existing row
                first_row = rows.iloc[0]
                for col in columns_to_populate:
                    if col in df.columns:
                        total_row[col] = first_row[col]

                # Sum the numeric columns (single row, so it remains the same)
                for col in columns_to_sum:
                    if col in rows.columns:
                        total_row[col] = rows[col].sum()
                    else:
                        total_row[col] = 0  # Default to 0 if column is missing

                new_rows.append(total_row)



 
            
            # If multiple rows exist, sum numeric columns and create a total row
            elif len(rows) > 1:
                total_row = {col: '' for col in df.columns}  # Initialize all columns as empty strings

                # Populate the necessary fields
                total_row['q_id'] = q_id
                total_row['type_of_upgrade'] = f"Total {upgrade}"
                total_row['item'] = 'no'

                # Populate the specified columns from the first row in the group
                first_row = rows.iloc[0]
                for col in columns_to_populate:
                    if col in df.columns:
                        total_row[col] = first_row[col]

                # Sum the numeric columns
                for col in columns_to_sum:
                    if col in rows.columns:
                        total_row[col] = rows[col].sum()
                    else:
                        total_row[col] = 0  # Default to 0 if column is missing

                new_rows.append(total_row)
 



      

if new_rows:
    total_rows_df = pd.DataFrame(new_rows)
    for col in df.columns:
        if col not in total_rows_df.columns:
            total_rows_df[col] = None
    total_rows_df = total_rows_df[df.columns]
    df = pd.concat([df, total_rows_df], ignore_index=True)

df.reset_index(drop=True, inplace=True)

# Update 'item' column based on Total in type_of_upgrade or cost_allocation_factor
df['item'] = df.apply(
    lambda row: 'no' if (
        'Total' in str(row.get('type_of_upgrade', '')) or 
        'Total' in str(row.get('cost_allocation_factor', ''))
    ) else 'yes',
    axis=1
)


# Step 8: Move 'item' column next to 'type_of_upgrade'
if 'item' in df.columns and 'type_of_upgrade' in df.columns:
    cols = df.columns.tolist()
    item_index = cols.index('item')
    type_index = cols.index('type_of_upgrade')
    if item_index < type_index:
        cols.insert(type_index + 1, cols.pop(item_index))
    else:
        cols.insert(type_index + 1, cols.pop(item_index))
    df = df[cols]

# Step 9: Remove "Total" values from cost_allocation_factor if they appear in type_of_upgrade
if 'cost_allocation_factor' in df.columns and 'type_of_upgrade' in df.columns:
    df['cost_allocation_factor'] = df.apply(
        lambda row: None if (
            pd.notna(row['type_of_upgrade']) and 'Total' in str(row['type_of_upgrade'])
        ) else row.get('cost_allocation_factor'),
        axis=1
    )
    

if 'cost_allocation_factor' in df.columns and 'type_of_upgrade' in df.columns:
    df['cost_allocation_factor'] = df.apply(
        lambda row: None if 'Total' in str(row.get('cost_allocation_factor', '')) else row.get('cost_allocation_factor'),
        axis=1
    )



def clean_estimated_time(value):
    if isinstance(value, str):
        value = re.sub(r'(\d+(?:-\w+)*)\s+\w+.*$', r'\1', value, flags=re.IGNORECASE).strip()
    return value

if 'estimated_time_to_construct' in df.columns:
    df['estimated_time_to_construct'] = df['estimated_time_to_construct'].apply(clean_estimated_time)

if 'type_of_upgrade' in df.columns:
    df['type_of_upgrade'] = df['type_of_upgrade'].apply(
        lambda x: re.sub(r'\s*\(note \d+\)', '', x, flags=re.IGNORECASE).strip() if isinstance(x, str) else x
    )

 



if 'type_of_upgrade' in df.columns:
    df['type_of_upgrade'] = df['type_of_upgrade'].apply(
        lambda x: re.sub(r'\bupgrades\b', 'upgrade', x, flags=re.IGNORECASE).strip() if isinstance(x, str) else x
    )
    df['type_of_upgrade'] = df['type_of_upgrade'].apply(
        lambda x: mappings.get(x, x) if isinstance(x, str) else x
    )
    df['type_of_upgrade'] = df['type_of_upgrade'].ffill()

if 'upgrade' in df.columns and 'type_of_upgrade' in df.columns and 'q_id' in df.columns:
    df['upgrade'] = df.groupby(['q_id', 'type_of_upgrade'])['upgrade'].ffill()

if 'type_of_upgrade' in df.columns:
    previous_type_of_upgrade = None
    for i in range(len(df)):
        if df.at[i, 'type_of_upgrade'] == 'Total':
            if previous_type_of_upgrade is not None:
                df.at[i, 'type_of_upgrade'] = previous_type_of_upgrade
        else:
            previous_type_of_upgrade = df.at[i, 'type_of_upgrade']

numeric_columns = [
    'cost_allocation_factor',
    'estimated_cost_x_1000',
    'estimated_time_to_construct',
    'total_estimated_cost_x_1000_escalated',
    'adnu_cost_rate_x_1000',
    'escalated_cost_x_1000',
    'estimated_cost_x_1000_escalated_without_itcca',
    'adnu_cost_rate_x_1000_escalated'
]
non_numeric_columns = ['type_of_upgrade', 'upgrade', 'description']

for col in non_numeric_columns:
    if col in df.columns:
        df[col] = df[col].apply(lambda x: 'None' if pd.isna(x) else x)

for col in numeric_columns:
    if col in df.columns:
        df[col] = df[col].replace('-', pd.NA)
        df[col] = df[col].fillna(0)

if 'original_order' in df.columns and 'q_id' in df.columns:
    df['original_order'] = df.index
    df = df.sort_values(by=['q_id', 'original_order'], ascending=[True, True])
    df = df.drop(columns=['original_order'])


def reorder_columns(df):
    """
    Reorders the columns of the DataFrame based on the specified order.

    Args:
        df (pd.DataFrame): The DataFrame to reorder.

    Returns:
        pd.DataFrame: The reordered DataFrame.
    """
    desired_order = [
        "q_id",
        "cluster",
        "req_deliverability",
        "latitude",
        "longitude",
        "capacity",
        "point_of_interconnection",
        "type_of_upgrade",
        "upgrade",
        "description",
        "cost_allocation_factor",
        "estimated_cost_x_1000",
        "escalated_cost_x_1000",
        "total_estimated_cost_x_1000",
        "total_estimated_cost_x_1000_escalated",
        "estimated_time_to_construct",
    ]

    # Start with desired columns that exist in the DataFrame
    existing_desired = [col for col in desired_order if col in df.columns]

    # Then add the remaining columns
    remaining = [col for col in df.columns if col not in existing_desired]

    # Combine the two lists
    new_order = existing_desired + remaining

    # Reorder the DataFrame
    df = df[new_order]

    return df        


df= reorder_columns(df)


# Save itemized and totals separately
if 'item' in df.columns:
    itemized_df = df[df['item'] == 'yes']
    itemized_df.to_csv('/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_itemized.csv', index=False)

    totals_columns = ['upgrade', 'description', 'cost_allocation_factor', 'estimated_time_to_construct']
    totals_df = df[df['item'] == 'no'].drop(columns=totals_columns, errors='ignore')
    totals_df.to_csv('/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_total.csv', index=False)

print(f"Itemized rows saved to 'costs_phase_1_cluster_12_style_G_itemized.csv'.")
print(f"Filtered Total rows saved to 'costs_phase_1_cluster_12_style_G_total.csv'.")


if 'type_of_upgrade' in df.columns:
    print(df['type_of_upgrade'].unique())

if 'q_id' in df.columns:
    print(df['q_id'].unique())

if 'cluster' in df.columns:
    print(df['cluster'].unique())
# Out:
# Itemized rows saved to 'costs_phase_1_cluster_12_style_G_itemized.csv'.
# Filtered Total rows saved to 'costs_phase_1_cluster_12_style_G_total.csv'.
# ['PTO_IF' 'RNU' 'LDNU' 'ADNU' 'CANU']
# [1541 1542 1543 1546 1548 1549 1550 1552 1553 1554 1555 1557 1558 1559
#  1561 1564 1565 1566 1568 1573 1574 1578 1581 1582 1584 1586 1587 1590
#  1591 1592 1593 1594 1595 1596 1597 1598 1599 1600 1601]
# [12]

# %% [markdown]
# # Addendums

# %%
import pandas as pd
import re
import unicodedata

# Load the CSV file
df = pd.read_csv('/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/03_raw/rawdata_cluster12_style_G_addendums.csv', dtype={'estimated_time_to_construct': str})

df['q_id'] = df['q_id'].astype('Int64')
df['cluster'] = df['cluster'].astype('Int64')


######################################################################################################################################
########################################
#STEP 1 MERGE COLUMNS

def merge_columns(df):
    merge_columns_dict = {
        "escalated_cost_x_1000": [
            "escalated costs x 1000",
            "estimated cost x 1000 escalated",
            "estimated cost x 1000 escalated without itcca",
            "escalated cost x 1000",
            "sum of allocated escalated cost"
        ],
        "estimated_cost_x_1000": [
            "estimated cost x 1000",
            "allocated_cost",
            "sum of allocated constant cost"
        ],
        "estimated_time_to_construct": [
            "estimated time to construct",
            "estimated time  to construct"
        ],
        "total_estimated_cost_x_1000_escalated": [
            "total estimated cost x 1000 escalalted",
            "total estimated cost x 1000 escalated"
        ],
        "total_estimated_cost_x_1000": [
            "total nu cost",
            "total cost constant"
        ],
        "adnu_cost_rate_x_1000": [
            "adnu cost rate x 1000",
            "cost rate x 1000",
            "cost rate",
            "cost rate constant"
        ],
        "description": ["description"],
        "capacity": [
            "capacity",
            "project size",
            "project mw",
            "mw at poi"
        ],
        "cost_allocation_factor": [
            "cost allocation factor",
            "cost allocatio n factor",
            "cost allocati on factor",
        ],
    }

    # Identify unnamed columns
    unnamed_columns = [col for col in df.columns if pd.isna(col) or col.strip() == "" or col.startswith("Unnamed")]
    if unnamed_columns:
        merge_columns_dict["description"].extend(unnamed_columns)

    for new_col, old_cols in merge_columns_dict.items():
        existing_cols = [col for col in old_cols if col in df.columns]
        if existing_cols:
            df[new_col] = df[existing_cols].bfill(axis=1).iloc[:, 0]
            cols_to_drop = [col for col in existing_cols if col != new_col]
            if cols_to_drop:
                df.drop(columns=cols_to_drop, inplace=True)

    return df

df = merge_columns(df)
df.drop('incremental deliverability', axis=1, inplace=True)

#STEP 2: NAMING CONVENTION
def convert_to_snake_case(column_name):
    column_name = column_name.strip().lower()
    column_name = re.sub(r'[\s\-]+', '_', column_name)
    column_name = re.sub(r'[^\w]', '', column_name)
    return column_name

def clean_string_cell(value):
    if isinstance(value, str):
        value = unicodedata.normalize('NFKD', value).encode('ascii', 'ignore').decode('ascii')
        value = value.replace('\n', ' ').strip()
    return value

df = df.map(clean_string_cell)
df.columns = [convert_to_snake_case(col) for col in df.columns]

required_columns = ['type_of_upgrade', 'cost_allocation_factor']
for col in required_columns:
    if col not in df.columns:
        df[col] = None

 
 
# Step 3: Rename 'Grand Total' to 'Total' in total_estimated_cost_x_1000
if 'total_estimated_cost_x_1000' in df.columns:
    df['total_estimated_cost_x_1000'] = df['total_estimated_cost_x_1000'].replace('Grand Total', 'Total')

# Step 4: Move 'Total' from total_estimated_cost_x_1000 to cost_allocation_factor
if 'total_estimated_cost_x_1000' in df.columns and 'cost_allocation_factor' in df.columns:
    df['cost_allocation_factor'] = df.apply(
        lambda row: 'Total' if str(row['total_estimated_cost_x_1000']) == 'Total' else row['cost_allocation_factor'],
        axis=1
    )
    df['total_estimated_cost_x_1000'] = df['total_estimated_cost_x_1000'].replace('Total', None)


df['item'] = df.apply(
    lambda row: 'no' if (
        (pd.notna(row.get('type_of_upgrade')) and 'Total' in str(row['type_of_upgrade'])) or
        (pd.notna(row.get('cost_allocation_factor')) and 'Total' in str(row['cost_allocation_factor']))
    ) else 'yes',
    axis=1
)
   


# Step 5: Clean the type of upgrade column
   
 
df['type_of_upgrade'] = (
    df['type_of_upgrade']
    .fillna('')  # Temporarily replace NaN with an empty string
    .str.replace(r'\(Note \d+\)', '', regex=True)  # Remove (Note digit)
    .str.strip()  # Strip leading/trailing whitespace
    .str.title()  # Capitalize the first letter of each word
    .str.replace(r'Upgrades$', 'Upgrade', regex=True)  # Fix plural endings
    .replace('', pd.NA)  # Convert empty strings back to NaN
)





mappings = {
    'Reliability Network Upgrade': 'RNU',
    'Local Delivery Network Upgrade': 'LDNU',
    'Local Delivery Network': 'LDNU',
    'Potential Local Delivery Network Upgrade': 'LDNU',
    "Ptos Interconnection Facilities": 'PTO_IF',
    'Area Delivery Network Upgrade': 'ADNU',
    'Reliability Network Upgrade To Physically Interconnect': 'RNU',
    "Reliability Network upgrade To Physically Interconnect": "RNU",
     'Pto': 'PTO_IF',
    "Other Potential Network Upgrade": "OPNU",
    "Conditionally Assigned Network Upgrade": "CANU",
    "Canus": "CANU",
    'Total PTO_IF': 'PTO_IF',
 'Total RNU': 'RNU',
 'Total LDNU': 'LDNU',
 'Total OPNU' : 'OPNU',
 
  
 'Total ADNU': 'ADNU',
  

 
}


#Step 6: Apply mapping and ffill type of upgrade column

if 'type_of_upgrade' in df.columns:
    df['type_of_upgrade'] = df['type_of_upgrade'].apply(
        lambda x: re.sub(r'\bupgrades\b', 'upgrade', x, flags=re.IGNORECASE).strip() if isinstance(x, str) else x
    )
    df['type_of_upgrade'] = df['type_of_upgrade'].apply(
        lambda x: mappings.get(x, x) if isinstance(x, str) else x
    )
    df['type_of_upgrade'] = df['type_of_upgrade'].ffill()   

    
# Step 7: Remove $ signs and convert to numeric
import re

def clean_currency(value):
    """
    Cleans a string by explicitly removing $, *, (Note 2), and similar patterns,
    then converts it to a numeric value.
    """
    if isinstance(value, str):
        # Explicitly remove $, *, and any "(Note ...)"
        value = value.replace('$', '').replace('*', '')
        value = re.sub(r'\(Note \d+\)', '', value)  # Remove patterns like "(Note 2)"
        value = value.replace(',', '').strip()  # Remove commas and extra spaces
    try:
        return pd.to_numeric(value)
    except ValueError:
        return pd.NA  # Return NaN for invalid entries


# Clean the specific columns
for col in ['estimated_cost_x_1000', 'escalated_cost_x_1000', 'total_estimated_cost_x_1000_escalated', 'total_estimated_cost_x_1000', 'adnu_cost_rate_x_1000', 'adnu_cost_rate_x_1000_escalated']:
    if col in df.columns:
        df[col] = df[col].apply(clean_currency)

# Create Total rows
new_rows = []
columns_to_sum = ['estimated_cost_x_1000', 'escalated_cost_x_1000', 'total_estimated_cost_x_1000_escalated',   'adnu_cost_rate_x_1000_escalated']
columns_to_populate = ['cluster', 'req_deliverability', 'latitude', 'longitude', 'capacity', 'point_of_interconnection']

for q_id, group in df.groupby('q_id', as_index=False):
    unique_upgrades = group['type_of_upgrade'].dropna().unique()
    for upgrade in unique_upgrades:
        if pd.isna(upgrade):
            continue
        
        rows = group[group['type_of_upgrade'] == upgrade]

                # Check if a Total row already exists for this (q_id, upgrade)
        total_exists = group[
            (group['type_of_upgrade'] == upgrade) & (group['item'] == 'no')
        ].shape[0] > 0
        
        if total_exists:
             
            continue


 
        
        
        if not total_exists:
            # If only one row exists, duplicate it as the total row
            if len(rows) == 1:

                total_row = {col: '' for col in df.columns}  # Initialize all columns as empty strings

                # Populate the necessary fields
                total_row['q_id'] = q_id
                total_row['type_of_upgrade'] = f"Total {upgrade}"
                total_row['item'] = 'no'

                # Populate specified columns from the existing row
                first_row = rows.iloc[0]
                for col in columns_to_populate:
                    if col in df.columns:
                        total_row[col] = first_row[col]

                # Sum the numeric columns (single row, so it remains the same)
                for col in columns_to_sum:
                    if col in rows.columns:
                        total_row[col] = rows[col].sum()
                    else:
                        total_row[col] = 0  # Default to 0 if column is missing

                new_rows.append(total_row)



 
            
            # If multiple rows exist, sum numeric columns and create a total row
            elif len(rows) > 1:
                total_row = {col: '' for col in df.columns}  # Initialize all columns as empty strings

                # Populate the necessary fields
                total_row['q_id'] = q_id
                total_row['type_of_upgrade'] = f"Total {upgrade}"
                total_row['item'] = 'no'

                # Populate the specified columns from the first row in the group
                first_row = rows.iloc[0]
                for col in columns_to_populate:
                    if col in df.columns:
                        total_row[col] = first_row[col]

                # Sum the numeric columns
                for col in columns_to_sum:
                    if col in rows.columns:
                        total_row[col] = rows[col].sum()
                    else:
                        total_row[col] = 0  # Default to 0 if column is missing

                new_rows.append(total_row)
 



      

if new_rows:
    total_rows_df = pd.DataFrame(new_rows)
    for col in df.columns:
        if col not in total_rows_df.columns:
            total_rows_df[col] = None
    total_rows_df = total_rows_df[df.columns]
    df = pd.concat([df, total_rows_df], ignore_index=True)

df.reset_index(drop=True, inplace=True)

# Update 'item' column based on Total in type_of_upgrade or cost_allocation_factor
df['item'] = df.apply(
    lambda row: 'no' if (
        'Total' in str(row.get('type_of_upgrade', '')) or 
        'Total' in str(row.get('cost_allocation_factor', ''))
    ) else 'yes',
    axis=1
)


# Step 8: Move 'item' column next to 'type_of_upgrade'
if 'item' in df.columns and 'type_of_upgrade' in df.columns:
    cols = df.columns.tolist()
    item_index = cols.index('item')
    type_index = cols.index('type_of_upgrade')
    if item_index < type_index:
        cols.insert(type_index + 1, cols.pop(item_index))
    else:
        cols.insert(type_index + 1, cols.pop(item_index))
    df = df[cols]

# Step 9: Remove "Total" values from cost_allocation_factor if they appear in type_of_upgrade
if 'cost_allocation_factor' in df.columns and 'type_of_upgrade' in df.columns:
    df['cost_allocation_factor'] = df.apply(
        lambda row: None if (
            pd.notna(row['type_of_upgrade']) and 'Total' in str(row['type_of_upgrade'])
        ) else row.get('cost_allocation_factor'),
        axis=1
    )
    

if 'cost_allocation_factor' in df.columns and 'type_of_upgrade' in df.columns:
    df['cost_allocation_factor'] = df.apply(
        lambda row: None if 'Total' in str(row.get('cost_allocation_factor', '')) else row.get('cost_allocation_factor'),
        axis=1
    )



def clean_estimated_time(value):
    if isinstance(value, str):
        value = re.sub(r'(\d+(?:-\w+)*)\s+\w+.*$', r'\1', value, flags=re.IGNORECASE).strip()
    return value

if 'estimated_time_to_construct' in df.columns:
    df['estimated_time_to_construct'] = df['estimated_time_to_construct'].apply(clean_estimated_time)

if 'type_of_upgrade' in df.columns:
    df['type_of_upgrade'] = df['type_of_upgrade'].apply(
        lambda x: re.sub(r'\s*\(note \d+\)', '', x, flags=re.IGNORECASE).strip() if isinstance(x, str) else x
    )

 



if 'type_of_upgrade' in df.columns:
    df['type_of_upgrade'] = df['type_of_upgrade'].apply(
        lambda x: re.sub(r'\bupgrades\b', 'upgrade', x, flags=re.IGNORECASE).strip() if isinstance(x, str) else x
    )
    df['type_of_upgrade'] = df['type_of_upgrade'].apply(
        lambda x: mappings.get(x, x) if isinstance(x, str) else x
    )
    df['type_of_upgrade'] = df['type_of_upgrade'].ffill()

if 'upgrade' in df.columns and 'type_of_upgrade' in df.columns and 'q_id' in df.columns:
    df['upgrade'] = df.groupby(['q_id', 'type_of_upgrade'])['upgrade'].ffill()

if 'type_of_upgrade' in df.columns:
    previous_type_of_upgrade = None
    for i in range(len(df)):
        if df.at[i, 'type_of_upgrade'] == 'Total':
            if previous_type_of_upgrade is not None:
                df.at[i, 'type_of_upgrade'] = previous_type_of_upgrade
        else:
            previous_type_of_upgrade = df.at[i, 'type_of_upgrade']

numeric_columns = [
    'cost_allocation_factor',
    'estimated_cost_x_1000',
    'estimated_time_to_construct',
    'total_estimated_cost_x_1000_escalated',
    'adnu_cost_rate_x_1000',
    'escalated_cost_x_1000',
    'estimated_cost_x_1000_escalated_without_itcca',
    'adnu_cost_rate_x_1000_escalated'
]
non_numeric_columns = ['type_of_upgrade', 'upgrade', 'description']

for col in non_numeric_columns:
    if col in df.columns:
        df[col] = df[col].apply(lambda x: 'None' if pd.isna(x) else x)

for col in numeric_columns:
    if col in df.columns:
        df[col] = df[col].replace('-', pd.NA)
        df[col] = df[col].fillna(0)

if 'original_order' in df.columns and 'q_id' in df.columns:
    df['original_order'] = df.index
    df = df.sort_values(by=['q_id', 'original_order'], ascending=[True, True])
    df = df.drop(columns=['original_order'])


def reorder_columns(df):
    """
    Reorders the columns of the DataFrame based on the specified order.

    Args:
        df (pd.DataFrame): The DataFrame to reorder.

    Returns:
        pd.DataFrame: The reordered DataFrame.
    """
    desired_order = [
        "q_id",
        "cluster",
        "req_deliverability",
        "latitude",
        "longitude",
        "capacity",
        "point_of_interconnection",
        "type_of_upgrade",
        "upgrade",
        "description",
        "cost_allocation_factor",
        "estimated_cost_x_1000",
        "escalated_cost_x_1000",
        "total_estimated_cost_x_1000",
        "total_estimated_cost_x_1000_escalated",
        "estimated_time_to_construct",
    ]

    # Start with desired columns that exist in the DataFrame
    existing_desired = [col for col in desired_order if col in df.columns]

    # Then add the remaining columns
    remaining = [col for col in df.columns if col not in existing_desired]

    # Combine the two lists
    new_order = existing_desired + remaining

    # Reorder the DataFrame
    df = df[new_order]

    return df        


df= reorder_columns(df)


# Save itemized and totals separately
if 'item' in df.columns:
    itemized_df = df[df['item'] == 'yes']
    itemized_df.to_csv('/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_itemized_addendums.csv', index=False)

    totals_columns = ['upgrade', 'description', 'cost_allocation_factor', 'estimated_time_to_construct']
    totals_df = df[df['item'] == 'no'].drop(columns=totals_columns, errors='ignore')
    totals_df.to_csv('/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_total_addendums.csv', index=False)

print(f"Itemized rows saved to 'costs_phase_1_cluster_12_style_G_itemized.csv'.")
print(f"Filtered Total rows saved to 'costs_phase_1_cluster_12_style_G_total.csv'.")


if 'type_of_upgrade' in df.columns:
    print(df['type_of_upgrade'].unique())

if 'q_id' in df.columns:
    print(df['q_id'].unique())

if 'cluster' in df.columns:
    print(df['cluster'].unique())
# Out:
# Itemized rows saved to 'costs_phase_1_cluster_12_style_G_itemized.csv'.
# Filtered Total rows saved to 'costs_phase_1_cluster_12_style_G_total.csv'.
# ['LDNU' 'ADNU' 'RNU' 'PTO_IF']
# [1542 1543 1546 1549 1550 1552 1554 1555 1564 1565 1568 1574 1578 1582
#  1584 1586 1587 1591 1592 1593 1594 1595 1596 1598 1599 1601]
# [12]

# %% [markdown]
# # Merge the Addendum and Original

# %%
import pandas as pd
import numpy as np

def load_data(file_path, char_columns):
    """
    Load a CSV file and ensure specific columns are treated as character, others as numeric.
    """
 # Get columns available in the dataset
    available_columns = pd.read_csv(file_path, nrows=0).columns
    
    # Restrict to char_columns that are present in the dataset
    char_columns_in_dataset = [col for col in char_columns if col in available_columns]
    
    # Load the dataset, treating char_columns_in_dataset as strings
    df = pd.read_csv(
        file_path,
        dtype={col: str for col in char_columns_in_dataset},
        na_values=[],  # Disable automatic NaN interpretation
        keep_default_na=False  # Prevent treating "None" as NaN
    )

    
    
    
    # Convert all other columns to numeric
    #for col in df.columns:
    #    if col not in char_columns:
    #        df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0)
    
    return df

def save_data(df, file_path, char_columns):
    """
    Save a dataframe to a CSV file, ensuring specific columns are treated as character.
    """
    for col in char_columns:
        if col in df.columns:
            df[col] = df[col].astype(str)
    df.to_csv(file_path, index=False)

def merge_with_addendums(itemized, itemized_addendums, total, total_addendums):
    # Add an 'original' column to the datasets
    itemized['original'] = "yes"
    total['original'] = "yes"
    
    


    # Preserve the original row order
    itemized['row_order'] = pd.to_numeric(itemized.index, errors="coerce")
    total['row_order'] = pd.to_numeric(total.index, errors="coerce")
    
    # Ensure q_id is numeric for comparison
    itemized['q_id'] = pd.to_numeric(itemized['q_id'], errors="coerce")
    itemized_addendums['q_id'] = pd.to_numeric(itemized_addendums['q_id'], errors="coerce")
    total['q_id'] = pd.to_numeric(total['q_id'], errors="coerce")
    total_addendums['q_id'] = pd.to_numeric(total_addendums['q_id'], errors="coerce")


    
    # Columns for conditional replacement
    conditional_columns = ["req_deliverability", "latitude", "longitude", "capacity", "point_of_interconnection"]
    
    # Prepare a list to collect the updated itemized rows
    updated_itemized_rows = []
    
    # Merge itemized and itemized_addendums
    for q_id in itemized_addendums['q_id'].unique():
        for upgrade_type in itemized_addendums['type_of_upgrade'].unique():
            addendum_rows = itemized_addendums[
                (itemized_addendums['q_id'] == q_id) &
                (itemized_addendums['type_of_upgrade'] == upgrade_type)
            ]
            if not addendum_rows.empty:
                mask = (itemized['q_id'] == q_id) & (itemized['type_of_upgrade'] == upgrade_type)
                original_rows = itemized[mask]
                print(f"Processing itemized: q_id={q_id}, type_of_upgrade={upgrade_type}")
                print(f"Length of addendum_rows: {len(addendum_rows)}")
                print(f"Length of original_rows: {len(original_rows)}")
                print(f"addendum_rows:\n{addendum_rows}")
                print(f"original_rows:\n{original_rows}")

                # For specified columns, replace only if addendum values are non-empty
                for col in conditional_columns:
                    if col in addendum_rows.columns and col in original_rows.columns:
                        # Debugging outputs
                        print(f"Before replacement: {col}")
                        print(f"Addendum values:\n{addendum_rows[col]}")
                        print(f"Original values:\n{original_rows[col]}")

                        # Replace blanks with NaN in addendum
                        addendum_rows[col] = addendum_rows[col].replace("", pd.NA)

                        # Combine values: prefer addendum if not NaN, else take original
                        addendum_rows[col] = addendum_rows[col].combine_first(original_rows[col].reset_index(drop=True))

                        # Replace NaN back with blank string for consistency
                        addendum_rows[col] = addendum_rows[col].fillna("")

                        print(f"After replacement: {col}")
                        print(f"Updated addendum values:\n{addendum_rows[col]}")

                # Match row_order with addendum_rows length
                # Adjust lengths by truncating the longer one
                '''
                if len(addendum_rows) > len(original_rows):
                    addendum_rows = addendum_rows.iloc[:len(original_rows)]
                elif len(addendum_rows) < len(original_rows):
                    original_rows = original_rows.iloc[:len(addendum_rows)]
                '''

                # Align the length of original_rows to addendum_rows
                original_rows = original_rows.reset_index(drop=True)
                addendum_rows = addendum_rows.reset_index(drop=True)
                
                if len(addendum_rows) > len(original_rows):
                    # Pad original_rows
                    extra_rows = pd.DataFrame({col: pd.NA for col in original_rows.columns}, index=range(len(addendum_rows) - len(original_rows)))
                    original_rows = pd.concat([original_rows, extra_rows], ignore_index=True)
                elif len(addendum_rows) < len(original_rows):
                    # Truncate original_rows
                    original_rows = original_rows.iloc[:len(addendum_rows)].reset_index(drop=True)
                

                     
                
                # Find non-character columns missing in the addendum dataset
                missing_cols = set(itemized.columns) - set(addendum_rows.columns) - set(char_columns)
                for col in missing_cols:
                    addendum_rows[col] = 0 
                itemized.loc[mask, 'original'] = "no"
                updated_itemized_rows.append(addendum_rows.assign(original="no", row_order=original_rows['row_order'].values[:len(addendum_rows)]))
                itemized = itemized[~mask]
    
    if updated_itemized_rows:
        updated_itemized = pd.concat([itemized] + updated_itemized_rows, ignore_index=True)
    else:
        updated_itemized = itemized.copy()
    

    updated_itemized["row_order"] = pd.to_numeric(updated_itemized["row_order"], errors="coerce").fillna(-1).astype(int)
    updated_itemized = updated_itemized.sort_values(by="row_order").drop(columns=["row_order"]).reset_index(drop=True)
    
    updated_total_rows = []
    
    for q_id in total_addendums['q_id'].unique():
        for upgrade_type in total_addendums['type_of_upgrade'].unique():
            addendum_row = total_addendums[
                (total_addendums['q_id'] == q_id) &
                (total_addendums['type_of_upgrade'] == upgrade_type)
            ]
            if not addendum_row.empty:
                mask = (total['q_id'] == q_id) & (total['type_of_upgrade'] == upgrade_type)
                original_row = total[mask]
                print(f"Processing itemized: q_id={q_id}, type_of_upgrade={upgrade_type}")
                print(f"Length of addendum_rows: {len(addendum_rows)}")
                print(f"Length of original_rows: {len(original_rows)}")
                print(f"addendum_rows:\n{addendum_rows}")
                print(f"original_rows:\n{original_rows}")

                # For specified columns, replace only if addendum values are non-empty
                for col in conditional_columns:
                    if col in addendum_rows.columns and col in original_rows.columns:
                        # Debugging outputs
                        print(f"Before replacement: {col}")
                        print(f"Addendum values:\n{addendum_rows[col]}")
                        print(f"Original values:\n{original_rows[col]}")

                        # Replace blanks with NaN in addendum
                        addendum_rows[col] = addendum_rows[col].replace("", pd.NA)

                        # Combine values: prefer addendum if not NaN, else take original
                        addendum_rows[col] = addendum_rows[col].combine_first(original_rows[col].reset_index(drop=True))

                        # Replace NaN back with blank string for consistency
                        addendum_rows[col] = addendum_rows[col].fillna("")

                        print(f"After replacement: {col}")
                        print(f"Updated addendum values:\n{addendum_rows[col]}")

                        
                        

                        
                
                # Find non-character columns missing in the addendum dataset
                missing_cols = set(total.columns) - set(addendum_row.columns) - set(char_columns)
                for col in missing_cols:
                    addendum_row[col] = 0 
                total.loc[mask, 'original'] = "no"
                updated_total_rows.append(addendum_row.assign(original="no", row_order=original_row['row_order'].values[:len(addendum_row)]))
                total = total[~mask]
    
    if updated_total_rows:
        updated_total = pd.concat([total] + updated_total_rows, ignore_index=True)
    else:
        updated_total = total.copy()
    
     
    

    updated_total["row_order"] = pd.to_numeric(updated_total["row_order"], errors="coerce").fillna(-1).astype(int)
    updated_total = updated_total.sort_values(by="row_order").drop(columns=["row_order"]).reset_index(drop=True)
    # Fill missing columns with zeros in the updated datasets
    for col in set(itemized.columns) - set(updated_itemized.columns):
        updated_itemized[col] = 0
    
    for col in set(total.columns) - set(updated_total.columns):
        updated_total[col] = 0

    # Move the 'original' column to the last position
    updated_itemized = updated_itemized[[col for col in updated_itemized.columns if col != 'original'] + ['original']]
    updated_total = updated_total[[col for col in updated_total.columns if col != 'original'] + ['original']]

     

    

     


     


        # Drop the row_order column directly
    if "row_order" in updated_itemized.columns:
        updated_itemized = updated_itemized.drop(columns=["row_order"]).reset_index(drop=True)

    if "row_order" in updated_total.columns:
        updated_total = updated_total.drop(columns=["row_order"]).reset_index(drop=True)


  
 
    
    
    return updated_itemized, updated_total

# Define the character columns
char_columns = [
    "req_deliverability", "point_of_interconnection", "type_of_upgrade",
    "upgrade", "description", "estimated_time_to_construct", "original", "item"
]




itemized = load_data("/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_itemized.csv", char_columns)
itemized_addendums = load_data("/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_itemized_addendums.csv", char_columns)
total = load_data("/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_total.csv", char_columns)
total_addendums = load_data("/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_total_addendums.csv", char_columns)


updated_itemized, updated_total = merge_with_addendums(itemized, itemized_addendums, total, total_addendums)

# Drop the specified columns from the updated datasets
columns_to_drop = [ "upgrade_classification","estimated", "caiso_queue", "project_type", "dependent_system_upgrade"]

# For the itemized dataset
updated_itemized = updated_itemized.drop(columns=[col for col in columns_to_drop if col in updated_itemized.columns], errors='ignore')

# For the total dataset
updated_total = updated_total.drop(columns=[col for col in columns_to_drop if col in updated_total.columns], errors='ignore')



# List of columns to process with ffill and bfill
columns_to_fill = ["point_of_interconnection", "latitude", "longitude", "req_deliverability", "capacity"]

# Replace empty strings with NaN for the specified columns
for col in columns_to_fill:
    updated_itemized[col] = updated_itemized[col].replace('', np.nan)
    updated_total[col] = updated_total[col].replace('', np.nan)

# Sort by q_id while maintaining other column order (stable sorting)
updated_itemized = updated_itemized.sort_values(by=["q_id"], kind="stable").reset_index(drop=True)
updated_total = updated_total.sort_values(by=["q_id"], kind="stable").reset_index(drop=True)

# Apply forward-fill and backward-fill for the specified columns within each q_id group
for col in columns_to_fill:
    updated_itemized[col] = (
        updated_itemized.groupby("q_id")[col]
        .apply(lambda group: group.ffill().bfill())
        .reset_index(drop=True)
    )
    updated_total[col] = (
        updated_total.groupby("q_id")[col]
        .apply(lambda group: group.ffill().bfill())
        .reset_index(drop=True)
    )

# Replace NaN back with empty strings for consistency
for col in columns_to_fill:
    updated_itemized[col] = updated_itemized[col].replace(np.nan, '')
    updated_total[col] = updated_total[col].replace(np.nan, '')

 
 







# Save the updated datasets
save_data(updated_itemized, "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/01_clean/costs_phase_1_cluster_12_style_G_itemized_updated.csv", char_columns)
save_data(updated_total, "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/01_clean/costs_phase_1_cluster_12_style_G_total_updated.csv", char_columns)



# Save the results
save_data(updated_itemized, "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/01_clean/costs_phase_1_cluster_12_style_G_itemized_updated.csv", char_columns)
save_data(updated_total, "/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/01_clean/costs_phase_1_cluster_12_style_G_total_updated.csv", char_columns)
# Out:
# Processing itemized: q_id=1542, type_of_upgrade=LDNU
# Length of addendum_rows: 1
# Length of original_rows: 1
# addendum_rows:
#    q_id  cluster req_deliverability   latitude   longitude capacity  \
# 0  1542       12               Full  40.461345 -124.043106
#
#         point_of_interconnection type_of_upgrade upgrade description  \
# 0  Bridgeville Substation 115 kV            LDNU    None
#
#   cost_allocation_factor  estimated_cost_x_1000  escalated_cost_x_1000  \
# 0                      0                    0.0                    0.0
#
#   total_estimated_cost_x_1000 estimated_time_to_construct item  \
# 0                                                     0.0  yes
#
#   upgrade_classification  adnu_cost_rate_x_1000
# 0                                           0.0
# original_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 19  1542       12               Full  40.461345 -124.043106
#
#          point_of_interconnection type_of_upgrade  \
# 19  Bridgeville Substation 115 kV            LDNU
#
#                                               upgrade  \
# 19  Re-conductor Eagle Rock- Fulton-Silverado 115 ...
#
#                                           description cost_allocation_factor  \
# 19  Re-conductor Eagle Rock-Fulton- Silverado 115 ...                  7.20%
#
#     estimated_cost_x_1000  escalated_cost_x_1000 total_estimated_cost_x_1000  \
# 19                 1747.0                 1997.0
#
#    estimated_time_to_construct item upgrade_classification  \
# 19                        22.0  yes
#
#     adnu_cost_rate_x_1000 original  row_order
# 19                    0.0      yes         19
# Before replacement: req_deliverability
# Addendum values:
# 0    Full
# Name: req_deliverability, dtype: object
# Original values:
# 19    Full
# Name: req_deliverability, dtype: object
# After replacement: req_deliverability
# Updated addendum values:
# 0    Full
# Name: req_deliverability, dtype: object
# Before replacement: latitude
# Addendum values:
# 0    40.461345
# Name: latitude, dtype: float64
# Original values:
# 19    40.461345
# Name: latitude, dtype: float64
# After replacement: latitude
# Updated addendum values:
# 0    40.461345
# Name: latitude, dtype: float64
# Before replacement: longitude
# Addendum values:
# 0   -124.043106
# Name: longitude, dtype: float64
# Original values:
# 19   -124.043106
# Name: longitude, dtype: float64
# After replacement: longitude
# Updated addendum values:
# 0   -124.043106
# Name: longitude, dtype: float64
# Before replacement: capacity
# Addendum values:
# 0
# Name: capacity, dtype: object
# Original values:
# 19
# Name: capacity, dtype: object
# After replacement: capacity
# Updated addendum values:
# 0
# Name: capacity, dtype: object
# Before replacement: point_of_interconnection
# Addendum values:
# 0    Bridgeville Substation 115 kV
# Name: point_of_interconnection, dtype: object
# Original values:
# 19    Bridgeville Substation 115 kV
# Name: point_of_interconnection, dtype: object
# After replacement: point_of_interconnection
# Updated addendum values:
# 0    Bridgeville Substation 115 kV
# Name: point_of_interconnection, dtype: object
# Processing itemized: q_id=1542, type_of_upgrade=ADNU
# Length of addendum_rows: 2
# Length of original_rows: 2
# addendum_rows:
#    q_id  cluster req_deliverability   latitude   longitude capacity  \
# 1  1542       12               Full  40.461345 -124.043106    100.0
# 2  1542       12               Full  40.461345 -124.043106    100.0
#
#         point_of_interconnection type_of_upgrade  \
# 1  Bridgeville Substation 115 kV            ADNU
# 2  Bridgeville Substation 115 kV            ADNU
#
#                                              upgrade description  \
# 1  New Delevan 500 kV station on Table Mountain-V...        None
# 2  New Humboldt-Trinity and Trinity- Cottonwood 1...        None
#
#   cost_allocation_factor  estimated_cost_x_1000  escalated_cost_x_1000  \
# 1                      0                29744.0                35515.0
# 2                      0               318000.0               379692.0
#
#   total_estimated_cost_x_1000 estimated_time_to_construct item  \
# 1                    523500.0                         0.0  yes
# 2                    318000.0                         0.0  yes
#
#   upgrade_classification  adnu_cost_rate_x_1000
# 1                                         297.4
# 2                                        3180.0
# original_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 20  1542       12               Full  40.461345 -124.043106    100.0
# 21  1542       12               Full  40.461345 -124.043106    100.0
#
#          point_of_interconnection type_of_upgrade  \
# 20  Bridgeville Substation 115 kV            ADNU
# 21  Bridgeville Substation 115 kV            ADNU
#
#                                               upgrade description  \
# 20  New Delevan 500 kV station on Table Mountain-V...        None
# 21  New Humboldt-Trinity and Trinity- Cottonwood 1...        None
#
#    cost_allocation_factor  estimated_cost_x_1000  escalated_cost_x_1000  \
# 20                      0                28616.0                34167.0
# 21                      0               244615.0               292071.0
#
#    total_estimated_cost_x_1000 estimated_time_to_construct item  \
# 20                    523500.0                         0.0  yes
# 21                    318000.0                         0.0  yes
#
#    upgrade_classification  adnu_cost_rate_x_1000 original  row_order
# 20                                         286.2      yes         20
# 21                                        2446.2      yes         21
# Before replacement: req_deliverability
# Addendum values:
# 1    Full
# 2    Full
# Name: req_deliverability, dtype: object
# Original values:
# 20    Full
# 21    Full
# Name: req_deliverability, dtype: object
# After replacement: req_deliverability
# Updated addendum values:
# 1    Full
# 2    Full
# Name: req_deliverability, dtype: object
# Before replacement: latitude
# Addendum values:
# 1    40.461345
# 2    40.461345
# Name: latitude, dtype: float64
# Original values:
# 20    40.461345
# 21    40.461345
# Name: latitude, dtype: float64
# After replacement: latitude
# Updated addendum values:
# 1    40.461345
# 2    40.461345
# Name: latitude, dtype: float64
# Before replacement: longitude
# Addendum values:
# 1   -124.043106
# 2   -124.043106
# Name: longitude, dtype: float64
# Original values:
# 20   -124.043106
# 21   -124.043106
# Name: longitude, dtype: float64
# After replacement: longitude
# Updated addendum values:
# 1   -124.043106
# 2   -124.043106
# Name: longitude, dtype: float64
# Before replacement: capacity
# Addendum values:
# 1    100.0
# 2    100.0
# Name: capacity, dtype: object
# Original values:
# 20    100.0
# 21    100.0
# Name: capacity, dtype: object
# After replacement: capacity
# Updated addendum values:
# 1    100.0
# 2    100.0
# Name: capacity, dtype: object
# Before replacement: point_of_interconnection
# Addendum values:
# 1    Bridgeville Substation 115 kV
# 2    Bridgeville Substation 115 kV
# Name: point_of_interconnection, dtype: object
# Original values:
# 20    Bridgeville Substation 115 kV
# 21    Bridgeville Substation 115 kV
# Name: point_of_interconnection, dtype: object
# After replacement: point_of_interconnection
# Updated addendum values:
# 1    Bridgeville Substation 115 kV
# 2    Bridgeville Substation 115 kV
# Name: point_of_interconnection, dtype: object
# Processing itemized: q_id=1543, type_of_upgrade=LDNU
# Length of addendum_rows: 2
# Length of original_rows: 2
# addendum_rows:
#    q_id  cluster req_deliverability   latitude  longitude capacity  \
# 3  1543       12               Full  39.106761 -122.26843
# 4  1543       12               Full  39.106761 -122.26843
#
#     point_of_interconnection type_of_upgrade  \
# 3  Cortina Substation 115 kV            LDNU
# 4  Cortina Substation 115 kV            LDNU
#
#                                              upgrade  \
# 3  Re-conductor Eagle Rock- Fulton-Silverado 115 ...
# 4  Re-conductor Fulton- Hopland 60 kV Line (Fitch...
#
#                                          description cost_allocation_factor  \
# 3  Re-conductor Eagle Rock-Fulton- Silverado 115 ...                 35.38%
# 4  Re-conductor Fulton-Hopland 60 kV Line (Fitch ...                 32.15%
#
#    estimated_cost_x_1000  escalated_cost_x_1000 total_estimated_cost_x_1000  \
# 3                 8588.0                 9814.0
# 4                12348.0                14111.0
#
#   estimated_time_to_construct item upgrade_classification  \
# 3                        22.0  yes
# 4                        22.0  yes
#
#    adnu_cost_rate_x_1000
# 3                    0.0
# 4                    0.0
# original_rows:
#     q_id  cluster req_deliverability   latitude  longitude capacity  \
# 35  1543       12               Full  39.106761 -122.26843
# 36  1543       12               Full  39.106761 -122.26843
#
#      point_of_interconnection type_of_upgrade  \
# 35  Cortina Substation 115 kV            LDNU
# 36  Cortina Substation 115 kV            LDNU
#
#                                               upgrade  \
# 35  Re-conductor Eagle Rock- Fulton-Silverado 115 ...
# 36  Re-conductor Fulton- Hopland 60 kV Line (Fitch...
#
#                                           description cost_allocation_factor  \
# 35  Re-conductor Eagle Rock-Fulton- Silverado 115 ...                 32.83%
# 36  Re-conductor Fulton-Hopland 60 kV Line (Fitch ...                 32.15%
#
#     estimated_cost_x_1000  escalated_cost_x_1000 total_estimated_cost_x_1000  \
# 35                 7970.0                 9108.0
# 36                12348.0                14111.0
#
#    estimated_time_to_construct item upgrade_classification  \
# 35                        22.0  yes
# 36                        22.0  yes
#
#     adnu_cost_rate_x_1000 original  row_order
# 35                    0.0      yes         35
# 36                    0.0      yes         36
# Before replacement: req_deliverability
# Addendum values:
# 3    Full
# 4    Full
# Name: req_deliverability, dtype: object
# Original values:
# 35    Full
# 36    Full
# Name: req_deliverability, dtype: object
# After replacement: req_deliverability
# Updated addendum values:
# 3    Full
# 4    Full
# Name: req_deliverability, dtype: object
# Before replacement: latitude
# Addendum values:
# 3    39.106761
# 4    39.106761
# Name: latitude, dtype: float64
# Original values:
# 35    39.106761
# 36    39.106761
# Name: latitude, dtype: float64
# After replacement: latitude
# Updated addendum values:
# 3    39.106761
# 4    39.106761
# Name: latitude, dtype: float64
# Before replacement: longitude
# Addendum values:
# 3   -122.26843
# 4   -122.26843
# Name: longitude, dtype: float64
# Original values:
# 35   -122.26843
# 36   -122.26843
# Name: longitude, dtype: float64
# After replacement: longitude
# Updated addendum values:
# 3   -122.26843
# 4   -122.26843
# Name: longitude, dtype: float64
# Before replacement: capacity
# Addendum values:
# 3
# 4
# Name: capacity, dtype: object
# Original values:
# 35
# 36
# Name: capacity, dtype: object
# After replacement: capacity
# Updated addendum values:
# 3
# 4
# Name: capacity, dtype: object
# Before replacement: point_of_interconnection
# Addendum values:
# 3    Cortina Substation 115 kV
# 4    Cortina Substation 115 kV
# Name: point_of_interconnection, dtype: object
# Original values:
# 35    Cortina Substation 115 kV
# 36    Cortina Substation 115 kV
# Name: point_of_interconnection, dtype: object
# After replacement: point_of_interconnection
# Updated addendum values:
# 3    Cortina Substation 115 kV
# 4    Cortina Substation 115 kV
# Name: point_of_interconnection, dtype: object
# Processing itemized: q_id=1543, type_of_upgrade=ADNU
# Length of addendum_rows: 3
# Length of original_rows: 3
# addendum_rows:
#    q_id  cluster req_deliverability   latitude  longitude capacity  \
# 5  1543       12               Full  39.106761 -122.26843    150.0
# 6  1543       12               Full  39.106761 -122.26843    150.0
# 7  1543       12               Full  39.106761 -122.26843    150.0
#
#     point_of_interconnection type_of_upgrade  \
# 5  Cortina Substation 115 kV            ADNU
# 6  Cortina Substation 115 kV            ADNU
# 7  Cortina Substation 115 kV            ADNU
#
#                                              upgrade description  \
# 5  New Delevan 500 kV station on Table Mountain-V...        None
# 6                    Reconductor Vaca-Parkway 230 kV        None
# 7  Contra Costa to Tesla and Newark 230 kV lines ...        None
#
#   cost_allocation_factor  estimated_cost_x_1000  escalated_cost_x_1000  \
# 5                      0                44616.0                53272.0
# 6                      0                 7503.0                 8575.0
# 7                      0                25934.0                30966.0
#
#   total_estimated_cost_x_1000 estimated_time_to_construct item  \
# 5                    523500.0                         0.0  yes
# 6                     84679.0                         0.0  yes
# 7                    322000.0                         0.0  yes
#
#   upgrade_classification  adnu_cost_rate_x_1000
# 5                                         297.4
# 6                                          50.0
# 7                                         172.9
# original_rows:
#     q_id  cluster req_deliverability   latitude  longitude capacity  \
# 37  1543       12               Full  39.106761 -122.26843    150.0
# 38  1543       12               Full  39.106761 -122.26843    150.0
# 39  1543       12               Full  39.106761 -122.26843    150.0
#
#      point_of_interconnection type_of_upgrade  \
# 37  Cortina Substation 115 kV            ADNU
# 38  Cortina Substation 115 kV            ADNU
# 39  Cortina Substation 115 kV            ADNU
#
#                                               upgrade description  \
# 37  New Delevan 500 kV station on Table Mountain-V...        None
# 38                    Reconductor Vaca-Parkway 230 kV        None
# 39  Contra Costa to Tesla and Newark 230 kV lines ...        None
#
#    cost_allocation_factor  estimated_cost_x_1000  escalated_cost_x_1000  \
# 37                      0                42924.0                51251.0
# 38                      0                 7503.0                 8575.0
# 39                      0                17820.0                21277.0
#
#    total_estimated_cost_x_1000 estimated_time_to_construct item  \
# 37                    523500.0                         0.0  yes
# 38                     84679.0                         0.0  yes
# 39                    322000.0                         0.0  yes
#
#    upgrade_classification  adnu_cost_rate_x_1000 original  row_order
# 37                                         286.2      yes         37
# 38                                          50.0      yes         38
# 39                                         118.8      yes         39
# Before replacement: req_deliverability
# Addendum values:
# 5    Full
# 6    Full
# 7    Full
# Name: req_deliverability, dtype: object
# Original values:
# 37    Full
# 38    Full
# 39    Full
# Name: req_deliverability, dtype: object
# After replacement: req_deliverability
# Updated addendum values:
# 5    Full
# 6    Full
# 7    Full
# Name: req_deliverability, dtype: object
# Before replacement: latitude
# Addendum values:
# 5    39.106761
# 6    39.106761
# 7    39.106761
# Name: latitude, dtype: float64
# Original values:
# 37    39.106761
# 38    39.106761
# 39    39.106761
# Name: latitude, dtype: float64
# After replacement: latitude
# Updated addendum values:
# 5    39.106761
# 6    39.106761
# 7    39.106761
# Name: latitude, dtype: float64
# Before replacement: longitude
# Addendum values:
# 5   -122.26843
# 6   -122.26843
# 7   -122.26843
# Name: longitude, dtype: float64
# Original values:
# 37   -122.26843
# 38   -122.26843
# 39   -122.26843
# Name: longitude, dtype: float64
# After replacement: longitude
# Updated addendum values:
# 5   -122.26843
# 6   -122.26843
# 7   -122.26843
# Name: longitude, dtype: float64
# Before replacement: capacity
# Addendum values:
# 5    150.0
# 6    150.0
# 7    150.0
# Name: capacity, dtype: object
# Original values:
# 37    150.0
# 38    150.0
# 39    150.0
# Name: capacity, dtype: object
# After replacement: capacity
# Updated addendum values:
# 5    150.0
# 6    150.0
# 7    150.0
# Name: capacity, dtype: object
# Before replacement: point_of_interconnection
# Addendum values:
# 5    Cortina Substation 115 kV
# 6    Cortina Substation 115 kV
# 7    Cortina Substation 115 kV
# Name: point_of_interconnection, dtype: object
# Original values:
# 37    Cortina Substation 115 kV
# 38    Cortina Substation 115 kV
# 39    Cortina Substation 115 kV
# Name: point_of_interconnection, dtype: object
# After replacement: point_of_interconnection
# Updated addendum values:
# 5    Cortina Substation 115 kV
# 6    Cortina Substation 115 kV
# 7    Cortina Substation 115 kV
# Name: point_of_interconnection, dtype: object
# Processing itemized: q_id=1546, type_of_upgrade=LDNU
# Length of addendum_rows: 2
# Length of original_rows: 2
# addendum_rows:
#    q_id  cluster req_deliverability   latitude   longitude capacity  \
# 8  1546       12               Full  38.911182 -123.681665
# 9  1546       12               Full  38.911182 -123.681665
#
#   point_of_interconnection type_of_upgrade  \
# 8  Elk  Gualala 60 kV Line            LDNU
# 9  Elk  Gualala 60 kV Line            LDNU
#
#                                              upgrade  \
# 8  Re-conductor Eagle Rock- Fulton-Silverado 115 ...
# 9  Re-conductor Fulton- Hopland 60 kV Line (Fitch...
#
#                                          description cost_allocation_factor  \
# 8  Re-conductor Eagle Rock-Fulton- Silverado 115 ...                 22.07%
# 9  Re-conductor Fulton-Hopland 60 kV Line (Fitch ...                 39.24%
#
#    estimated_cost_x_1000  escalated_cost_x_1000 total_estimated_cost_x_1000  \
# 8                 5357.0                 6122.0
# 9                15070.0                17221.0
#
#   estimated_time_to_construct item upgrade_classification  \
# 8                        22.0  yes
# 9                        22.0  yes
#
#    adnu_cost_rate_x_1000
# 8                    0.0
# 9                    0.0
# original_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 52  1546       12               Full  38.911182 -123.681665
# 53  1546       12               Full  38.911182 -123.681665
#
#    point_of_interconnection type_of_upgrade  \
# 52  Elk  Gualala 60 kV Line            LDNU
# 53  Elk  Gualala 60 kV Line            LDNU
#
#                                               upgrade  \
# 52  Re-conductor Eagle Rock- Fulton-Silverado 115 ...
# 53  Re-conductor Fulton- Hopland 60 kV Line (Fitch...
#
#                                           description cost_allocation_factor  \
# 52  Re-conductor Eagle Rock-Fulton- Silverado 115 ...                 20.48%
# 53  Re-conductor Fulton-Hopland 60 kV Line (Fitch ...                 39.24%
#
#     estimated_cost_x_1000  escalated_cost_x_1000 total_estimated_cost_x_1000  \
# 52                 4972.0                 5681.0
# 53                15070.0                17221.0
#
#    estimated_time_to_construct item upgrade_classification  \
# 52                        22.0  yes
# 53                        22.0  yes
#
#     adnu_cost_rate_x_1000 original  row_order
# 52                    0.0      yes         52
# 53                    0.0      yes         53
# Before replacement: req_deliverability
# Addendum values:
# 8    Full
# 9    Full
# Name: req_deliverability, dtype: object
# Original values:
# 52    Full
# 53    Full
# Name: req_deliverability, dtype: object
# After replacement: req_deliverability
# Updated addendum values:
# 8    Full
# 9    Full
# Name: req_deliverability, dtype: object
# Before replacement: latitude
# Addendum values:
# 8    38.911182
# 9    38.911182
# Name: latitude, dtype: float64
# Original values:
# 52    38.911182
# 53    38.911182
# Name: latitude, dtype: float64
# After replacement: latitude
# Updated addendum values:
# 8    38.911182
# 9    38.911182
# Name: latitude, dtype: float64
# Before replacement: longitude
# Addendum values:
# 8   -123.681665
# 9   -123.681665
# Name: longitude, dtype: float64
# Original values:
# 52   -123.681665
# 53   -123.681665
# Name: longitude, dtype: float64
# After replacement: longitude
# Updated addendum values:
# 8   -123.681665
# 9   -123.681665
# Name: longitude, dtype: float64
# Before replacement: capacity
# Addendum values:
# 8
# 9
# Name: capacity, dtype: object
# Original values:
# 52
# 53
# Name: capacity, dtype: object
# After replacement: capacity
# Updated addendum values:
# 8
# 9
# Name: capacity, dtype: object
# Before replacement: point_of_interconnection
# Addendum values:
# 8    Elk  Gualala 60 kV Line
# 9    Elk  Gualala 60 kV Line
# Name: point_of_interconnection, dtype: object
# Original values:
# 52    Elk  Gualala 60 kV Line
# 53    Elk  Gualala 60 kV Line
# Name: point_of_interconnection, dtype: object
# After replacement: point_of_interconnection
# Updated addendum values:
# 8    Elk  Gualala 60 kV Line
# 9    Elk  Gualala 60 kV Line
# Name: point_of_interconnection, dtype: object
# Processing itemized: q_id=1546, type_of_upgrade=ADNU
# Length of addendum_rows: 3
# Length of original_rows: 3
# addendum_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 10  1546       12               Full  38.911182 -123.681665      0.0
# 11  1546       12               Full  38.911182 -123.681665      0.0
# 12  1546       12               Full  38.911182 -123.681665     30.0
#
#    point_of_interconnection type_of_upgrade  \
# 10  Elk  Gualala 60 kV Line            ADNU
# 11  Elk  Gualala 60 kV Line            ADNU
# 12  Elk  Gualala 60 kV Line            ADNU
#
#                                               upgrade description  \
# 10  New Delevan 500 kV station on Table Mountain-V...        None
# 11  New Humboldt-Trinity and Trinity- Cottonwood 1...        None
# 12  Contra Costa to Tesla and Newark 230 kV lines ...        None
#
#    cost_allocation_factor  estimated_cost_x_1000  escalated_cost_x_1000  \
# 10                      0                    0.0                    0.0
# 11                      0                    0.0                    0.0
# 12                      0                 5187.0                 6193.0
#
#    total_estimated_cost_x_1000 estimated_time_to_construct item  \
# 10                    523500.0                         0.0  yes
# 11                    318000.0                         0.0  yes
# 12                    322000.0                         0.0  yes
#
#    upgrade_classification  adnu_cost_rate_x_1000
# 10                                         297.4
# 11                                        3180.0
# 12                                         172.9
# original_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 54  1546       12               Full  38.911182 -123.681665     30.0
# 55  1546       12               Full  38.911182 -123.681665     30.0
# 56  1546       12               Full  38.911182 -123.681665     30.0
#
#    point_of_interconnection type_of_upgrade  \
# 54  Elk  Gualala 60 kV Line            ADNU
# 55  Elk  Gualala 60 kV Line            ADNU
# 56  Elk  Gualala 60 kV Line            ADNU
#
#                                               upgrade description  \
# 54  New Delevan 500 kV station on Table Mountain-V...        None
# 55  New Humboldt-Trinity and Trinity- Cottonwood 1...        None
# 56  Contra Costa to Tesla and Newark 230 kV lines ...        None
#
#    cost_allocation_factor  estimated_cost_x_1000  escalated_cost_x_1000  \
# 54                      0                 8585.0                10250.0
# 55                      0                73385.0                87621.0
# 56                      0                 3564.0                 4255.0
#
#    total_estimated_cost_x_1000 estimated_time_to_construct item  \
# 54                    523500.0                         0.0  yes
# 55                    318000.0                         0.0  yes
# 56                    322000.0                         0.0  yes
#
#    upgrade_classification  adnu_cost_rate_x_1000 original  row_order
# 54                                         286.2      yes         54
# 55                                        2446.2      yes         55
# 56                                         118.8      yes         56
# Before replacement: req_deliverability
# Addendum values:
# 10    Full
# 11    Full
# 12    Full
# Name: req_deliverability, dtype: object
# Original values:
# 54    Full
# 55    Full
# 56    Full
# Name: req_deliverability, dtype: object
# After replacement: req_deliverability
# Updated addendum values:
# 10    Full
# 11    Full
# 12    Full
# Name: req_deliverability, dtype: object
# Before replacement: latitude
# Addendum values:
# 10    38.911182
# 11    38.911182
# 12    38.911182
# Name: latitude, dtype: float64
# Original values:
# 54    38.911182
# 55    38.911182
# 56    38.911182
# Name: latitude, dtype: float64
# After replacement: latitude
# Updated addendum values:
# 10    38.911182
# 11    38.911182
# 12    38.911182
# Name: latitude, dtype: float64
# Before replacement: longitude
# Addendum values:
# 10   -123.681665
# 11   -123.681665
# 12   -123.681665
# Name: longitude, dtype: float64
# Original values:
# 54   -123.681665
# 55   -123.681665
# 56   -123.681665
# Name: longitude, dtype: float64
# After replacement: longitude
# Updated addendum values:
# 10   -123.681665
# 11   -123.681665
# 12   -123.681665
# Name: longitude, dtype: float64
# Before replacement: capacity
# Addendum values:
# 10     0.0
# 11     0.0
# 12    30.0
# Name: capacity, dtype: object
# Original values:
# 54    30.0
# 55    30.0
# 56    30.0
# Name: capacity, dtype: object
# After replacement: capacity
# Updated addendum values:
# 10     0.0
# 11     0.0
# 12    30.0
# Name: capacity, dtype: object
# Before replacement: point_of_interconnection
# Addendum values:
# 10    Elk  Gualala 60 kV Line
# 11    Elk  Gualala 60 kV Line
# 12    Elk  Gualala 60 kV Line
# Name: point_of_interconnection, dtype: object
# Original values:
# 54    Elk  Gualala 60 kV Line
# 55    Elk  Gualala 60 kV Line
# 56    Elk  Gualala 60 kV Line
# Name: point_of_interconnection, dtype: object
# After replacement: point_of_interconnection
# Updated addendum values:
# 10    Elk  Gualala 60 kV Line
# 11    Elk  Gualala 60 kV Line
# 12    Elk  Gualala 60 kV Line
# Name: point_of_interconnection, dtype: object
# Processing itemized: q_id=1549, type_of_upgrade=ADNU
# Length of addendum_rows: 1
# Length of original_rows: 1
# addendum_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 17  1549       12               Full  37.426372 -121.935394      0.0
#
#          point_of_interconnection type_of_upgrade  \
# 17  Los Esteros Substation 115 kV            ADNU
#
#                                               upgrade description  \
# 17  Contra Costa to Tesla and Newark 230 kV lines ...        None
#
#    cost_allocation_factor  estimated_cost_x_1000  escalated_cost_x_1000  \
# 17                      0                    0.0                    0.0
#
#    total_estimated_cost_x_1000 estimated_time_to_construct item  \
# 17                    322000.0                         0.0  yes
#
#    upgrade_classification  adnu_cost_rate_x_1000
# 17                                         172.9
# original_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 78  1549       12               Full  37.426372 -121.935394    200.0
#
#          point_of_interconnection type_of_upgrade  \
# 78  Los Esteros Substation 115 kV            ADNU
#
#                                               upgrade description  \
# 78  Contra Costa to Tesla and Newark 230 kV lines ...        None
#
#    cost_allocation_factor  estimated_cost_x_1000  escalated_cost_x_1000  \
# 78                      0                23760.0                28370.0
#
#    total_estimated_cost_x_1000 estimated_time_to_construct item  \
# 78                    322000.0                         0.0  yes
#
#    upgrade_classification  adnu_cost_rate_x_1000 original  row_order
# 78                                         118.8      yes         78
# Before replacement: req_deliverability
# Addendum values:
# 17    Full
# Name: req_deliverability, dtype: object
# Original values:
# 78    Full
# Name: req_deliverability, dtype: object
# After replacement: req_deliverability
# Updated addendum values:
# 17    Full
# Name: req_deliverability, dtype: object
# Before replacement: latitude
# Addendum values:
# 17    37.426372
# Name: latitude, dtype: float64
# Original values:
# 78    37.426372
# Name: latitude, dtype: float64
# After replacement: latitude
# Updated addendum values:
# 17    37.426372
# Name: latitude, dtype: float64
# Before replacement: longitude
# Addendum values:
# 17   -121.935394
# Name: longitude, dtype: float64
# Original values:
# 78   -121.935394
# Name: longitude, dtype: float64
# After replacement: longitude
# Updated addendum values:
# 17   -121.935394
# Name: longitude, dtype: float64
# Before replacement: capacity
# Addendum values:
# 17    0.0
# Name: capacity, dtype: object
# Original values:
# 78    200.0
# Name: capacity, dtype: object
# After replacement: capacity
# Updated addendum values:
# 17    0.0
# Name: capacity, dtype: object
# Before replacement: point_of_interconnection
# Addendum values:
# 17    Los Esteros Substation 115 kV
# Name: point_of_interconnection, dtype: object
# Original values:
# 78    Los Esteros Substation 115 kV
# Name: point_of_interconnection, dtype: object
# After replacement: point_of_interconnection
# Updated addendum values:
# 17    Los Esteros Substation 115 kV
# Name: point_of_interconnection, dtype: object
# Processing itemized: q_id=1549, type_of_upgrade=RNU
# Length of addendum_rows: 4
# Length of original_rows: 4
# addendum_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 13  1549       12               Full  37.426372 -121.935394
# 14  1549       12               Full  37.426372 -121.935394
# 15  1549       12               Full  37.426372 -121.935394
# 16  1549       12               Full  37.426372 -121.935394
#
#          point_of_interconnection type_of_upgrade  \
# 13  Los Esteros Substation 115 kV             RNU
# 14  Los Esteros Substation 115 kV             RNU
# 15  Los Esteros Substation 115 kV             RNU
# 16  Los Esteros Substation 115 kV             RNU
#
#                                           upgrade  \
# 13                Los Esteros Substation (Note 2)
# 14        Newark Substation 115 kV bus overstress
# 15  Nortech 115 kV circuit breaker 192 overstress
# 16                      Midway 500kV CB Overloads
#
#                                           description cost_allocation_factor  \
# 13                            Complete BAAH bay, 3 CB                 50.00%
# 14  Install reactors between Newark Substation 115...                 21.56%
# 15  Replace Nortech 115 kV circuit breaker 192 and...                 41.49%
# 16  Midway Sub: Relocate to the Gates and Los Bano...                  1.99%
#
#     estimated_cost_x_1000  escalated_cost_x_1000 total_estimated_cost_x_1000  \
# 13                 2150.0                 2457.0
# 14                 5390.0                 6159.0
# 15                  830.0                  928.0
# 16                  695.0                  812.0
#
#    estimated_time_to_construct item upgrade_classification  \
# 13                        24.0  yes                   IRNU
# 14                        48.0  yes                   GRNU
# 15                        36.0  yes                   GRNU
# 16                        48.0  yes                   GRNU
#
#     adnu_cost_rate_x_1000
# 13                    0.0
# 14                    0.0
# 15                    0.0
# 16                    0.0
# original_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 72  1549       12               Full  37.426372 -121.935394
# 73  1549       12               Full  37.426372 -121.935394
# 74  1549       12               Full  37.426372 -121.935394
# 75  1549       12               Full  37.426372 -121.935394
#
#          point_of_interconnection type_of_upgrade  \
# 72  Los Esteros Substation 115 kV             RNU
# 73  Los Esteros Substation 115 kV             RNU
# 74  Los Esteros Substation 115 kV             RNU
# 75  Los Esteros Substation 115 kV             RNU
#
#                                           upgrade  \
# 72                         Los Esteros Substation
# 73        Newark Substation 115 kV bus overstress
# 74  Nortech 115 kV circuit breaker 192 overstress
# 75                      Midway 500kV CB Overloads
#
#                                           description cost_allocation_factor  \
# 72                            Complete BAAH bay, 3 CB                100.00%
# 73  Install reactors between Newark Substation 115...                 21.56%
# 74  Replace Nortech 115 kV circuit breaker 192 and...                 41.49%
# 75  Midway Sub: Relocate to the Gates and Los Bano...                  1.99%
#
#     estimated_cost_x_1000  escalated_cost_x_1000 total_estimated_cost_x_1000  \
# 72                 4300.0                 4914.0
# 73                 5390.0                 6159.0
# 74                  830.0                  928.0
# 75                  695.0                  812.0
#
#    estimated_time_to_construct item upgrade_classification  \
# 72                        24.0  yes                   IRNU
# 73                        48.0  yes                   GRNU
# 74                        36.0  yes                   GRNU
# 75                        48.0  yes                   GRNU
#
#     adnu_cost_rate_x_1000 original  row_order
# 72                    0.0      yes         72
# 73                    0.0      yes         73
# 74                    0.0      yes         74
# 75                    0.0      yes         75
# Before replacement: req_deliverability
# Addendum values:
# 13    Full
# 14    Full
# 15    Full
# 16    Full
# Name: req_deliverability, dtype: object
# Original values:
# 72    Full
# 73    Full
# 74    Full
# 75    Full
# Name: req_deliverability, dtype: object
# After replacement: req_deliverability
# Updated addendum values:
# 13    Full
# 14    Full
# 15    Full
# 16    Full
# Name: req_deliverability, dtype: object
# Before replacement: latitude
# Addendum values:
# 13    37.426372
# 14    37.426372
# 15    37.426372
# 16    37.426372
# Name: latitude, dtype: float64
# Original values:
# 72    37.426372
# 73    37.426372
# 74    37.426372
# 75    37.426372
# Name: latitude, dtype: float64
# After replacement: latitude
# Updated addendum values:
# 13    37.426372
# 14    37.426372
# 15    37.426372
# 16    37.426372
# Name: latitude, dtype: float64
# Before replacement: longitude
# Addendum values:
# 13   -121.935394
# 14   -121.935394
# 15   -121.935394
# 16   -121.935394
# Name: longitude, dtype: float64
# Original values:
# 72   -121.935394
# 73   -121.935394
# 74   -121.935394
# 75   -121.935394
# Name: longitude, dtype: float64
# After replacement: longitude
# Updated addendum values:
# 13   -121.935394
# 14   -121.935394
# 15   -121.935394
# 16   -121.935394
# Name: longitude, dtype: float64
# Before replacement: capacity
# Addendum values:
# 13
# 14
# 15
# 16
# Name: capacity, dtype: object
# Original values:
# 72
# 73
# 74
# 75
# Name: capacity, dtype: object
# After replacement: capacity
# Updated addendum values:
# 13
# 14
# 15
# 16
# Name: capacity, dtype: object
# Before replacement: point_of_interconnection
# Addendum values:
# 13    Los Esteros Substation 115 kV
# 14    Los Esteros Substation 115 kV
# 15    Los Esteros Substation 115 kV
# 16    Los Esteros Substation 115 kV
# Name: point_of_interconnection, dtype: object
# Original values:
# 72    Los Esteros Substation 115 kV
# 73    Los Esteros Substation 115 kV
# 74    Los Esteros Substation 115 kV
# 75    Los Esteros Substation 115 kV
# Name: point_of_interconnection, dtype: object
# After replacement: point_of_interconnection
# Updated addendum values:
# 13    Los Esteros Substation 115 kV
# 14    Los Esteros Substation 115 kV
# 15    Los Esteros Substation 115 kV
# 16    Los Esteros Substation 115 kV
# Name: point_of_interconnection, dtype: object
# Processing itemized: q_id=1550, type_of_upgrade=ADNU
# Length of addendum_rows: 1
# Length of original_rows: 1
# addendum_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 21  1550       12               Full  37.429382 -121.933628      0.0
#
#          point_of_interconnection type_of_upgrade  \
# 21  Los Esteros Substation 230 kV            ADNU
#
#                                               upgrade description  \
# 21  Contra Costa to Tesla and Newark 230 kV lines ...        None
#
#    cost_allocation_factor  estimated_cost_x_1000  escalated_cost_x_1000  \
# 21                      0                    0.0                    0.0
#
#    total_estimated_cost_x_1000 estimated_time_to_construct item  \
# 21                    322000.0                         0.0  yes
#
#    upgrade_classification  adnu_cost_rate_x_1000
# 21                                         172.9
# original_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 90  1550       12               Full  37.429382 -121.933628    200.0
#
#          point_of_interconnection type_of_upgrade  \
# 90  Los Esteros Substation 230 kV            ADNU
#
#                                               upgrade description  \
# 90  Contra Costa to Tesla and Newark 230 kV lines ...        None
#
#    cost_allocation_factor  estimated_cost_x_1000  escalated_cost_x_1000  \
# 90                      0                23760.0                28370.0
#
#    total_estimated_cost_x_1000 estimated_time_to_construct item  \
# 90                    322000.0                         0.0  yes
#
#    upgrade_classification  adnu_cost_rate_x_1000 original  row_order
# 90                                         118.8      yes         90
# Before replacement: req_deliverability
# Addendum values:
# 21    Full
# Name: req_deliverability, dtype: object
# Original values:
# 90    Full
# Name: req_deliverability, dtype: object
# After replacement: req_deliverability
# Updated addendum values:
# 21    Full
# Name: req_deliverability, dtype: object
# Before replacement: latitude
# Addendum values:
# 21    37.429382
# Name: latitude, dtype: float64
# Original values:
# 90    37.429382
# Name: latitude, dtype: float64
# After replacement: latitude
# Updated addendum values:
# 21    37.429382
# Name: latitude, dtype: float64
# Before replacement: longitude
# Addendum values:
# 21   -121.933628
# Name: longitude, dtype: float64
# Original values:
# 90   -121.933628
# Name: longitude, dtype: float64
# After replacement: longitude
# Updated addendum values:
# 21   -121.933628
# Name: longitude, dtype: float64
# Before replacement: capacity
# Addendum values:
# 21    0.0
# Name: capacity, dtype: object
# Original values:
# 90    200.0
# Name: capacity, dtype: object
# After replacement: capacity
# Updated addendum values:
# 21    0.0
# Name: capacity, dtype: object
# Before replacement: point_of_interconnection
# Addendum values:
# 21    Los Esteros Substation 230 kV
# Name: point_of_interconnection, dtype: object
# Original values:
# 90    Los Esteros Substation 230 kV
# Name: point_of_interconnection, dtype: object
# After replacement: point_of_interconnection
# Updated addendum values:
# 21    Los Esteros Substation 230 kV
# Name: point_of_interconnection, dtype: object
# Processing itemized: q_id=1550, type_of_upgrade=PTO_IF
# Length of addendum_rows: 3
# Length of original_rows: 3
# addendum_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 18  1550       12               Full  37.429382 -121.933628
# 19  1550       12               Full  37.429382 -121.933628
# 20  1550       12               Full  37.429382 -121.933628
#
#          point_of_interconnection type_of_upgrade                 upgrade  \
# 18  Los Esteros Substation 230 kV          PTO_IF  Los Esteros Substation
# 19  Los Esteros Substation 230 kV          PTO_IF       Transmission Line
# 20  Los Esteros Substation 230 kV          PTO_IF         Generation Site
#
#                                           description cost_allocation_factor  \
# 18  Install Current Differential line relay  packa...                100.00%
# 19  Install (3) 230 kV spans of transmission line ...                100.00%
# 20  Engineering Reviews, Metering, Pre-parallel  I...                100.00%
#
#     estimated_cost_x_1000  escalated_cost_x_1000 total_estimated_cost_x_1000  \
# 18                  970.0                 1072.0
# 19                 1070.0                 1183.0
# 20                  370.0                  409.0
#
#    estimated_time_to_construct item upgrade_classification  \
# 18                        34.0  yes
# 19                        43.0  yes
# 20                        13.0  yes
#
#     adnu_cost_rate_x_1000
# 18                    0.0
# 19                    0.0
# 20                    0.0
# original_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 80  1550       12               Full  37.429382 -121.933628
# 81  1550       12               Full  37.429382 -121.933628
# 82  1550       12               Full  37.429382 -121.933628
#
#          point_of_interconnection type_of_upgrade                 upgrade  \
# 80  Los Esteros Substation 230 kV          PTO_IF  Los Esteros Substation
# 81  Los Esteros Substation 230 kV          PTO_IF   Q1550 Tanager Storage
# 82  Los Esteros Substation 230 kV          PTO_IF                  T-Line
#
#                                           description cost_allocation_factor  \
# 80  Line relay package, VTs, dead- end, line switc...                100.00%
# 81  PG&E Pre-Parallel Review  PG&E RTU, EMS Teleme...                100.00%
# 82  Gen-Tie: 1 conductor, 1 TSP single circuit, PG...                100.00%
#
#     estimated_cost_x_1000  escalated_cost_x_1000 total_estimated_cost_x_1000  \
# 80                 1100.0                 1257.0
# 81                  370.0                  423.0
# 82                 1290.0                 1474.0
#
#    estimated_time_to_construct item upgrade_classification  \
# 80                        30.0  yes
# 81                        30.0  yes
# 82                        30.0  yes
#
#     adnu_cost_rate_x_1000 original  row_order
# 80                    0.0      yes         80
# 81                    0.0      yes         81
# 82                    0.0      yes         82
# Before replacement: req_deliverability
# Addendum values:
# 18    Full
# 19    Full
# 20    Full
# Name: req_deliverability, dtype: object
# Original values:
# 80    Full
# 81    Full
# 82    Full
# Name: req_deliverability, dtype: object
# After replacement: req_deliverability
# Updated addendum values:
# 18    Full
# 19    Full
# 20    Full
# Name: req_deliverability, dtype: object
# Before replacement: latitude
# Addendum values:
# 18    37.429382
# 19    37.429382
# 20    37.429382
# Name: latitude, dtype: float64
# Original values:
# 80    37.429382
# 81    37.429382
# 82    37.429382
# Name: latitude, dtype: float64
# After replacement: latitude
# Updated addendum values:
# 18    37.429382
# 19    37.429382
# 20    37.429382
# Name: latitude, dtype: float64
# Before replacement: longitude
# Addendum values:
# 18   -121.933628
# 19   -121.933628
# 20   -121.933628
# Name: longitude, dtype: float64
# Original values:
# 80   -121.933628
# 81   -121.933628
# 82   -121.933628
# Name: longitude, dtype: float64
# After replacement: longitude
# Updated addendum values:
# 18   -121.933628
# 19   -121.933628
# 20   -121.933628
# Name: longitude, dtype: float64
# Before replacement: capacity
# Addendum values:
# 18
# 19
# 20
# Name: capacity, dtype: object
# Original values:
# 80
# 81
# 82
# Name: capacity, dtype: object
# After replacement: capacity
# Updated addendum values:
# 18
# 19
# 20
# Name: capacity, dtype: object
# Before replacement: point_of_interconnection
# Addendum values:
# 18    Los Esteros Substation 230 kV
# 19    Los Esteros Substation 230 kV
# 20    Los Esteros Substation 230 kV
# Name: point_of_interconnection, dtype: object
# Original values:
# 80    Los Esteros Substation 230 kV
# 81    Los Esteros Substation 230 kV
# 82    Los Esteros Substation 230 kV
# Name: point_of_interconnection, dtype: object
# After replacement: point_of_interconnection
# Updated addendum values:
# 18    Los Esteros Substation 230 kV
# 19    Los Esteros Substation 230 kV
# 20    Los Esteros Substation 230 kV
# Name: point_of_interconnection, dtype: object
# Processing itemized: q_id=1552, type_of_upgrade=ADNU
# Length of addendum_rows: 1
# Length of original_rows: 1
# addendum_rows:
#     q_id  cluster req_deliverability   latitude   longitude capacity  \
# 22  1552       12               Full  37.703164 -122.407006      0.0
#
#                point_of_interconnection type_of_upgrade  \
# 22  Martin Substation (San Francisco H)            ADNU
#
#                                               upgrade description  \
# 22  Contra Costa to Tesla and Newark 230 kV lines ...        None
#
#    cost_allocation_factor  estimated_cost_x_1000  escalated_cost_x_1000  \
# 22                      0                    0.0                    0.0
#
#    total_estimated_cost_x_1000 estimated_time_to_construct item  \
# 22                    322000.0                         0.0  yes
#
#    upgrade_classification  adnu_cost_rate_x_1000
# 22                                         172.9
# original_rows:
#      q_id  cluster req_deliverability   latitude   longitude capacity  \
# 104  1552       12               Full  37.703164 -122.407006    250.0
#
#                 point_of_interconnection type_of_upgrade  \
# 104  Martin Substation (San Francisco H)            ADNU
#
#                                                upgrade description  \
# 104  Contra Costa to Tesla and Newark 230 kV lines ...        None
#
#     cost_allocation_factor  estimated_cost_x_1000  escalated_cost_x_1000  \
# 104                      0                29700.0                35462.0
#
#     total_estimated_cost_x_1000 estimated_time_to_construct item  \
# 104                    322000.0                         0.0  yes
#
#     upgrade_classification  adnu_cost_rate_x_1000 original  row_order
# 104                                         118.8      yes        104
# Before replacement: req_deliverability
# Addendum values:
# 22    Full
# Name: req_deliverability, dtype: object
# Original values:
# 104    Full
# Name: req_deliverability, dtype: object
# After replacement: req_deliverability
# Updated addendum values:
# 22    Full
# Name: req_deliverability, dtype: object
# Before replacement: latitude
# Addendum values:
# 22    37.703164
# Name: latitude, dtype: float64
# Original values:
# 104    37.703164
# Name: latitude, dtype: float64
# After replacement: latitude
# Updated addendum values:
# 22    37.703164
# Name: latitude, dtype: float64
# Before replacement: longitude
# Addendum values:
# 22   -122.407006
# Name: longitude, dtype: float64
# Original values:
# 104   -122.407006
# Name: longitude, dtype: float64
# After replacement: longitude
# Updated addendum values:
# 22   -122.407006
# Name: longitude, dtype: float64
# Before replacement: capacity
# Addendum values:
# 22    0.0
# Name: capacity, dtype: object
# Original values:
# 104    250.0
# Name: capacity, dtype: object
# After replacement: capacity
# Updated addendum values:
# 22    0.0
# Name: capacity, dtype: object
# Before replacement: point_of_interconnection
# Addendum values:
# 22    Martin Substation (San Francisco H)
# Name: point_of_interconnection, dtype: object
# Original values:
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_row[col] = 0
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].replace("", pd.NA)
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].combine_first(original_rows[col].reset_index(drop=True))
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].fillna("")
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].replace("", pd.NA)
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].combine_first(original_rows[col].reset_index(drop=True))
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].fillna("")
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].replace("", pd.NA)
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].combine_first(original_rows[col].reset_index(drop=True))
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].fillna("")
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].replace("", pd.NA)
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].combine_first(original_rows[col].reset_index(drop=True))
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].fillna("")
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].replace("", pd.NA)
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].combine_first(original_rows[col].reset_index(drop=True))
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].fillna("")
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_row[col] = 0
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].replace("", pd.NA)
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].combine_first(original_rows[col].reset_index(drop=True))
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].fillna("")
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].replace("", pd.NA)
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].combine_first(original_rows[col].reset_index(drop=True))
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].fillna("")
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].replace("", pd.NA)
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].combine_first(original_rows[col].reset_index(drop=True))
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].fillna("")
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].replace("", pd.NA)
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].combine_first(original_rows[col].reset_index(drop=True))
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].fillna("")
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].replace("", pd.NA)
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].combine_first(original_rows[col].reset_index(drop=True))
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_rows[col] = addendum_rows[col].fillna("")
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   addendum_row[col] = 0
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:273: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   updated_total[col] = updated_total[col].replace('', np.nan)
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:283: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .apply(lambda group: group.ffill().bfill())
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:288: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .apply(lambda group: group.ffill().bfill())
# /var/folders/l5/3g5pj1nj2j108yb2yjngfmcmcmdwpt/T/ipykernel_35165/3187731748.py:283: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .apply(lambda group: group.ffill().bfill())

# %% [markdown]
# # Checking Scraped Data

# %%
import pandas as pd
import os
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# ---------------------- Configuration ---------------------- #

# Paths to the CSV files
ITEMIZED_CSV_PATH = '/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_itemized.csv'
TOTALS_CSV_PATH = '/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_total.csv'

# Columns in totals_df that hold the reported total costs
TOTALS_ESTIMATED_COLUMN = 'estimated_cost_x_1000'
TOTALS_ESCALATED_COLUMN = 'escalated_cost_x_1000'

# Upgrade types to check
REQUIRED_UPGRADES = ['PTO_IF', 'RNU', 'LDNU', 'ADNU', 'CANU']

# Output paths
MISMATCHES_CSV_PATH = '/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/mismatches.csv'
MATCHED_QIDS_CSV_PATH = '/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/matched_qids.csv'

# ---------------------- Load Data ---------------------- #

def load_csv(path, dataset_name):
    """
    Loads a CSV file into a pandas DataFrame.
    """
    try:
        df = pd.read_csv(path)
        print(f"Loaded {dataset_name} from {path}")
        return df
    except FileNotFoundError:
        print(f"Error: File not found at {path}")
        exit(1)
    except Exception as e:
        print(f"Error loading {dataset_name}: {e}")
        exit(1)

# Load datasets
itemized_df = load_csv(ITEMIZED_CSV_PATH, "itemized data")
totals_df = load_csv(TOTALS_CSV_PATH, "totals data")

# ---------------------- Data Cleaning ---------------------- #

def clean_text(df, column):
    """
    Cleans text data by stripping leading/trailing spaces and converting to uppercase.
    """
    if column in df.columns:
        df[column] = df[column].astype(str).str.strip().str.upper()
    else:
        print(f"Warning: '{column}' column is missing in the dataset. Filling with 'UNKNOWN'.")
        df[column] = 'UNKNOWN'
    return df

# Clean 'type_of_upgrade' and 'point_of_interconnection' in both datasets
itemized_df = clean_text(itemized_df, 'type_of_upgrade')
itemized_df = clean_text(itemized_df, 'point_of_interconnection')

totals_df = clean_text(totals_df, 'type_of_upgrade')
totals_df = clean_text(totals_df, 'point_of_interconnection')

# ---------------------- Data Preparation ---------------------- #

# Ensure necessary columns exist in itemized_df
required_itemized_columns = ['q_id', 'type_of_upgrade', 'point_of_interconnection', 'estimated_cost_x_1000', 'escalated_cost_x_1000']
for col in required_itemized_columns:
    if col not in itemized_df.columns:
        print(f"Warning: '{col}' column is missing in the itemized dataset.")
        if col in ['q_id', 'type_of_upgrade', 'point_of_interconnection']:
            itemized_df[col] = 'UNKNOWN'
        else:
            itemized_df[col] = 0

# Ensure necessary columns exist in totals_df
required_totals_columns = ['q_id', 'type_of_upgrade', 'point_of_interconnection', TOTALS_ESTIMATED_COLUMN, TOTALS_ESCALATED_COLUMN]
for col in required_totals_columns:
    if col not in totals_df.columns:
        print(f"Error: '{col}' column is missing in the totals dataset. Cannot proceed.")
        exit(1)

# Convert cost columns to numeric, coercing errors to NaN and filling with 0
cost_columns_itemized = ['estimated_cost_x_1000', 'escalated_cost_x_1000']
for col in cost_columns_itemized:
    itemized_df[col] = pd.to_numeric(itemized_df[col], errors='coerce').fillna(0)

cost_columns_totals = [TOTALS_ESTIMATED_COLUMN, TOTALS_ESCALATED_COLUMN]
for col in cost_columns_totals:
    totals_df[col] = pd.to_numeric(totals_df[col], errors='coerce').fillna(0)

# ---------------------- Calculate Manual Totals ---------------------- #

# Group itemized data by q_id and type_of_upgrade and calculate sums
itemized_grouped = itemized_df.groupby(['q_id', 'type_of_upgrade']).agg({
    'estimated_cost_x_1000': 'sum',
    'escalated_cost_x_1000': 'sum'
}).reset_index()

# Apply preference: Use estimated_cost_x_1000 if sum > 0, else use escalated_cost_x_1000
itemized_grouped['manual_total'] = itemized_grouped.apply(
    lambda row: row['estimated_cost_x_1000'] if row['estimated_cost_x_1000'] > 0 else row['escalated_cost_x_1000'],
    axis=1
)

# ---------------------- Prepare Totals Data ---------------------- #

# Group totals data by q_id and type_of_upgrade and calculate sums
totals_grouped = totals_df.groupby(['q_id', 'type_of_upgrade']).agg({
    TOTALS_ESTIMATED_COLUMN: 'sum',
    TOTALS_ESCALATED_COLUMN: 'sum'
}).reset_index()

# Apply preference: Use estimated_cost_x_1000 if sum > 0, else use escalated_cost_x_1000
totals_grouped['reported_total'] = totals_grouped.apply(
    lambda row: row[TOTALS_ESTIMATED_COLUMN] if row[TOTALS_ESTIMATED_COLUMN] > 0 else row[TOTALS_ESCALATED_COLUMN],
    axis=1
)

# ---------------------- Merge Data ---------------------- #

# Merge the itemized and totals data on q_id and type_of_upgrade
comparison_df = pd.merge(
    itemized_grouped,
    totals_grouped[['q_id', 'type_of_upgrade', 'reported_total']],
    on=['q_id', 'type_of_upgrade'],
    how='left'
)

# ---------------------- Check for Missing Upgrades ---------------------- #

# Identify q_ids that are missing any of the required upgrades
missing_upgrades_report = []
for q_id in comparison_df['q_id'].unique():
    upgrades_present = comparison_df[comparison_df['q_id'] == q_id]['type_of_upgrade'].unique()
    missing_upgrades = [upgrade for upgrade in REQUIRED_UPGRADES if upgrade not in upgrades_present]
    if missing_upgrades:
        missing_upgrades_report.append((q_id, missing_upgrades))

# Report missing upgrades
if missing_upgrades_report:
    print("\nQ_ids with missing upgrades:")
    for q_id, missing in missing_upgrades_report:
        print(f"  Q_id {q_id} is missing upgrades: {', '.join(missing)}")
else:
    print("\nAll q_ids have all required upgrades.")


# ------------------------ Check for no duplicates in type of upgrade in total data ------------------------ #

 

# Identify duplicates by grouping by q_id and type_of_upgrade
duplicates = totals_df[totals_df.duplicated(subset=['q_id', 'type_of_upgrade'], keep=False)]

if not duplicates.empty:
    print("\nDuplicate upgrade types detected:")
    for q_id, group in duplicates.groupby('q_id'):
        upgrade_types = group['type_of_upgrade'].unique()
        print(f"  Q_id {q_id} has repeated upgrade types: {', '.join(upgrade_types)}")
else:
    print("\nNo type of upgrade is repeated for any Q_id.")    

# ---------------------- Compare Totals and Identify Mismatches ---------------------- #

# Initialize list to store mismatches
mismatches = []

# Iterate through each row to compare manual_total with reported_total
for index, row in comparison_df.iterrows():
    q_id = row['q_id']
    upgrade = row['type_of_upgrade']
    manual_total = row['manual_total']
    reported_total = row['reported_total']
    
    # Determine if both manual_total and reported_total are zero
    if manual_total == 0.0 and reported_total == 0.0:
        continue  # No mismatch
    # Determine if manual_total is zero and reported_total is missing or zero
    elif manual_total == 0.0 and (pd.isna(row['reported_total']) or reported_total == 0.0):
        continue  # No mismatch
    # If reported_total is missing (NaN) and manual_total is not zero
    elif pd.isna(row['reported_total']) and manual_total != 0.0:
        print(f"Mismatch: Q_id {q_id}, Upgrade '{upgrade}' - Manual Total: {manual_total}, Reported Total: Missing")
        mismatches.append({
            'q_id': q_id,
            'type_of_upgrade': upgrade,
            'manual_total': manual_total,
            'reported_total': 'Missing'
        })
    # If manual_total is not zero and reported_total is zero
    elif manual_total != 0.0 and reported_total == 0.0:
        print(f"Mismatch: Q_id {q_id}, Upgrade '{upgrade}' - Manual Total: {manual_total}, Reported Total: 0.0")
        mismatches.append({
            'q_id': q_id,
            'type_of_upgrade': upgrade,
            'manual_total': manual_total,
            'reported_total': reported_total
        })
    # If both totals are non-zero but differ beyond tolerance
    elif abs(manual_total - reported_total) > 1e+1:
        print(f"Mismatch: Q_id {q_id}, Upgrade '{upgrade}' - Manual Total: {manual_total}, Reported Total: {reported_total}")
        mismatches.append({
            'q_id': q_id,
            'type_of_upgrade': upgrade,
            'manual_total': manual_total,
            'reported_total': reported_total
        })
    # Else, totals match; do nothing

# Create a DataFrame for mismatches
mismatches_df = pd.DataFrame(mismatches, columns=['q_id', 'type_of_upgrade', 'manual_total', 'reported_total'])

# Save mismatches to a CSV file
try:
    mismatches_df.to_csv(MISMATCHES_CSV_PATH, index=False)
    print(f"\nMismatches saved to '{MISMATCHES_CSV_PATH}'.")
except Exception as e:
    print(f"Error saving mismatches CSV: {e}")

# ---------------------- Point of Interconnection Matching ---------------------- #

# Extract unique q_id and point_of_interconnection from itemized dataset
itemized_poi = itemized_df[['q_id', 'point_of_interconnection']].drop_duplicates()

# Extract unique q_id and point_of_interconnection from totals dataset
totals_poi = totals_df[['q_id', 'point_of_interconnection']].drop_duplicates()

# Merge both to have a complete list of q_id and point_of_interconnection
all_poi = pd.concat([itemized_poi, totals_poi]).drop_duplicates().reset_index(drop=True)

# ---------------------- Direct Match Identification ---------------------- #

# Group by point_of_interconnection to find q_ids sharing the same point_of_interconnection
direct_matches = all_poi.groupby('point_of_interconnection')['q_id'].apply(list).reset_index()

# Filter groups with more than one q_id (i.e., shared points_of_interconnection)
direct_matches = direct_matches[direct_matches['q_id'].apply(len) > 1]

print("\nDirect Matches (Exact Point of Interconnection Names):")
if not direct_matches.empty:
    print(direct_matches)
else:
    print("No direct matches found.")

# ---------------------- Fuzzy Match Identification ---------------------- #

# Prepare list of points_of_interconnection for fuzzy matching
poi_list = all_poi['point_of_interconnection'].unique().tolist()

# Initialize list to store fuzzy matches
fuzzy_matches = []

# Iterate through each point_of_interconnection to find similar ones
for i, poi in enumerate(poi_list):
    # Compare with the rest of the points to avoid redundant comparisons
    similar_pois = process.extract(poi, poi_list[i+1:], scorer=fuzz.token_set_ratio)
    
    # Filter matches with similarity >= 80%
    for match_poi, score in similar_pois:
        if score >= 80:
            # Retrieve q_ids for both points_of_interconnection
            qids_poi1 = all_poi[all_poi['point_of_interconnection'] == poi]['q_id'].tolist()
            qids_poi2 = all_poi[all_poi['point_of_interconnection'] == match_poi]['q_id'].tolist()
            
            # Append the matched pairs with their points_of_interconnection and similarity score
            fuzzy_matches.append({
                'point_of_interconnection_1': poi,
                'q_ids_1': qids_poi1,
                'point_of_interconnection_2': match_poi,
                'q_ids_2': qids_poi2,
                'similarity_score': score
            })

# Convert fuzzy matches to DataFrame
fuzzy_matches_df = pd.DataFrame(fuzzy_matches)

print("\nFuzzy Matches (>=80% Similarity in Point of Interconnection):")
if not fuzzy_matches_df.empty:
    print(fuzzy_matches_df)
else:
    print("No fuzzy matches found.")

# ---------------------- Save Matched Q_ids to CSV ---------------------- #

# For clarity, create a combined DataFrame for direct and fuzzy matches

# Direct matches: list each pair of q_ids sharing the same point_of_interconnection
direct_matches_expanded = []
for _, row in direct_matches.iterrows():
    qids = row['q_id']
    poi = row['point_of_interconnection']
    # Generate all possible unique pairs
    for i in range(len(qids)):
        for j in range(i+1, len(qids)):
            direct_matches_expanded.append({
                'match_type': 'Direct',
                'point_of_interconnection_1': poi,
                'q_id_1': qids[i],
                'point_of_interconnection_2': poi,
                'q_id_2': qids[j],
                'similarity_score': 100
            })

# Fuzzy matches: already have pairs
fuzzy_matches_expanded = []
for _, row in fuzzy_matches_df.iterrows():
    fuzzy_matches_expanded.append({
        'match_type': 'Fuzzy',
        'point_of_interconnection_1': row['point_of_interconnection_1'],
        'q_id_1': row['q_ids_1'],
        'point_of_interconnection_2': row['point_of_interconnection_2'],
        'q_id_2': row['q_ids_2'],
        'similarity_score': row['similarity_score']
    })

# Convert to DataFrame
matched_qids_df = pd.DataFrame(direct_matches_expanded + fuzzy_matches_expanded)

# Save matched q_ids to CSV
try:
    matched_qids_df.to_csv(MATCHED_QIDS_CSV_PATH, index=False)
    print(f"Matched Q_ids saved to '{MATCHED_QIDS_CSV_PATH}'.")
except Exception as e:
    print(f"Error saving matched Q_ids CSV: {e}")

# ---------------------- Summary ---------------------- #

# Print a summary
total_checked = len(comparison_df)
total_mismatches = len(mismatches_df)
print(f"\nTotal checks performed: {total_checked}")
print(f"Total mismatches found: {total_mismatches}")
# Out:
# Loaded itemized data from /Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/output/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_itemized.csv
# Loaded totals data from /Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/output/Cluster 12/02_intermediate/costs_phase_1_cluster_12_style_G_total.csv
#
# All q_ids have all required upgrades.
#
# No type of upgrade is repeated for any Q_id.
# Mismatch: Q_id 1591, Upgrade 'ADNU' - Manual Total: 12077.0, Reported Total: 13603.0
#
# Mismatches saved to '/Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/output/Cluster 12/mismatches.csv'.
#
# Direct Matches (Exact Point of Interconnection Names):
#      point_of_interconnection          q_id
# 0      ARCO SUBSTATION 230 KV  [1586, 1587]
# 5   GATES  MIDWAY 230 KV LINE  [1593, 1594]
# 27  PANOCHE SUBSTATION 230 KV  [1574, 1582]
#
# Fuzzy Matches (>=80% Similarity in Point of Interconnection):
#                            point_of_interconnection_1       q_ids_1  \
# 0                       BRIDGEVILLE SUBSTATION 115 KV        [1542]
# 1                       BRIDGEVILLE SUBSTATION 115 KV        [1542]
# 2                           CORTINA SUBSTATION 115 KV        [1543]
# 3                           CORTINA SUBSTATION 115 KV        [1543]
# 4                           CORTINA SUBSTATION 115 KV        [1543]
# 5                       MORGAN HILL SUBSTATION 115 KV        [1548]
# 6                       LOS ESTEROS SUBSTATION 115 KV        [1549]
# 7                       LOS ESTEROS SUBSTATION 115 KV        [1549]
# 8                       LOS ESTEROS SUBSTATION 230 KV        [1550]
# 9                       LOS ESTEROS SUBSTATION 230 KV        [1550]
# 10                      LOS ESTEROS SUBSTATION 230 KV        [1550]
# 11                          METCALF SUBSTATION 230 KV        [1553]
# 12                          METCALF SUBSTATION 230 KV        [1553]
# 13                          METCALF SUBSTATION 230 KV        [1553]
# 14                          METCALF SUBSTATION 230 KV        [1553]
# 15                          METCALF SUBSTATION 230 KV        [1553]
# 16                        PITTSBURG SUBSTATION 230 KV        [1555]
# 17                        PITTSBURG SUBSTATION 230 KV        [1555]
# 18  ROUND MOUNTAIN SUBSTATION 500 KV (VIA NEW DOUB...        [1559]
# 19                             JAYNE SUBSTATION 70 KV        [1573]
# 20                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 21                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 22                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 23                        HENRIETTA SUBSTATION 230 KV        [1578]
# 24                             ARCO SUBSTATION 230 KV  [1586, 1587]
# 25  NEW 500 KV SW STA (LOOP IN DIABLO CANYON - GAT...        [1590]
# 26  MIDWAY - TUPMAN - RIO BRAVO - RENFRO (VIA EXG....        [1591]
# 27                       GATES  TEMPLETON 230 KV LINE        [1592]
# 28                          GATES  MIDWAY 230 KV LINE  [1593, 1594]
# 29                          GATES  MIDWAY 230 KV LINE  [1593, 1594]
# 30  MIDWAY SUBSTATION 230 KV (VIA THE MIDWAY - ELK...        [1595]
#
#                            point_of_interconnection_2       q_ids_2  \
# 0                             RIPON SUBSTATION 115 KV        [1557]
# 1                           CORTINA SUBSTATION 115 KV        [1543]
# 2                             RIPON SUBSTATION 115 KV        [1557]
# 3                       MORGAN HILL SUBSTATION 115 KV        [1548]
# 4                       LOS ESTEROS SUBSTATION 115 KV        [1549]
# 5                             RIPON SUBSTATION 115 KV        [1557]
# 6                       LOS ESTEROS SUBSTATION 230 KV        [1550]
# 7                             RIPON SUBSTATION 115 KV        [1557]
# 8                              ARCO SUBSTATION 230 KV  [1586, 1587]
# 9                           METCALF SUBSTATION 230 KV        [1553]
# 10                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 11                             ARCO SUBSTATION 230 KV  [1586, 1587]
# 12                        PITTSBURG SUBSTATION 230 KV        [1555]
# 13                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 14                        HENRIETTA SUBSTATION 230 KV        [1578]
# 15  MIDWAY SUBSTATION 230 KV (VIA THE MIDWAY - ELK...        [1595]
# 16                             ARCO SUBSTATION 230 KV  [1586, 1587]
# 17                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 18                           MIDWAY SUBSTATION 500 KV        [1596]
# 19                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 20                             ARCO SUBSTATION 230 KV  [1586, 1587]
# 21                        HENRIETTA SUBSTATION 230 KV        [1578]
# 22  MIDWAY SUBSTATION 230 KV (VIA THE MIDWAY - ELK...        [1595]
# 23                             ARCO SUBSTATION 230 KV  [1586, 1587]
# 24  MIDWAY SUBSTATION 230 KV (VIA THE MIDWAY - ELK...        [1595]
# 25  NEW SW STA (LOOP IN PG&E'S MIDWAY - DIABLO CAN...        [1600]
# 26                           MIDWAY SUBSTATION 500 KV        [1596]
# 27                          GATES  MIDWAY 230 KV LINE  [1593, 1594]
# 28  MIDWAY SUBSTATION 230 KV (VIA THE MIDWAY - ELK...        [1595]
# 29               MIDWAY  WHEELER RIDGE #1 230 KV LINE        [1597]
# 30                           MIDWAY SUBSTATION 500 KV        [1596]
#
#     similarity_score
# 0                 85
# 1                 81
# 2                 88
# 3                 81
# 4                 81
# 5                 85
# 6                 93
# 7                 85
# 8                 87
# 9                 81
# 10                81
# 11                87
# 12                81
# 13                81
# 14                81
# 15                81
# 16                87
# 17                81
# 18                83
# 19                81
# 20                87
# 21                81
# 22                81
# 23                87
# 24                87
# 25                85
# 26                83
# 27                83
# 28                86
# 29                86
# 30                91
# Matched Q_ids saved to '/Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/output/Cluster 12/matched_qids.csv'.
#
# Total checks performed: 195
# Total mismatches found: 1

# %% [markdown]
# # Scraped Data Check for Final Data

# %%
import pandas as pd
import os
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# ---------------------- Configuration ---------------------- #

# Paths to the CSV files
ITEMIZED_CSV_PATH = '/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/01_clean/costs_phase_1_cluster_12_style_G_itemized_updated.csv'
TOTALS_CSV_PATH = '/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/01_clean/costs_phase_1_cluster_12_style_G_total_updated.csv'

# Columns in totals_df that hold the reported total costs
TOTALS_ESTIMATED_COLUMN = 'estimated_cost_x_1000'
TOTALS_ESCALATED_COLUMN = 'escalated_cost_x_1000'

# Upgrade types to check
REQUIRED_UPGRADES = ['PTO_IF', 'RNU', 'LDNU', 'ADNU', 'CANU']

# Output paths
MISMATCHES_CSV_PATH = '/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/mismatches.csv'
MATCHED_QIDS_CSV_PATH = '/Users/vk365/Dropbox/Interconnections_data/data/ic_studies/raw/04_intermediate_scraped_data/phase_1_cost_data/Cluster 12/matched_qids.csv'

# ---------------------- Load Data ---------------------- #

def load_csv(path, dataset_name):
    """
    Loads a CSV file into a pandas DataFrame.
    """
    try:
        df = pd.read_csv(path)
        print(f"Loaded {dataset_name} from {path}")
        return df
    except FileNotFoundError:
        print(f"Error: File not found at {path}")
        exit(1)
    except Exception as e:
        print(f"Error loading {dataset_name}: {e}")
        exit(1)

# Load datasets
itemized_df = load_csv(ITEMIZED_CSV_PATH, "itemized data")
totals_df = load_csv(TOTALS_CSV_PATH, "totals data")

# ---------------------- Data Cleaning ---------------------- #

def clean_text(df, column):
    """
    Cleans text data by stripping leading/trailing spaces and converting to uppercase.
    """
    if column in df.columns:
        df[column] = df[column].astype(str).str.strip().str.upper()
    else:
        print(f"Warning: '{column}' column is missing in the dataset. Filling with 'UNKNOWN'.")
        df[column] = 'UNKNOWN'
    return df

# Clean 'type_of_upgrade' and 'point_of_interconnection' in both datasets
itemized_df = clean_text(itemized_df, 'type_of_upgrade')
itemized_df = clean_text(itemized_df, 'point_of_interconnection')

totals_df = clean_text(totals_df, 'type_of_upgrade')
totals_df = clean_text(totals_df, 'point_of_interconnection')

# ---------------------- Data Preparation ---------------------- #

# Ensure necessary columns exist in itemized_df
required_itemized_columns = ['q_id', 'type_of_upgrade', 'point_of_interconnection', 'estimated_cost_x_1000', 'escalated_cost_x_1000']
for col in required_itemized_columns:
    if col not in itemized_df.columns:
        print(f"Warning: '{col}' column is missing in the itemized dataset.")
        if col in ['q_id', 'type_of_upgrade', 'point_of_interconnection']:
            itemized_df[col] = 'UNKNOWN'
        else:
            itemized_df[col] = 0

# Ensure necessary columns exist in totals_df
required_totals_columns = ['q_id', 'type_of_upgrade', 'point_of_interconnection', TOTALS_ESTIMATED_COLUMN, TOTALS_ESCALATED_COLUMN]
for col in required_totals_columns:
    if col not in totals_df.columns:
        print(f"Error: '{col}' column is missing in the totals dataset. Cannot proceed.")
        exit(1)

# Convert cost columns to numeric, coercing errors to NaN and filling with 0
cost_columns_itemized = ['estimated_cost_x_1000', 'escalated_cost_x_1000']
for col in cost_columns_itemized:
    itemized_df[col] = pd.to_numeric(itemized_df[col], errors='coerce').fillna(0)

cost_columns_totals = [TOTALS_ESTIMATED_COLUMN, TOTALS_ESCALATED_COLUMN]
for col in cost_columns_totals:
    totals_df[col] = pd.to_numeric(totals_df[col], errors='coerce').fillna(0)

# ---------------------- Calculate Manual Totals ---------------------- #

# Group itemized data by q_id and type_of_upgrade and calculate sums
itemized_grouped = itemized_df.groupby(['q_id', 'type_of_upgrade']).agg({
    'estimated_cost_x_1000': 'sum',
    'escalated_cost_x_1000': 'sum'
}).reset_index()

# Apply preference: Use estimated_cost_x_1000 if sum > 0, else use escalated_cost_x_1000
itemized_grouped['manual_total'] = itemized_grouped.apply(
    lambda row: row['estimated_cost_x_1000'] if row['estimated_cost_x_1000'] > 0 else row['escalated_cost_x_1000'],
    axis=1
)

# ---------------------- Prepare Totals Data ---------------------- #

# Group totals data by q_id and type_of_upgrade and calculate sums
totals_grouped = totals_df.groupby(['q_id', 'type_of_upgrade']).agg({
    TOTALS_ESTIMATED_COLUMN: 'sum',
    TOTALS_ESCALATED_COLUMN: 'sum'
}).reset_index()

# Apply preference: Use estimated_cost_x_1000 if sum > 0, else use escalated_cost_x_1000
totals_grouped['reported_total'] = totals_grouped.apply(
    lambda row: row[TOTALS_ESTIMATED_COLUMN] if row[TOTALS_ESTIMATED_COLUMN] > 0 else row[TOTALS_ESCALATED_COLUMN],
    axis=1
)

# ---------------------- Merge Data ---------------------- #

# Merge the itemized and totals data on q_id and type_of_upgrade
comparison_df = pd.merge(
    itemized_grouped,
    totals_grouped[['q_id', 'type_of_upgrade', 'reported_total']],
    on=['q_id', 'type_of_upgrade'],
    how='left'
)

# ---------------------- Check for Missing Upgrades ---------------------- #

# Identify q_ids that are missing any of the required upgrades
missing_upgrades_report = []
for q_id in comparison_df['q_id'].unique():
    upgrades_present = comparison_df[comparison_df['q_id'] == q_id]['type_of_upgrade'].unique()
    missing_upgrades = [upgrade for upgrade in REQUIRED_UPGRADES if upgrade not in upgrades_present]
    if missing_upgrades:
        missing_upgrades_report.append((q_id, missing_upgrades))

# Report missing upgrades
if missing_upgrades_report:
    print("\nQ_ids with missing upgrades:")
    for q_id, missing in missing_upgrades_report:
        print(f"  Q_id {q_id} is missing upgrades: {', '.join(missing)}")
else:
    print("\nAll q_ids have all required upgrades.")


# ------------------------ Check for no duplicates in type of upgrade in total data ------------------------ #

 

# Identify duplicates by grouping by q_id and type_of_upgrade
duplicates = totals_df[totals_df.duplicated(subset=['q_id', 'type_of_upgrade'], keep=False)]

if not duplicates.empty:
    print("\nDuplicate upgrade types detected:")
    for q_id, group in duplicates.groupby('q_id'):
        upgrade_types = group['type_of_upgrade'].unique()
        print(f"  Q_id {q_id} has repeated upgrade types: {', '.join(upgrade_types)}")
else:
    print("\nNo type of upgrade is repeated for any Q_id.")    

# ---------------------- Compare Totals and Identify Mismatches ---------------------- #

# Initialize list to store mismatches
mismatches = []

# Iterate through each row to compare manual_total with reported_total
for index, row in comparison_df.iterrows():
    q_id = row['q_id']
    upgrade = row['type_of_upgrade']
    manual_total = row['manual_total']
    reported_total = row['reported_total']
    
    # Determine if both manual_total and reported_total are zero
    if manual_total == 0.0 and reported_total == 0.0:
        continue  # No mismatch
    # Determine if manual_total is zero and reported_total is missing or zero
    elif manual_total == 0.0 and (pd.isna(row['reported_total']) or reported_total == 0.0):
        continue  # No mismatch
    # If reported_total is missing (NaN) and manual_total is not zero
    elif pd.isna(row['reported_total']) and manual_total != 0.0:
        print(f"Mismatch: Q_id {q_id}, Upgrade '{upgrade}' - Manual Total: {manual_total}, Reported Total: Missing")
        mismatches.append({
            'q_id': q_id,
            'type_of_upgrade': upgrade,
            'manual_total': manual_total,
            'reported_total': 'Missing'
        })
    # If manual_total is not zero and reported_total is zero
    elif manual_total != 0.0 and reported_total == 0.0:
        print(f"Mismatch: Q_id {q_id}, Upgrade '{upgrade}' - Manual Total: {manual_total}, Reported Total: 0.0")
        mismatches.append({
            'q_id': q_id,
            'type_of_upgrade': upgrade,
            'manual_total': manual_total,
            'reported_total': reported_total
        })
    # If both totals are non-zero but differ beyond tolerance
    elif abs(manual_total - reported_total) > 1e+1:
        print(f"Mismatch: Q_id {q_id}, Upgrade '{upgrade}' - Manual Total: {manual_total}, Reported Total: {reported_total}")
        mismatches.append({
            'q_id': q_id,
            'type_of_upgrade': upgrade,
            'manual_total': manual_total,
            'reported_total': reported_total
        })
    # Else, totals match; do nothing

# Create a DataFrame for mismatches
mismatches_df = pd.DataFrame(mismatches, columns=['q_id', 'type_of_upgrade', 'manual_total', 'reported_total'])

# Save mismatches to a CSV file
try:
    mismatches_df.to_csv(MISMATCHES_CSV_PATH, index=False)
    print(f"\nMismatches saved to '{MISMATCHES_CSV_PATH}'.")
except Exception as e:
    print(f"Error saving mismatches CSV: {e}")

# ---------------------- Point of Interconnection Matching ---------------------- #

# Extract unique q_id and point_of_interconnection from itemized dataset
itemized_poi = itemized_df[['q_id', 'point_of_interconnection']].drop_duplicates()

# Extract unique q_id and point_of_interconnection from totals dataset
totals_poi = totals_df[['q_id', 'point_of_interconnection']].drop_duplicates()

# Merge both to have a complete list of q_id and point_of_interconnection
all_poi = pd.concat([itemized_poi, totals_poi]).drop_duplicates().reset_index(drop=True)

# ---------------------- Direct Match Identification ---------------------- #

# Group by point_of_interconnection to find q_ids sharing the same point_of_interconnection
direct_matches = all_poi.groupby('point_of_interconnection')['q_id'].apply(list).reset_index()

# Filter groups with more than one q_id (i.e., shared points_of_interconnection)
direct_matches = direct_matches[direct_matches['q_id'].apply(len) > 1]

print("\nDirect Matches (Exact Point of Interconnection Names):")
if not direct_matches.empty:
    print(direct_matches)
else:
    print("No direct matches found.")

# ---------------------- Fuzzy Match Identification ---------------------- #

# Prepare list of points_of_interconnection for fuzzy matching
poi_list = all_poi['point_of_interconnection'].unique().tolist()

# Initialize list to store fuzzy matches
fuzzy_matches = []

# Iterate through each point_of_interconnection to find similar ones
for i, poi in enumerate(poi_list):
    # Compare with the rest of the points to avoid redundant comparisons
    similar_pois = process.extract(poi, poi_list[i+1:], scorer=fuzz.token_set_ratio)
    
    # Filter matches with similarity >= 80%
    for match_poi, score in similar_pois:
        if score >= 80:
            # Retrieve q_ids for both points_of_interconnection
            qids_poi1 = all_poi[all_poi['point_of_interconnection'] == poi]['q_id'].tolist()
            qids_poi2 = all_poi[all_poi['point_of_interconnection'] == match_poi]['q_id'].tolist()
            
            # Append the matched pairs with their points_of_interconnection and similarity score
            fuzzy_matches.append({
                'point_of_interconnection_1': poi,
                'q_ids_1': qids_poi1,
                'point_of_interconnection_2': match_poi,
                'q_ids_2': qids_poi2,
                'similarity_score': score
            })

# Convert fuzzy matches to DataFrame
fuzzy_matches_df = pd.DataFrame(fuzzy_matches)

print("\nFuzzy Matches (>=80% Similarity in Point of Interconnection):")
if not fuzzy_matches_df.empty:
    print(fuzzy_matches_df)
else:
    print("No fuzzy matches found.")

# ---------------------- Save Matched Q_ids to CSV ---------------------- #

# For clarity, create a combined DataFrame for direct and fuzzy matches

# Direct matches: list each pair of q_ids sharing the same point_of_interconnection
direct_matches_expanded = []
for _, row in direct_matches.iterrows():
    qids = row['q_id']
    poi = row['point_of_interconnection']
    # Generate all possible unique pairs
    for i in range(len(qids)):
        for j in range(i+1, len(qids)):
            direct_matches_expanded.append({
                'match_type': 'Direct',
                'point_of_interconnection_1': poi,
                'q_id_1': qids[i],
                'point_of_interconnection_2': poi,
                'q_id_2': qids[j],
                'similarity_score': 100
            })

# Fuzzy matches: already have pairs
fuzzy_matches_expanded = []
for _, row in fuzzy_matches_df.iterrows():
    fuzzy_matches_expanded.append({
        'match_type': 'Fuzzy',
        'point_of_interconnection_1': row['point_of_interconnection_1'],
        'q_id_1': row['q_ids_1'],
        'point_of_interconnection_2': row['point_of_interconnection_2'],
        'q_id_2': row['q_ids_2'],
        'similarity_score': row['similarity_score']
    })

# Convert to DataFrame
matched_qids_df = pd.DataFrame(direct_matches_expanded + fuzzy_matches_expanded)

# Save matched q_ids to CSV
try:
    matched_qids_df.to_csv(MATCHED_QIDS_CSV_PATH, index=False)
    print(f"Matched Q_ids saved to '{MATCHED_QIDS_CSV_PATH}'.")
except Exception as e:
    print(f"Error saving matched Q_ids CSV: {e}")

# ---------------------- Summary ---------------------- #

# Print a summary
total_checked = len(comparison_df)
total_mismatches = len(mismatches_df)
print(f"\nTotal checks performed: {total_checked}")
print(f"Total mismatches found: {total_mismatches}")
# Out:
# Loaded itemized data from /Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/output/Cluster 12/01_clean/costs_phase_1_cluster_12_style_G_itemized_updated.csv
# Loaded totals data from /Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/output/Cluster 12/01_clean/costs_phase_1_cluster_12_style_G_total_updated.csv
#
# All q_ids have all required upgrades.
#
# No type of upgrade is repeated for any Q_id.
#
# Mismatches saved to '/Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/output/Cluster 12/mismatches.csv'.
#
# Direct Matches (Exact Point of Interconnection Names):
#      point_of_interconnection          q_id
# 0      ARCO SUBSTATION 230 KV  [1586, 1587]
# 5   GATES  MIDWAY 230 KV LINE  [1593, 1594]
# 27  PANOCHE SUBSTATION 230 KV  [1574, 1582]
#
# Fuzzy Matches (>=80% Similarity in Point of Interconnection):
#                            point_of_interconnection_1       q_ids_1  \
# 0                       BRIDGEVILLE SUBSTATION 115 KV        [1542]
# 1                       BRIDGEVILLE SUBSTATION 115 KV        [1542]
# 2                           CORTINA SUBSTATION 115 KV        [1543]
# 3                           CORTINA SUBSTATION 115 KV        [1543]
# 4                           CORTINA SUBSTATION 115 KV        [1543]
# 5                       MORGAN HILL SUBSTATION 115 KV        [1548]
# 6                       LOS ESTEROS SUBSTATION 115 KV        [1549]
# 7                       LOS ESTEROS SUBSTATION 115 KV        [1549]
# 8                       LOS ESTEROS SUBSTATION 230 KV        [1550]
# 9                       LOS ESTEROS SUBSTATION 230 KV        [1550]
# 10                      LOS ESTEROS SUBSTATION 230 KV        [1550]
# 11                          METCALF SUBSTATION 230 KV        [1553]
# 12                          METCALF SUBSTATION 230 KV        [1553]
# 13                          METCALF SUBSTATION 230 KV        [1553]
# 14                          METCALF SUBSTATION 230 KV        [1553]
# 15                          METCALF SUBSTATION 230 KV        [1553]
# 16                        PITTSBURG SUBSTATION 230 KV        [1555]
# 17                        PITTSBURG SUBSTATION 230 KV        [1555]
# 18  ROUND MOUNTAIN SUBSTATION 500 KV (VIA NEW DOUB...        [1559]
# 19                             JAYNE SUBSTATION 70 KV        [1573]
# 20                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 21                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 22                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 23                        HENRIETTA SUBSTATION 230 KV        [1578]
# 24                             ARCO SUBSTATION 230 KV  [1586, 1587]
# 25  NEW 500 KV SW STA (LOOP IN DIABLO CANYON - GAT...        [1590]
# 26  MIDWAY - TUPMAN - RIO BRAVO - RENFRO (VIA EXG....        [1591]
# 27                       GATES  TEMPLETON 230 KV LINE        [1592]
# 28                          GATES  MIDWAY 230 KV LINE  [1593, 1594]
# 29                          GATES  MIDWAY 230 KV LINE  [1593, 1594]
# 30  MIDWAY SUBSTATION 230 KV (VIA THE MIDWAY - ELK...        [1595]
#
#                            point_of_interconnection_2       q_ids_2  \
# 0                             RIPON SUBSTATION 115 KV        [1557]
# 1                           CORTINA SUBSTATION 115 KV        [1543]
# 2                             RIPON SUBSTATION 115 KV        [1557]
# 3                       MORGAN HILL SUBSTATION 115 KV        [1548]
# 4                       LOS ESTEROS SUBSTATION 115 KV        [1549]
# 5                             RIPON SUBSTATION 115 KV        [1557]
# 6                       LOS ESTEROS SUBSTATION 230 KV        [1550]
# 7                             RIPON SUBSTATION 115 KV        [1557]
# 8                              ARCO SUBSTATION 230 KV  [1586, 1587]
# 9                           METCALF SUBSTATION 230 KV        [1553]
# 10                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 11                             ARCO SUBSTATION 230 KV  [1586, 1587]
# 12                        PITTSBURG SUBSTATION 230 KV        [1555]
# 13                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 14                        HENRIETTA SUBSTATION 230 KV        [1578]
# 15  MIDWAY SUBSTATION 230 KV (VIA THE MIDWAY - ELK...        [1595]
# 16                             ARCO SUBSTATION 230 KV  [1586, 1587]
# 17                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 18                           MIDWAY SUBSTATION 500 KV        [1596]
# 19                          PANOCHE SUBSTATION 230 KV  [1574, 1582]
# 20                             ARCO SUBSTATION 230 KV  [1586, 1587]
# 21                        HENRIETTA SUBSTATION 230 KV        [1578]
# 22  MIDWAY SUBSTATION 230 KV (VIA THE MIDWAY - ELK...        [1595]
# 23                             ARCO SUBSTATION 230 KV  [1586, 1587]
# 24  MIDWAY SUBSTATION 230 KV (VIA THE MIDWAY - ELK...        [1595]
# 25  NEW SW STA (LOOP IN PG&E'S MIDWAY - DIABLO CAN...        [1600]
# 26                           MIDWAY SUBSTATION 500 KV        [1596]
# 27                          GATES  MIDWAY 230 KV LINE  [1593, 1594]
# 28  MIDWAY SUBSTATION 230 KV (VIA THE MIDWAY - ELK...        [1595]
# 29               MIDWAY  WHEELER RIDGE #1 230 KV LINE        [1597]
# 30                           MIDWAY SUBSTATION 500 KV        [1596]
#
#     similarity_score
# 0                 85
# 1                 81
# 2                 88
# 3                 81
# 4                 81
# 5                 85
# 6                 93
# 7                 85
# 8                 87
# 9                 81
# 10                81
# 11                87
# 12                81
# 13                81
# 14                81
# 15                81
# 16                87
# 17                81
# 18                83
# 19                81
# 20                87
# 21                81
# 22                81
# 23                87
# 24                87
# 25                85
# 26                83
# 27                83
# 28                86
# 29                86
# 30                91
# Matched Q_ids saved to '/Users/vk365/Dropbox/Interconnections_data/data/pdf_scraper/output/Cluster 12/matched_qids.csv'.
#
# Total checks performed: 195
# Total mismatches found: 0
